# %%
import sys
import os

# Menambahkan folder root proyek ke sys.path
sys.path.append(os.path.abspath(".."))

import matplotlib.pyplot as plt
from simulated_annealing import SimulatedAnnealing
from cube.visual import plot_cube

# %%
main = SimulatedAnnealing(initial_temperature=1000, cooling_rate=0.99, temperature_threshold=0.001, stagnation_threshold=50)
initial_state = main.initial_state
initial_score = main.objective_function

# %%
# Visualisasi kondisi awal
plot_cube(initial_state, f"Initial State of the Cube (Score: {initial_score})")

# %%
# Menjalankan pencarian lokal
final_state, final_score = main.search()
# Out:
# Iterasi 1: Skor Heuristik = 3644, Temperatur = 1000.0000, Probabilitas = 0.9085
# Iterasi 2: Skor Heuristik = 3702, Temperatur = 990.0000, Probabilitas = 0.9431
# Iterasi 3: Skor Heuristik = 3598, Temperatur = 980.1000, Probabilitas = 1.0000
# Iterasi 4: Skor Heuristik = 3667, Temperatur = 970.2990, Probabilitas = 0.9314
# Iterasi 5: Skor Heuristik = 3702, Temperatur = 960.5960, Probabilitas = 0.9642
# Iterasi 6: Skor Heuristik = 3752, Temperatur = 950.9900, Probabilitas = 0.9488
# Iterasi 7: Skor Heuristik = 3740, Temperatur = 941.4801, Probabilitas = 1.0000
# Iterasi 8: Skor Heuristik = 3761, Temperatur = 932.0653, Probabilitas = 0.9777
# Iterasi 9: Skor Heuristik = 3608, Temperatur = 922.7447, Probabilitas = 1.0000
# Iterasi 10: Skor Heuristik = 3852, Temperatur = 913.5172, Probabilitas = 0.7656
# Iterasi 11: Skor Heuristik = 4074, Temperatur = 904.3821, Probabilitas = 0.7823
# Iterasi 12: Skor Heuristik = 4074, Temperatur = 895.3383, Probabilitas = 1.0000
# Iterasi 13: Skor Heuristik = 4074, Temperatur = 886.3849, Probabilitas = 1.0000
# Iterasi 14: Skor Heuristik = 4196, Temperatur = 877.5210, Probabilitas = 0.8702
# Iterasi 15: Skor Heuristik = 4195, Temperatur = 868.7458, Probabilitas = 1.0000
# Iterasi 16: Skor Heuristik = 3901, Temperatur = 860.0584, Probabilitas = 1.0000
# Iterasi 17: Skor Heuristik = 3928, Temperatur = 851.4578, Probabilitas = 0.9688
# Iterasi 18: Skor Heuristik = 3886, Temperatur = 842.9432, Probabilitas = 1.0000
# Iterasi 19: Skor Heuristik = 3798, Temperatur = 834.5138, Probabilitas = 1.0000
# Iterasi 20: Skor Heuristik = 3750, Temperatur = 826.1686, Probabilitas = 1.0000
# Iterasi 21: Skor Heuristik = 3982, Temperatur = 817.9069, Probabilitas = 0.7530
# Iterasi 22: Skor Heuristik = 4064, Temperatur = 809.7279, Probabilitas = 0.9037
# Iterasi 23: Skor Heuristik = 3848, Temperatur = 801.6306, Probabilitas = 1.0000
# Iterasi 24: Skor Heuristik = 3147, Temperatur = 793.6143, Probabilitas = 1.0000
# Iterasi 25: Skor Heuristik = 3286, Temperatur = 785.6781, Probabilitas = 0.8378
# Iterasi 26: Skor Heuristik = 3265, Temperatur = 777.8214, Probabilitas = 1.0000
# Iterasi 27: Skor Heuristik = 3265, Temperatur = 770.0431, Probabilitas = 1.0000
# Iterasi 28: Skor Heuristik = 3265, Temperatur = 762.3427, Probabilitas = 0.6236
# Iterasi 29: Skor Heuristik = 3249, Temperatur = 754.7193, Probabilitas = 1.0000
# Iterasi 30: Skor Heuristik = 3293, Temperatur = 747.1721, Probabilitas = 0.9428
# Iterasi 31: Skor Heuristik = 3332, Temperatur = 739.7004, Probabilitas = 0.9486
# Iterasi 32: Skor Heuristik = 3274, Temperatur = 732.3034, Probabilitas = 1.0000
# Iterasi 33: Skor Heuristik = 3317, Temperatur = 724.9803, Probabilitas = 0.9424
# Iterasi 34: Skor Heuristik = 3353, Temperatur = 717.7305, Probabilitas = 0.9511
# Iterasi 35: Skor Heuristik = 3402, Temperatur = 710.5532, Probabilitas = 0.9334
# Iterasi 36: Skor Heuristik = 3321, Temperatur = 703.4477, Probabilitas = 1.0000
# Iterasi 37: Skor Heuristik = 3541, Temperatur = 696.4132, Probabilitas = 0.7291
# Iterasi 38: Skor Heuristik = 3541, Temperatur = 689.4491, Probabilitas = 1.0000
# Iterasi 39: Skor Heuristik = 3613, Temperatur = 682.5546, Probabilitas = 0.8999
# Iterasi 40: Skor Heuristik = 3642, Temperatur = 675.7290, Probabilitas = 0.9580
# Iterasi 41: Skor Heuristik = 3680, Temperatur = 668.9718, Probabilitas = 0.9448
# Iterasi 42: Skor Heuristik = 3852, Temperatur = 662.2820, Probabilitas = 0.7713
# Iterasi 43: Skor Heuristik = 4152, Temperatur = 655.6592, Probabilitas = 0.6328
# Iterasi 44: Skor Heuristik = 4150, Temperatur = 649.1026, Probabilitas = 1.0000
# Iterasi 45: Skor Heuristik = 3890, Temperatur = 642.6116, Probabilitas = 1.0000
# Iterasi 46: Skor Heuristik = 3958, Temperatur = 636.1855, Probabilitas = 0.8986
# Iterasi 47: Skor Heuristik = 4058, Temperatur = 629.8236, Probabilitas = 0.8532
# Iterasi 48: Skor Heuristik = 4080, Temperatur = 623.5254, Probabilitas = 0.9653
# Iterasi 49: Skor Heuristik = 3990, Temperatur = 617.2901, Probabilitas = 1.0000
# Iterasi 50: Skor Heuristik = 3978, Temperatur = 611.1172, Probabilitas = 1.0000
# Iterasi 51: Skor Heuristik = 3978, Temperatur = 605.0061, Probabilitas = 0.7987
# Iterasi 52: Skor Heuristik = 4014, Temperatur = 598.9560, Probabilitas = 0.9417
# Iterasi 53: Skor Heuristik = 3872, Temperatur = 592.9664, Probabilitas = 1.0000
# Iterasi 54: Skor Heuristik = 3925, Temperatur = 587.0368, Probabilitas = 0.9137
# Iterasi 55: Skor Heuristik = 3891, Temperatur = 581.1664, Probabilitas = 1.0000
# Iterasi 56: Skor Heuristik = 3795, Temperatur = 575.3547, Probabilitas = 1.0000
# Iterasi 57: Skor Heuristik = 3885, Temperatur = 569.6012, Probabilitas = 0.8538
# Iterasi 58: Skor Heuristik = 3885, Temperatur = 563.9052, Probabilitas = 1.0000
# Iterasi 59: Skor Heuristik = 3949, Temperatur = 558.2661, Probabilitas = 0.8917
# Iterasi 60: Skor Heuristik = 3899, Temperatur = 552.6835, Probabilitas = 1.0000
# Iterasi 61: Skor Heuristik = 3923, Temperatur = 547.1566, Probabilitas = 0.9571
# Iterasi 62: Skor Heuristik = 3965, Temperatur = 541.6851, Probabilitas = 0.9254
# Iterasi 63: Skor Heuristik = 3946, Temperatur = 536.2682, Probabilitas = 1.0000
# Iterasi 64: Skor Heuristik = 3878, Temperatur = 530.9055, Probabilitas = 1.0000
# Iterasi 65: Skor Heuristik = 3554, Temperatur = 525.5965, Probabilitas = 1.0000
# Iterasi 66: Skor Heuristik = 3554, Temperatur = 520.3405, Probabilitas = 1.0000
# Iterasi 67: Skor Heuristik = 3558, Temperatur = 515.1371, Probabilitas = 0.9923
# Iterasi 68: Skor Heuristik = 3710, Temperatur = 509.9857, Probabilitas = 0.7423
# Iterasi 69: Skor Heuristik = 3828, Temperatur = 504.8859, Probabilitas = 0.7916
# Iterasi 70: Skor Heuristik = 3891, Temperatur = 499.8370, Probabilitas = 0.8816
# Iterasi 71: Skor Heuristik = 3891, Temperatur = 494.8387, Probabilitas = 0.8072
# Iterasi 72: Skor Heuristik = 3899, Temperatur = 489.8903, Probabilitas = 0.9838
# Iterasi 73: Skor Heuristik = 3945, Temperatur = 484.9914, Probabilitas = 0.9095
# Iterasi 74: Skor Heuristik = 3715, Temperatur = 480.1415, Probabilitas = 1.0000
# Iterasi 75: Skor Heuristik = 3470, Temperatur = 475.3400, Probabilitas = 1.0000
# Iterasi 76: Skor Heuristik = 3800, Temperatur = 470.5866, Probabilitas = 0.4960
# Iterasi 77: Skor Heuristik = 3800, Temperatur = 465.8808, Probabilitas = 0.8173
# Iterasi 78: Skor Heuristik = 3668, Temperatur = 461.2220, Probabilitas = 1.0000
# Iterasi 79: Skor Heuristik = 3668, Temperatur = 456.6097, Probabilitas = 0.7232
# Iterasi 80: Skor Heuristik = 3592, Temperatur = 452.0437, Probabilitas = 1.0000
# Iterasi 81: Skor Heuristik = 3486, Temperatur = 447.5232, Probabilitas = 1.0000
# Iterasi 82: Skor Heuristik = 3410, Temperatur = 443.0480, Probabilitas = 1.0000
# Iterasi 83: Skor Heuristik = 3296, Temperatur = 438.6175, Probabilitas = 1.0000
# Iterasi 84: Skor Heuristik = 3322, Temperatur = 434.2313, Probabilitas = 0.9419
# Iterasi 85: Skor Heuristik = 3322, Temperatur = 429.8890, Probabilitas = 1.0000
# Iterasi 86: Skor Heuristik = 3335, Temperatur = 425.5901, Probabilitas = 0.9699
# Iterasi 87: Skor Heuristik = 3335, Temperatur = 421.3342, Probabilitas = 0.7850
# Iterasi 88: Skor Heuristik = 3335, Temperatur = 417.1209, Probabilitas = 1.0000
# Iterasi 89: Skor Heuristik = 3443, Temperatur = 412.9497, Probabilitas = 0.7699
# Iterasi 90: Skor Heuristik = 3407, Temperatur = 408.8202, Probabilitas = 1.0000
# Iterasi 91: Skor Heuristik = 3341, Temperatur = 404.7320, Probabilitas = 1.0000
# Iterasi 92: Skor Heuristik = 3299, Temperatur = 400.6847, Probabilitas = 1.0000
# Iterasi 93: Skor Heuristik = 3351, Temperatur = 396.6778, Probabilitas = 0.8771
# Iterasi 94: Skor Heuristik = 3226, Temperatur = 392.7110, Probabilitas = 1.0000
# Iterasi 95: Skor Heuristik = 3073, Temperatur = 388.7839, Probabilitas = 1.0000
# Iterasi 96: Skor Heuristik = 3073, Temperatur = 384.8961, Probabilitas = 0.5129
# Iterasi 97: Skor Heuristik = 3073, Temperatur = 381.0471, Probabilitas = 0.8432
# Iterasi 98: Skor Heuristik = 3073, Temperatur = 377.2366, Probabilitas = 1.0000
# Iterasi 99: Skor Heuristik = 2924, Temperatur = 373.4643, Probabilitas = 1.0000
# Iterasi 100: Skor Heuristik = 2858, Temperatur = 369.7296, Probabilitas = 1.0000
# Iterasi 101: Skor Heuristik = 2858, Temperatur = 366.0323, Probabilitas = 0.6285
# Iterasi 102: Skor Heuristik = 2918, Temperatur = 362.3720, Probabilitas = 0.8474
# Iterasi 103: Skor Heuristik = 2918, Temperatur = 358.7483, Probabilitas = 0.9564
# Iterasi 104: Skor Heuristik = 2949, Temperatur = 355.1608, Probabilitas = 0.9164
# Iterasi 105: Skor Heuristik = 2943, Temperatur = 351.6092, Probabilitas = 1.0000
# Iterasi 106: Skor Heuristik = 2933, Temperatur = 348.0931, Probabilitas = 1.0000
# Iterasi 107: Skor Heuristik = 2933, Temperatur = 344.6122, Probabilitas = 0.6661
# Iterasi 108: Skor Heuristik = 2909, Temperatur = 341.1661, Probabilitas = 1.0000
# Iterasi 109: Skor Heuristik = 2763, Temperatur = 337.7544, Probabilitas = 1.0000
# Iterasi 110: Skor Heuristik = 2810, Temperatur = 334.3769, Probabilitas = 0.8689
# Iterasi 111: Skor Heuristik = 2804, Temperatur = 331.0331, Probabilitas = 1.0000
# Iterasi 112: Skor Heuristik = 2804, Temperatur = 327.7228, Probabilitas = 0.9351
# Iterasi 113: Skor Heuristik = 2804, Temperatur = 324.4455, Probabilitas = 1.0000
# Iterasi 114: Skor Heuristik = 2813, Temperatur = 321.2011, Probabilitas = 0.9724
# Iterasi 115: Skor Heuristik = 2652, Temperatur = 317.9891, Probabilitas = 1.0000
# Iterasi 116: Skor Heuristik = 2708, Temperatur = 314.8092, Probabilitas = 0.8370
# Iterasi 117: Skor Heuristik = 2381, Temperatur = 311.6611, Probabilitas = 1.0000
# Iterasi 118: Skor Heuristik = 2502, Temperatur = 308.5445, Probabilitas = 0.6756
# Iterasi 119: Skor Heuristik = 2478, Temperatur = 305.4590, Probabilitas = 1.0000
# Iterasi 120: Skor Heuristik = 2462, Temperatur = 302.4044, Probabilitas = 1.0000
# Iterasi 121: Skor Heuristik = 2462, Temperatur = 299.3804, Probabilitas = 1.0000
# Iterasi 122: Skor Heuristik = 2586, Temperatur = 296.3866, Probabilitas = 0.6581
# Iterasi 123: Skor Heuristik = 2602, Temperatur = 293.4227, Probabilitas = 0.9469
# Iterasi 124: Skor Heuristik = 2499, Temperatur = 290.4885, Probabilitas = 1.0000
# Iterasi 125: Skor Heuristik = 2431, Temperatur = 287.5836, Probabilitas = 1.0000
# Iterasi 126: Skor Heuristik = 2431, Temperatur = 284.7078, Probabilitas = 1.0000
# Iterasi 127: Skor Heuristik = 2431, Temperatur = 281.8607, Probabilitas = 1.0000
# Iterasi 128: Skor Heuristik = 2431, Temperatur = 279.0421, Probabilitas = 0.7191
# Iterasi 129: Skor Heuristik = 2410, Temperatur = 276.2517, Probabilitas = 1.0000
# Iterasi 130: Skor Heuristik = 2414, Temperatur = 273.4892, Probabilitas = 0.9855
# Iterasi 131: Skor Heuristik = 2414, Temperatur = 270.7543, Probabilitas = 1.0000
# Iterasi 132: Skor Heuristik = 2410, Temperatur = 268.0467, Probabilitas = 1.0000
# Iterasi 133: Skor Heuristik = 2410, Temperatur = 265.3662, Probabilitas = 0.6809
# Iterasi 134: Skor Heuristik = 2410, Temperatur = 262.7126, Probabilitas = 0.1305
# Iterasi 135: Skor Heuristik = 2464, Temperatur = 260.0855, Probabilitas = 0.8125
# Iterasi 136: Skor Heuristik = 2432, Temperatur = 257.4846, Probabilitas = 1.0000
# Iterasi 137: Skor Heuristik = 2564, Temperatur = 254.9098, Probabilitas = 0.5958
# Iterasi 138: Skor Heuristik = 2558, Temperatur = 252.3607, Probabilitas = 1.0000
# Iterasi 139: Skor Heuristik = 2558, Temperatur = 249.8371, Probabilitas = 0.7202
# Iterasi 140: Skor Heuristik = 2558, Temperatur = 247.3387, Probabilitas = 0.5632
# Iterasi 141: Skor Heuristik = 2582, Temperatur = 244.8653, Probabilitas = 0.9066
# Iterasi 142: Skor Heuristik = 2513, Temperatur = 242.4166, Probabilitas = 1.0000
# Iterasi 143: Skor Heuristik = 2381, Temperatur = 239.9925, Probabilitas = 1.0000
# Iterasi 144: Skor Heuristik = 2385, Temperatur = 237.5926, Probabilitas = 0.9833
# Iterasi 145: Skor Heuristik = 2385, Temperatur = 235.2166, Probabilitas = 0.3559
# Iterasi 146: Skor Heuristik = 2389, Temperatur = 232.8645, Probabilitas = 0.9830
# Iterasi 147: Skor Heuristik = 2425, Temperatur = 230.5358, Probabilitas = 0.8554
# Iterasi 148: Skor Heuristik = 2263, Temperatur = 228.2305, Probabilitas = 1.0000
# Iterasi 149: Skor Heuristik = 2263, Temperatur = 225.9482, Probabilitas = 0.0858
# Iterasi 150: Skor Heuristik = 2302, Temperatur = 223.6887, Probabilitas = 0.8400
# Iterasi 151: Skor Heuristik = 2299, Temperatur = 221.4518, Probabilitas = 1.0000
# Iterasi 152: Skor Heuristik = 2299, Temperatur = 219.2373, Probabilitas = 1.0000
# Iterasi 153: Skor Heuristik = 2299, Temperatur = 217.0449, Probabilitas = 0.9036
# Iterasi 154: Skor Heuristik = 2295, Temperatur = 214.8744, Probabilitas = 1.0000
# Iterasi 155: Skor Heuristik = 2295, Temperatur = 212.7257, Probabilitas = 0.4604
# Iterasi 156: Skor Heuristik = 2371, Temperatur = 210.5984, Probabilitas = 0.6971
# Iterasi 157: Skor Heuristik = 2414, Temperatur = 208.4925, Probabilitas = 0.8136
# Iterasi 158: Skor Heuristik = 2464, Temperatur = 206.4075, Probabilitas = 0.7849
# Iterasi 159: Skor Heuristik = 2473, Temperatur = 204.3435, Probabilitas = 0.9569
# Iterasi 160: Skor Heuristik = 2473, Temperatur = 202.3000, Probabilitas = 0.6537
# Iterasi 161: Skor Heuristik = 2347, Temperatur = 200.2770, Probabilitas = 1.0000
# Iterasi 162: Skor Heuristik = 2347, Temperatur = 198.2743, Probabilitas = 0.4417
# Iterasi 163: Skor Heuristik = 2565, Temperatur = 196.2915, Probabilitas = 0.3294
# Iterasi 164: Skor Heuristik = 2579, Temperatur = 194.3286, Probabilitas = 0.9305
# Iterasi 165: Skor Heuristik = 2567, Temperatur = 192.3853, Probabilitas = 1.0000
# Iterasi 166: Skor Heuristik = 2395, Temperatur = 190.4615, Probabilitas = 1.0000
# Iterasi 167: Skor Heuristik = 2395, Temperatur = 188.5568, Probabilitas = 0.3829
# Iterasi 168: Skor Heuristik = 2395, Temperatur = 186.6713, Probabilitas = 0.4878
# Iterasi 169: Skor Heuristik = 2357, Temperatur = 184.8046, Probabilitas = 1.0000
# Iterasi 170: Skor Heuristik = 2357, Temperatur = 182.9565, Probabilitas = 0.2027
# Iterasi 171: Skor Heuristik = 2363, Temperatur = 181.1270, Probabilitas = 0.9674
# Iterasi 172: Skor Heuristik = 2363, Temperatur = 179.3157, Probabilitas = 1.0000
# Iterasi 173: Skor Heuristik = 2363, Temperatur = 177.5225, Probabilitas = 0.3241
# Iterasi 174: Skor Heuristik = 2507, Temperatur = 175.7473, Probabilitas = 0.4407
# Iterasi 175: Skor Heuristik = 2503, Temperatur = 173.9898, Probabilitas = 1.0000
# Iterasi 176: Skor Heuristik = 2480, Temperatur = 172.2499, Probabilitas = 1.0000
# Iterasi 177: Skor Heuristik = 2459, Temperatur = 170.5274, Probabilitas = 1.0000
# Iterasi 178: Skor Heuristik = 2449, Temperatur = 168.8222, Probabilitas = 1.0000
# Iterasi 179: Skor Heuristik = 2591, Temperatur = 167.1339, Probabilitas = 0.4276
# Iterasi 180: Skor Heuristik = 2663, Temperatur = 165.4626, Probabilitas = 0.6472
# Iterasi 181: Skor Heuristik = 2663, Temperatur = 163.8080, Probabilitas = 0.2708
# Iterasi 182: Skor Heuristik = 2718, Temperatur = 162.1699, Probabilitas = 0.7124
# Iterasi 183: Skor Heuristik = 2734, Temperatur = 160.5482, Probabilitas = 0.9051
# Iterasi 184: Skor Heuristik = 2720, Temperatur = 158.9427, Probabilitas = 1.0000
# Iterasi 185: Skor Heuristik = 2684, Temperatur = 157.3533, Probabilitas = 1.0000
# Iterasi 186: Skor Heuristik = 2677, Temperatur = 155.7797, Probabilitas = 1.0000
# Iterasi 187: Skor Heuristik = 2677, Temperatur = 154.2220, Probabilitas = 1.0000
# Iterasi 188: Skor Heuristik = 2663, Temperatur = 152.6797, Probabilitas = 1.0000
# Iterasi 189: Skor Heuristik = 2582, Temperatur = 151.1529, Probabilitas = 1.0000
# Iterasi 190: Skor Heuristik = 2582, Temperatur = 149.6414, Probabilitas = 0.4859
# Iterasi 191: Skor Heuristik = 2666, Temperatur = 148.1450, Probabilitas = 0.5672
# Iterasi 192: Skor Heuristik = 2684, Temperatur = 146.6635, Probabilitas = 0.8845
# Iterasi 193: Skor Heuristik = 2922, Temperatur = 145.1969, Probabilitas = 0.1941
# Iterasi 194: Skor Heuristik = 2922, Temperatur = 143.7449, Probabilitas = 0.6588
# Iterasi 195: Skor Heuristik = 3232, Temperatur = 142.3075, Probabilitas = 0.1132
# Iterasi 196: Skor Heuristik = 3290, Temperatur = 140.8844, Probabilitas = 0.6625
# Iterasi 197: Skor Heuristik = 3296, Temperatur = 139.4756, Probabilitas = 0.9579
# Iterasi 198: Skor Heuristik = 3296, Temperatur = 138.0808, Probabilitas = 0.1918
# Iterasi 199: Skor Heuristik = 3291, Temperatur = 136.7000, Probabilitas = 1.0000
# Iterasi 200: Skor Heuristik = 3380, Temperatur = 135.3330, Probabilitas = 0.5181
# Iterasi 201: Skor Heuristik = 3399, Temperatur = 133.9797, Probabilitas = 0.8678
# Iterasi 202: Skor Heuristik = 3357, Temperatur = 132.6399, Probabilitas = 1.0000
# Iterasi 203: Skor Heuristik = 3335, Temperatur = 131.3135, Probabilitas = 1.0000
# Iterasi 204: Skor Heuristik = 3334, Temperatur = 130.0003, Probabilitas = 1.0000
# Iterasi 205: Skor Heuristik = 3276, Temperatur = 128.7003, Probabilitas = 1.0000
# Iterasi 206: Skor Heuristik = 3256, Temperatur = 127.4133, Probabilitas = 1.0000
# Iterasi 207: Skor Heuristik = 3254, Temperatur = 126.1392, Probabilitas = 1.0000
# Iterasi 208: Skor Heuristik = 3277, Temperatur = 124.8778, Probabilitas = 0.8318
# Iterasi 209: Skor Heuristik = 3203, Temperatur = 123.6290, Probabilitas = 1.0000
# Iterasi 210: Skor Heuristik = 3255, Temperatur = 122.3927, Probabilitas = 0.6539
# Iterasi 211: Skor Heuristik = 3385, Temperatur = 121.1688, Probabilitas = 0.3420
# Iterasi 212: Skor Heuristik = 3432, Temperatur = 119.9571, Probabilitas = 0.6758
# Iterasi 213: Skor Heuristik = 3510, Temperatur = 118.7576, Probabilitas = 0.5185
# Iterasi 214: Skor Heuristik = 3512, Temperatur = 117.5700, Probabilitas = 0.9831
# Iterasi 215: Skor Heuristik = 3488, Temperatur = 116.3943, Probabilitas = 1.0000
# Iterasi 216: Skor Heuristik = 3564, Temperatur = 115.2303, Probabilitas = 0.5171
# Iterasi 217: Skor Heuristik = 3564, Temperatur = 114.0780, Probabilitas = 0.4162
# Iterasi 218: Skor Heuristik = 3355, Temperatur = 112.9373, Probabilitas = 1.0000
# Iterasi 219: Skor Heuristik = 3355, Temperatur = 111.8079, Probabilitas = 0.0789
# Iterasi 220: Skor Heuristik = 3301, Temperatur = 110.6898, Probabilitas = 1.0000
# Iterasi 221: Skor Heuristik = 3108, Temperatur = 109.5829, Probabilitas = 1.0000
# Iterasi 222: Skor Heuristik = 3022, Temperatur = 108.4871, Probabilitas = 1.0000
# Iterasi 223: Skor Heuristik = 3080, Temperatur = 107.4022, Probabilitas = 0.5827
# Iterasi 224: Skor Heuristik = 3084, Temperatur = 106.3282, Probabilitas = 0.9631
# Iterasi 225: Skor Heuristik = 3084, Temperatur = 105.2649, Probabilitas = 0.3198
# Iterasi 226: Skor Heuristik = 3192, Temperatur = 104.2123, Probabilitas = 0.3547
# Iterasi 227: Skor Heuristik = 3288, Temperatur = 103.1701, Probabilitas = 0.3944
# Iterasi 228: Skor Heuristik = 3355, Temperatur = 102.1384, Probabilitas = 0.5189
# Iterasi 229: Skor Heuristik = 3347, Temperatur = 101.1170, Probabilitas = 1.0000
# Iterasi 230: Skor Heuristik = 3443, Temperatur = 100.1059, Probabilitas = 0.3833
# Iterasi 231: Skor Heuristik = 3381, Temperatur = 99.1048, Probabilitas = 1.0000
# Iterasi 232: Skor Heuristik = 3313, Temperatur = 98.1138, Probabilitas = 1.0000
# Iterasi 233: Skor Heuristik = 3340, Temperatur = 97.1326, Probabilitas = 0.7573
# Iterasi 234: Skor Heuristik = 3302, Temperatur = 96.1613, Probabilitas = 1.0000
# Iterasi 235: Skor Heuristik = 3302, Temperatur = 95.1997, Probabilitas = 0.2690
# Iterasi 236: Skor Heuristik = 3253, Temperatur = 94.2477, Probabilitas = 1.0000
# Iterasi 237: Skor Heuristik = 3253, Temperatur = 93.3052, Probabilitas = 0.0158
# Iterasi 238: Skor Heuristik = 3148, Temperatur = 92.3722, Probabilitas = 1.0000
# Iterasi 239: Skor Heuristik = 3150, Temperatur = 91.4484, Probabilitas = 0.9784
# Iterasi 240: Skor Heuristik = 3146, Temperatur = 90.5340, Probabilitas = 1.0000
# Iterasi 241: Skor Heuristik = 3146, Temperatur = 89.6286, Probabilitas = 0.0027
# Iterasi 242: Skor Heuristik = 3146, Temperatur = 88.7323, Probabilitas = 0.1229
# Iterasi 243: Skor Heuristik = 2996, Temperatur = 87.8450, Probabilitas = 1.0000
# Iterasi 244: Skor Heuristik = 2992, Temperatur = 86.9666, Probabilitas = 1.0000
# Iterasi 245: Skor Heuristik = 3129, Temperatur = 86.0969, Probabilitas = 0.2037
# Iterasi 246: Skor Heuristik = 3129, Temperatur = 85.2359, Probabilitas = 1.0000
# Iterasi 247: Skor Heuristik = 3153, Temperatur = 84.3836, Probabilitas = 0.7525
# Iterasi 248: Skor Heuristik = 3158, Temperatur = 83.5397, Probabilitas = 0.9419
# Iterasi 249: Skor Heuristik = 3158, Temperatur = 82.7043, Probabilitas = 0.0481
# Iterasi 250: Skor Heuristik = 3158, Temperatur = 81.8773, Probabilitas = 1.0000
# Iterasi 251: Skor Heuristik = 3192, Temperatur = 81.0585, Probabilitas = 0.6574
# Iterasi 252: Skor Heuristik = 3182, Temperatur = 80.2479, Probabilitas = 1.0000
# Iterasi 253: Skor Heuristik = 3130, Temperatur = 79.4455, Probabilitas = 1.0000
# Iterasi 254: Skor Heuristik = 3113, Temperatur = 78.6510, Probabilitas = 1.0000
# Iterasi 255: Skor Heuristik = 3113, Temperatur = 77.8645, Probabilitas = 0.3720
# Iterasi 256: Skor Heuristik = 3113, Temperatur = 77.0858, Probabilitas = 0.5160
# Iterasi 257: Skor Heuristik = 3113, Temperatur = 76.3150, Probabilitas = 0.3505
# Iterasi 258: Skor Heuristik = 3121, Temperatur = 75.5518, Probabilitas = 0.8995
# Iterasi 259: Skor Heuristik = 3123, Temperatur = 74.7963, Probabilitas = 0.9736
# Iterasi 260: Skor Heuristik = 3123, Temperatur = 74.0484, Probabilitas = 0.3681
# Iterasi 261: Skor Heuristik = 3123, Temperatur = 73.3079, Probabilitas = 0.1328
# Iterasi 262: Skor Heuristik = 3109, Temperatur = 72.5748, Probabilitas = 1.0000
# Iterasi 263: Skor Heuristik = 3046, Temperatur = 71.8490, Probabilitas = 1.0000
# Iterasi 264: Skor Heuristik = 3046, Temperatur = 71.1306, Probabilitas = 1.0000
# Iterasi 265: Skor Heuristik = 3046, Temperatur = 70.4192, Probabilitas = 0.7012
# Iterasi 266: Skor Heuristik = 3046, Temperatur = 69.7151, Probabilitas = 1.0000
# Iterasi 267: Skor Heuristik = 3040, Temperatur = 69.0179, Probabilitas = 1.0000
# Iterasi 268: Skor Heuristik = 3040, Temperatur = 68.3277, Probabilitas = 1.0000
# Iterasi 269: Skor Heuristik = 3040, Temperatur = 67.6444, Probabilitas = 1.0000
# Iterasi 270: Skor Heuristik = 3120, Temperatur = 66.9680, Probabilitas = 0.3028
# Iterasi 271: Skor Heuristik = 2992, Temperatur = 66.2983, Probabilitas = 1.0000
# Iterasi 272: Skor Heuristik = 3034, Temperatur = 65.6353, Probabilitas = 0.5273
# Iterasi 273: Skor Heuristik = 3078, Temperatur = 64.9790, Probabilitas = 0.5081
# Iterasi 274: Skor Heuristik = 3040, Temperatur = 64.3292, Probabilitas = 1.0000
# Iterasi 275: Skor Heuristik = 2937, Temperatur = 63.6859, Probabilitas = 1.0000
# Iterasi 276: Skor Heuristik = 3012, Temperatur = 63.0490, Probabilitas = 0.3044
# Iterasi 277: Skor Heuristik = 2970, Temperatur = 62.4186, Probabilitas = 1.0000
# Iterasi 278: Skor Heuristik = 2970, Temperatur = 61.7944, Probabilitas = 0.2486
# Iterasi 279: Skor Heuristik = 2949, Temperatur = 61.1764, Probabilitas = 1.0000
# Iterasi 280: Skor Heuristik = 2949, Temperatur = 60.5647, Probabilitas = 0.0406
# Iterasi 281: Skor Heuristik = 2949, Temperatur = 59.9590, Probabilitas = 1.0000
# Iterasi 282: Skor Heuristik = 3059, Temperatur = 59.3594, Probabilitas = 0.1567
# Iterasi 283: Skor Heuristik = 3059, Temperatur = 58.7658, Probabilitas = 0.0368
# Iterasi 284: Skor Heuristik = 3059, Temperatur = 58.1782, Probabilitas = 0.2057
# Iterasi 285: Skor Heuristik = 3059, Temperatur = 57.5964, Probabilitas = 0.1202
# Iterasi 286: Skor Heuristik = 3059, Temperatur = 57.0204, Probabilitas = 1.0000
# Iterasi 287: Skor Heuristik = 2975, Temperatur = 56.4502, Probabilitas = 1.0000
# Iterasi 288: Skor Heuristik = 2965, Temperatur = 55.8857, Probabilitas = 1.0000
# Iterasi 289: Skor Heuristik = 2951, Temperatur = 55.3269, Probabilitas = 1.0000
# Iterasi 290: Skor Heuristik = 2951, Temperatur = 54.7736, Probabilitas = 0.0130
# Iterasi 291: Skor Heuristik = 2943, Temperatur = 54.2259, Probabilitas = 1.0000
# Iterasi 292: Skor Heuristik = 2943, Temperatur = 53.6836, Probabilitas = 0.7997
# Iterasi 293: Skor Heuristik = 2943, Temperatur = 53.1468, Probabilitas = 0.0759
# Iterasi 294: Skor Heuristik = 2943, Temperatur = 52.6153, Probabilitas = 0.0516
# Iterasi 295: Skor Heuristik = 2939, Temperatur = 52.0891, Probabilitas = 1.0000
# Iterasi 296: Skor Heuristik = 2936, Temperatur = 51.5683, Probabilitas = 1.0000
# Iterasi 297: Skor Heuristik = 2928, Temperatur = 51.0526, Probabilitas = 1.0000
# Iterasi 298: Skor Heuristik = 2928, Temperatur = 50.5420, Probabilitas = 0.0145
# Iterasi 299: Skor Heuristik = 2928, Temperatur = 50.0366, Probabilitas = 0.0660
# Iterasi 300: Skor Heuristik = 2928, Temperatur = 49.5363, Probabilitas = 0.0029
# Iterasi 301: Skor Heuristik = 2928, Temperatur = 49.0409, Probabilitas = 0.0451
# Iterasi 302: Skor Heuristik = 2928, Temperatur = 48.5505, Probabilitas = 0.1059
# Iterasi 303: Skor Heuristik = 2923, Temperatur = 48.0650, Probabilitas = 1.0000
# Iterasi 304: Skor Heuristik = 2919, Temperatur = 47.5843, Probabilitas = 1.0000
# Iterasi 305: Skor Heuristik = 2772, Temperatur = 47.1085, Probabilitas = 1.0000
# Iterasi 306: Skor Heuristik = 2878, Temperatur = 46.6374, Probabilitas = 0.1030
# Iterasi 307: Skor Heuristik = 2878, Temperatur = 46.1710, Probabilitas = 0.2786
# Iterasi 308: Skor Heuristik = 2878, Temperatur = 45.7093, Probabilitas = 0.2520
# Iterasi 309: Skor Heuristik = 2878, Temperatur = 45.2522, Probabilitas = 0.0291
# Iterasi 310: Skor Heuristik = 2893, Temperatur = 44.7997, Probabilitas = 0.7155
# Iterasi 311: Skor Heuristik = 2898, Temperatur = 44.3517, Probabilitas = 0.8934
# Iterasi 312: Skor Heuristik = 2898, Temperatur = 43.9082, Probabilitas = 0.0403
# Iterasi 313: Skor Heuristik = 2917, Temperatur = 43.4691, Probabilitas = 0.6459
# Iterasi 314: Skor Heuristik = 2938, Temperatur = 43.0344, Probabilitas = 0.6139
# Iterasi 315: Skor Heuristik = 2941, Temperatur = 42.6041, Probabilitas = 0.9320
# Iterasi 316: Skor Heuristik = 2929, Temperatur = 42.1780, Probabilitas = 1.0000
# Iterasi 317: Skor Heuristik = 2929, Temperatur = 41.7563, Probabilitas = 0.8061
# Iterasi 318: Skor Heuristik = 2929, Temperatur = 41.3387, Probabilitas = 0.0030
# Iterasi 319: Skor Heuristik = 2929, Temperatur = 40.9253, Probabilitas = 0.1808
# Iterasi 320: Skor Heuristik = 2889, Temperatur = 40.5160, Probabilitas = 1.0000
# Iterasi 321: Skor Heuristik = 2855, Temperatur = 40.1109, Probabilitas = 1.0000
# Iterasi 322: Skor Heuristik = 2855, Temperatur = 39.7098, Probabilitas = 0.2700
# Iterasi 323: Skor Heuristik = 2855, Temperatur = 39.3127, Probabilitas = 1.0000
# Iterasi 324: Skor Heuristik = 2855, Temperatur = 38.9196, Probabilitas = 0.2629
# Iterasi 325: Skor Heuristik = 2849, Temperatur = 38.5304, Probabilitas = 1.0000
# Iterasi 326: Skor Heuristik = 2855, Temperatur = 38.1451, Probabilitas = 0.8545
# Iterasi 327: Skor Heuristik = 2855, Temperatur = 37.7636, Probabilitas = 0.0375
# Iterasi 328: Skor Heuristik = 2855, Temperatur = 37.3860, Probabilitas = 0.0689
# Iterasi 329: Skor Heuristik = 2900, Temperatur = 37.0121, Probabilitas = 0.2965
# Iterasi 330: Skor Heuristik = 2900, Temperatur = 36.6420, Probabilitas = 0.0728
# Iterasi 331: Skor Heuristik = 2832, Temperatur = 36.2756, Probabilitas = 1.0000
# Iterasi 332: Skor Heuristik = 2829, Temperatur = 35.9128, Probabilitas = 1.0000
# Iterasi 333: Skor Heuristik = 2844, Temperatur = 35.5537, Probabilitas = 0.6558
# Iterasi 334: Skor Heuristik = 2844, Temperatur = 35.1981, Probabilitas = 0.9183
# Iterasi 335: Skor Heuristik = 2860, Temperatur = 34.8462, Probabilitas = 0.6318
# Iterasi 336: Skor Heuristik = 2868, Temperatur = 34.4977, Probabilitas = 0.7930
# Iterasi 337: Skor Heuristik = 2868, Temperatur = 34.1527, Probabilitas = 0.1366
# Iterasi 338: Skor Heuristik = 2914, Temperatur = 33.8112, Probabilitas = 0.2565
# Iterasi 339: Skor Heuristik = 2914, Temperatur = 33.4731, Probabilitas = 1.0000
# Iterasi 340: Skor Heuristik = 2910, Temperatur = 33.1384, Probabilitas = 1.0000
# Iterasi 341: Skor Heuristik = 2910, Temperatur = 32.8070, Probabilitas = 1.0000
# Iterasi 342: Skor Heuristik = 2910, Temperatur = 32.4789, Probabilitas = 0.5571
# Iterasi 343: Skor Heuristik = 2920, Temperatur = 32.1541, Probabilitas = 0.7327
# Iterasi 344: Skor Heuristik = 2920, Temperatur = 31.8326, Probabilitas = 0.0090
# Iterasi 345: Skor Heuristik = 2950, Temperatur = 31.5142, Probabilitas = 0.3860
# Iterasi 346: Skor Heuristik = 2996, Temperatur = 31.1991, Probabilitas = 0.2289
# Iterasi 347: Skor Heuristik = 2997, Temperatur = 30.8871, Probabilitas = 0.9681
# Iterasi 348: Skor Heuristik = 2997, Temperatur = 30.5782, Probabilitas = 0.0117
# Iterasi 349: Skor Heuristik = 2997, Temperatur = 30.2725, Probabilitas = 0.0014
# Iterasi 350: Skor Heuristik = 2997, Temperatur = 29.9697, Probabilitas = 0.1886
# Iterasi 351: Skor Heuristik = 2997, Temperatur = 29.6700, Probabilitas = 0.0344
# Iterasi 352: Skor Heuristik = 2899, Temperatur = 29.3733, Probabilitas = 1.0000
# Iterasi 353: Skor Heuristik = 2896, Temperatur = 29.0796, Probabilitas = 1.0000
# Iterasi 354: Skor Heuristik = 2896, Temperatur = 28.7888, Probabilitas = 0.0191
# Iterasi 355: Skor Heuristik = 2896, Temperatur = 28.5009, Probabilitas = 0.0097
# Iterasi 356: Skor Heuristik = 2896, Temperatur = 28.2159, Probabilitas = 0.0043
# Iterasi 357: Skor Heuristik = 2896, Temperatur = 27.9338, Probabilitas = 0.2475
# Iterasi 358: Skor Heuristik = 2938, Temperatur = 27.6544, Probabilitas = 0.2190
# Iterasi 359: Skor Heuristik = 2938, Temperatur = 27.3779, Probabilitas = 0.0013
# Iterasi 360: Skor Heuristik = 2894, Temperatur = 27.1041, Probabilitas = 1.0000
# Iterasi 361: Skor Heuristik = 2894, Temperatur = 26.8331, Probabilitas = 0.2816
# Iterasi 362: Skor Heuristik = 2894, Temperatur = 26.5647, Probabilitas = 0.0933
# Iterasi 363: Skor Heuristik = 2874, Temperatur = 26.2991, Probabilitas = 1.0000
# Iterasi 364: Skor Heuristik = 2874, Temperatur = 26.0361, Probabilitas = 0.0001
# Iterasi 365: Skor Heuristik = 2874, Temperatur = 25.7757, Probabilitas = 0.0261
# Iterasi 366: Skor Heuristik = 2874, Temperatur = 25.5180, Probabilitas = 0.2256
# Iterasi 367: Skor Heuristik = 2874, Temperatur = 25.2628, Probabilitas = 0.0651
# Iterasi 368: Skor Heuristik = 2858, Temperatur = 25.0102, Probabilitas = 1.0000
# Iterasi 369: Skor Heuristik = 2858, Temperatur = 24.7601, Probabilitas = 0.2533
# Iterasi 370: Skor Heuristik = 2858, Temperatur = 24.5125, Probabilitas = 0.0489
# Iterasi 371: Skor Heuristik = 2858, Temperatur = 24.2673, Probabilitas = 1.0000
# Iterasi 372: Skor Heuristik = 2858, Temperatur = 24.0247, Probabilitas = 0.1537
# Iterasi 373: Skor Heuristik = 2858, Temperatur = 23.7844, Probabilitas = 0.0006
# Iterasi 374: Skor Heuristik = 2808, Temperatur = 23.5466, Probabilitas = 1.0000
# Iterasi 375: Skor Heuristik = 2688, Temperatur = 23.3111, Probabilitas = 1.0000
# Iterasi 376: Skor Heuristik = 2688, Temperatur = 23.0780, Probabilitas = 0.0388
# Iterasi 377: Skor Heuristik = 2698, Temperatur = 22.8472, Probabilitas = 0.6455
# Iterasi 378: Skor Heuristik = 2698, Temperatur = 22.6187, Probabilitas = 0.5385
# Iterasi 379: Skor Heuristik = 2530, Temperatur = 22.3926, Probabilitas = 1.0000
# Iterasi 380: Skor Heuristik = 2530, Temperatur = 22.1686, Probabilitas = 0.0610
# Iterasi 381: Skor Heuristik = 2499, Temperatur = 21.9469, Probabilitas = 1.0000
# Iterasi 382: Skor Heuristik = 2499, Temperatur = 21.7275, Probabilitas = 0.0332
# Iterasi 383: Skor Heuristik = 2499, Temperatur = 21.5102, Probabilitas = 0.0000
# Iterasi 384: Skor Heuristik = 2499, Temperatur = 21.2951, Probabilitas = 0.0340
# Iterasi 385: Skor Heuristik = 2499, Temperatur = 21.0821, Probabilitas = 0.0002
# Iterasi 386: Skor Heuristik = 2499, Temperatur = 20.8713, Probabilitas = 0.0000
# Iterasi 387: Skor Heuristik = 2499, Temperatur = 20.6626, Probabilitas = 0.0665
# Iterasi 388: Skor Heuristik = 2499, Temperatur = 20.4560, Probabilitas = 1.0000
# Iterasi 389: Skor Heuristik = 2499, Temperatur = 20.2514, Probabilitas = 0.0000
# Iterasi 390: Skor Heuristik = 2501, Temperatur = 20.0489, Probabilitas = 0.9051
# Iterasi 391: Skor Heuristik = 2501, Temperatur = 19.8484, Probabilitas = 0.7028
# Iterasi 392: Skor Heuristik = 2501, Temperatur = 19.6499, Probabilitas = 0.0000
# Iterasi 393: Skor Heuristik = 2501, Temperatur = 19.4534, Probabilitas = 0.0000
# Iterasi 394: Skor Heuristik = 2501, Temperatur = 19.2589, Probabilitas = 0.2106
# Iterasi 395: Skor Heuristik = 2501, Temperatur = 19.0663, Probabilitas = 0.0000
# Iterasi 396: Skor Heuristik = 2461, Temperatur = 18.8756, Probabilitas = 1.0000
# Iterasi 397: Skor Heuristik = 2459, Temperatur = 18.6869, Probabilitas = 1.0000
# Iterasi 398: Skor Heuristik = 2411, Temperatur = 18.5000, Probabilitas = 1.0000
# Iterasi 399: Skor Heuristik = 2411, Temperatur = 18.3150, Probabilitas = 0.8966
# Iterasi 400: Skor Heuristik = 2411, Temperatur = 18.1319, Probabilitas = 0.0128
# Iterasi 401: Skor Heuristik = 2411, Temperatur = 17.9506, Probabilitas = 0.0003
# Iterasi 402: Skor Heuristik = 2421, Temperatur = 17.7710, Probabilitas = 0.5697
# Iterasi 403: Skor Heuristik = 2421, Temperatur = 17.5933, Probabilitas = 0.0000
# Iterasi 404: Skor Heuristik = 2421, Temperatur = 17.4174, Probabilitas = 0.0000
# Iterasi 405: Skor Heuristik = 2421, Temperatur = 17.2432, Probabilitas = 0.5284
# Iterasi 406: Skor Heuristik = 2421, Temperatur = 17.0708, Probabilitas = 0.3484
# Iterasi 407: Skor Heuristik = 2421, Temperatur = 16.9001, Probabilitas = 0.0323
# Iterasi 408: Skor Heuristik = 2421, Temperatur = 16.7311, Probabilitas = 0.2114
# Iterasi 409: Skor Heuristik = 2421, Temperatur = 16.5638, Probabilitas = 0.0000
# Iterasi 410: Skor Heuristik = 2405, Temperatur = 16.3981, Probabilitas = 1.0000
# Iterasi 411: Skor Heuristik = 2405, Temperatur = 16.2342, Probabilitas = 0.0000
# Iterasi 412: Skor Heuristik = 2405, Temperatur = 16.0718, Probabilitas = 0.0000
# Iterasi 413: Skor Heuristik = 2405, Temperatur = 15.9111, Probabilitas = 0.2509
# Iterasi 414: Skor Heuristik = 2263, Temperatur = 15.7520, Probabilitas = 1.0000
# Iterasi 415: Skor Heuristik = 2211, Temperatur = 15.5945, Probabilitas = 1.0000
# Iterasi 416: Skor Heuristik = 2211, Temperatur = 15.4385, Probabilitas = 0.0010
# Iterasi 417: Skor Heuristik = 2211, Temperatur = 15.2841, Probabilitas = 0.0001
# Iterasi 418: Skor Heuristik = 2151, Temperatur = 15.1313, Probabilitas = 1.0000
# Iterasi 419: Skor Heuristik = 2151, Temperatur = 14.9800, Probabilitas = 0.1350
# Iterasi 420: Skor Heuristik = 2129, Temperatur = 14.8302, Probabilitas = 1.0000
# Iterasi 421: Skor Heuristik = 2122, Temperatur = 14.6819, Probabilitas = 1.0000
# Iterasi 422: Skor Heuristik = 2122, Temperatur = 14.5351, Probabilitas = 0.0000
# Iterasi 423: Skor Heuristik = 2122, Temperatur = 14.3897, Probabilitas = 0.0072
# Iterasi 424: Skor Heuristik = 2122, Temperatur = 14.2458, Probabilitas = 0.0034
# Iterasi 425: Skor Heuristik = 2122, Temperatur = 14.1034, Probabilitas = 0.0000
# Iterasi 426: Skor Heuristik = 2122, Temperatur = 13.9623, Probabilitas = 0.0066
# Iterasi 427: Skor Heuristik = 2128, Temperatur = 13.8227, Probabilitas = 0.6479
# Iterasi 428: Skor Heuristik = 2128, Temperatur = 13.6845, Probabilitas = 0.0000
# Iterasi 429: Skor Heuristik = 2128, Temperatur = 13.5476, Probabilitas = 0.0003
# Iterasi 430: Skor Heuristik = 2128, Temperatur = 13.4122, Probabilitas = 0.1671
# Iterasi 431: Skor Heuristik = 2128, Temperatur = 13.2780, Probabilitas = 0.0898
# Iterasi 432: Skor Heuristik = 2128, Temperatur = 13.1453, Probabilitas = 1.0000
# Iterasi 433: Skor Heuristik = 2128, Temperatur = 13.0138, Probabilitas = 0.0000
# Iterasi 434: Skor Heuristik = 2128, Temperatur = 12.8837, Probabilitas = 0.0000
# Iterasi 435: Skor Heuristik = 2128, Temperatur = 12.7548, Probabilitas = 0.1302
# Iterasi 436: Skor Heuristik = 2128, Temperatur = 12.6273, Probabilitas = 0.0191
# Iterasi 437: Skor Heuristik = 2128, Temperatur = 12.5010, Probabilitas = 0.0273
# Iterasi 438: Skor Heuristik = 2128, Temperatur = 12.3760, Probabilitas = 0.0001
# Iterasi 439: Skor Heuristik = 2138, Temperatur = 12.2522, Probabilitas = 0.4421
# Iterasi 440: Skor Heuristik = 2138, Temperatur = 12.1297, Probabilitas = 0.0000
# Iterasi 441: Skor Heuristik = 2138, Temperatur = 12.0084, Probabilitas = 0.4349
# Iterasi 442: Skor Heuristik = 2138, Temperatur = 11.8883, Probabilitas = 0.0126
# Iterasi 443: Skor Heuristik = 2102, Temperatur = 11.7694, Probabilitas = 1.0000
# Iterasi 444: Skor Heuristik = 2102, Temperatur = 11.6518, Probabilitas = 1.0000
# Iterasi 445: Skor Heuristik = 2102, Temperatur = 11.5352, Probabilitas = 0.0000
# Iterasi 446: Skor Heuristik = 2104, Temperatur = 11.4199, Probabilitas = 0.8393
# Iterasi 447: Skor Heuristik = 2104, Temperatur = 11.3057, Probabilitas = 0.0000
# Iterasi 448: Skor Heuristik = 2104, Temperatur = 11.1926, Probabilitas = 0.0000
# Iterasi 449: Skor Heuristik = 2104, Temperatur = 11.0807, Probabilitas = 0.0271
# Iterasi 450: Skor Heuristik = 2104, Temperatur = 10.9699, Probabilitas = 0.0000
# Iterasi 451: Skor Heuristik = 2104, Temperatur = 10.8602, Probabilitas = 0.0000
# Iterasi 452: Skor Heuristik = 2104, Temperatur = 10.7516, Probabilitas = 0.0066
# Iterasi 453: Skor Heuristik = 2104, Temperatur = 10.6441, Probabilitas = 0.0000
# Iterasi 454: Skor Heuristik = 2102, Temperatur = 10.5376, Probabilitas = 1.0000
# Iterasi 455: Skor Heuristik = 2102, Temperatur = 10.4323, Probabilitas = 0.0000
# Iterasi 456: Skor Heuristik = 2102, Temperatur = 10.3279, Probabilitas = 0.0000
# Iterasi 457: Skor Heuristik = 2122, Temperatur = 10.2247, Probabilitas = 0.1414
# Iterasi 458: Skor Heuristik = 2122, Temperatur = 10.1224, Probabilitas = 0.0007
# Iterasi 459: Skor Heuristik = 2122, Temperatur = 10.0212, Probabilitas = 0.0000
# Iterasi 460: Skor Heuristik = 2102, Temperatur = 9.9210, Probabilitas = 1.0000
# Iterasi 461: Skor Heuristik = 2108, Temperatur = 9.8218, Probabilitas = 0.5429
# Iterasi 462: Skor Heuristik = 2108, Temperatur = 9.7235, Probabilitas = 0.0000
# Iterasi 463: Skor Heuristik = 2108, Temperatur = 9.6263, Probabilitas = 0.0157
# Iterasi 464: Skor Heuristik = 2108, Temperatur = 9.5300, Probabilitas = 0.0000
# Iterasi 465: Skor Heuristik = 2108, Temperatur = 9.4347, Probabilitas = 0.0000
# Iterasi 466: Skor Heuristik = 2108, Temperatur = 9.3404, Probabilitas = 1.0000
# Iterasi 467: Skor Heuristik = 2108, Temperatur = 9.2470, Probabilitas = 0.0001
# Iterasi 468: Skor Heuristik = 2108, Temperatur = 9.1545, Probabilitas = 0.1255
# Iterasi 469: Skor Heuristik = 2108, Temperatur = 9.0630, Probabilitas = 0.0000
# Iterasi 470: Skor Heuristik = 2108, Temperatur = 8.9724, Probabilitas = 0.0000
# Iterasi 471: Skor Heuristik = 2108, Temperatur = 8.8826, Probabilitas = 0.0002
# Iterasi 472: Skor Heuristik = 2108, Temperatur = 8.7938, Probabilitas = 0.0000
# Iterasi 473: Skor Heuristik = 2130, Temperatur = 8.7059, Probabilitas = 0.0799
# Iterasi 474: Skor Heuristik = 2126, Temperatur = 8.6188, Probabilitas = 1.0000
# Iterasi 475: Skor Heuristik = 2071, Temperatur = 8.5326, Probabilitas = 1.0000
# Iterasi 476: Skor Heuristik = 2071, Temperatur = 8.4473, Probabilitas = 0.0000
# Iterasi 477: Skor Heuristik = 2071, Temperatur = 8.3628, Probabilitas = 0.0000
# Iterasi 478: Skor Heuristik = 2071, Temperatur = 8.2792, Probabilitas = 0.0012
# Iterasi 479: Skor Heuristik = 2071, Temperatur = 8.1964, Probabilitas = 0.0025
# Iterasi 480: Skor Heuristik = 2071, Temperatur = 8.1144, Probabilitas = 0.0219
# Iterasi 481: Skor Heuristik = 2071, Temperatur = 8.0333, Probabilitas = 0.0000
# Iterasi 482: Skor Heuristik = 2071, Temperatur = 7.9530, Probabilitas = 0.0000
# Iterasi 483: Skor Heuristik = 2071, Temperatur = 7.8734, Probabilitas = 0.0000
# Iterasi 484: Skor Heuristik = 2037, Temperatur = 7.7947, Probabilitas = 1.0000
# Iterasi 485: Skor Heuristik = 2030, Temperatur = 7.7167, Probabilitas = 1.0000
# Iterasi 486: Skor Heuristik = 2030, Temperatur = 7.6396, Probabilitas = 0.3509
# Iterasi 487: Skor Heuristik = 2030, Temperatur = 7.5632, Probabilitas = 0.0000
# Iterasi 488: Skor Heuristik = 2030, Temperatur = 7.4876, Probabilitas = 0.0000
# Iterasi 489: Skor Heuristik = 2018, Temperatur = 7.4127, Probabilitas = 1.0000
# Iterasi 490: Skor Heuristik = 2018, Temperatur = 7.3385, Probabilitas = 0.0019
# Iterasi 491: Skor Heuristik = 2019, Temperatur = 7.2652, Probabilitas = 0.8714
# Iterasi 492: Skor Heuristik = 2019, Temperatur = 7.1925, Probabilitas = 0.0001
# Iterasi 493: Skor Heuristik = 2019, Temperatur = 7.1206, Probabilitas = 0.0012
# Iterasi 494: Skor Heuristik = 2019, Temperatur = 7.0494, Probabilitas = 0.0000
# Iterasi 495: Skor Heuristik = 2019, Temperatur = 6.9789, Probabilitas = 0.0000
# Iterasi 496: Skor Heuristik = 1997, Temperatur = 6.9091, Probabilitas = 1.0000
# Iterasi 497: Skor Heuristik = 1994, Temperatur = 6.8400, Probabilitas = 1.0000
# Iterasi 498: Skor Heuristik = 1978, Temperatur = 6.7716, Probabilitas = 1.0000
# Iterasi 499: Skor Heuristik = 1958, Temperatur = 6.7039, Probabilitas = 1.0000
# Iterasi 500: Skor Heuristik = 1941, Temperatur = 6.6369, Probabilitas = 1.0000
# Iterasi 501: Skor Heuristik = 1941, Temperatur = 6.5705, Probabilitas = 0.0000
# Iterasi 502: Skor Heuristik = 1941, Temperatur = 6.5048, Probabilitas = 0.0000
# Iterasi 503: Skor Heuristik = 1941, Temperatur = 6.4397, Probabilitas = 0.0004
# Iterasi 504: Skor Heuristik = 1941, Temperatur = 6.3753, Probabilitas = 0.0014
# Iterasi 505: Skor Heuristik = 1941, Temperatur = 6.3116, Probabilitas = 0.7284
# Iterasi 506: Skor Heuristik = 1941, Temperatur = 6.2485, Probabilitas = 0.0001
# Iterasi 507: Skor Heuristik = 1872, Temperatur = 6.1860, Probabilitas = 1.0000
# Iterasi 508: Skor Heuristik = 1872, Temperatur = 6.1241, Probabilitas = 0.0000
# Iterasi 509: Skor Heuristik = 1872, Temperatur = 6.0629, Probabilitas = 0.0000
# Iterasi 510: Skor Heuristik = 1872, Temperatur = 6.0022, Probabilitas = 0.0000
# Iterasi 511: Skor Heuristik = 1872, Temperatur = 5.9422, Probabilitas = 0.0000
# Iterasi 512: Skor Heuristik = 1872, Temperatur = 5.8828, Probabilitas = 0.0003
# Iterasi 513: Skor Heuristik = 1872, Temperatur = 5.8240, Probabilitas = 0.0000
# Iterasi 514: Skor Heuristik = 1878, Temperatur = 5.7657, Probabilitas = 0.3532
# Iterasi 515: Skor Heuristik = 1878, Temperatur = 5.7081, Probabilitas = 0.0000
# Iterasi 516: Skor Heuristik = 1878, Temperatur = 5.6510, Probabilitas = 0.0414
# Iterasi 517: Skor Heuristik = 1878, Temperatur = 5.5945, Probabilitas = 0.0000
# Iterasi 518: Skor Heuristik = 1878, Temperatur = 5.5385, Probabilitas = 0.0556
# Iterasi 519: Skor Heuristik = 1881, Temperatur = 5.4832, Probabilitas = 0.5786
# Iterasi 520: Skor Heuristik = 1881, Temperatur = 5.4283, Probabilitas = 0.0000
# Iterasi 521: Skor Heuristik = 1881, Temperatur = 5.3740, Probabilitas = 0.0000
# Iterasi 522: Skor Heuristik = 1881, Temperatur = 5.3203, Probabilitas = 0.0000
# Iterasi 523: Skor Heuristik = 1856, Temperatur = 5.2671, Probabilitas = 1.0000
# Iterasi 524: Skor Heuristik = 1856, Temperatur = 5.2144, Probabilitas = 0.0000
# Iterasi 525: Skor Heuristik = 1856, Temperatur = 5.1623, Probabilitas = 0.0000
# Iterasi 526: Skor Heuristik = 1856, Temperatur = 5.1107, Probabilitas = 0.3091
# Iterasi 527: Skor Heuristik = 1856, Temperatur = 5.0596, Probabilitas = 0.0000
# Iterasi 528: Skor Heuristik = 1832, Temperatur = 5.0090, Probabilitas = 1.0000
# Iterasi 529: Skor Heuristik = 1832, Temperatur = 4.9589, Probabilitas = 0.0000
# Iterasi 530: Skor Heuristik = 1832, Temperatur = 4.9093, Probabilitas = 0.0000
# Iterasi 531: Skor Heuristik = 1832, Temperatur = 4.8602, Probabilitas = 0.0000
# Iterasi 532: Skor Heuristik = 1832, Temperatur = 4.8116, Probabilitas = 0.0000
# Iterasi 533: Skor Heuristik = 1832, Temperatur = 4.7635, Probabilitas = 0.0000
# Iterasi 534: Skor Heuristik = 1828, Temperatur = 4.7158, Probabilitas = 1.0000
# Iterasi 535: Skor Heuristik = 1828, Temperatur = 4.6687, Probabilitas = 0.0000
# Iterasi 536: Skor Heuristik = 1838, Temperatur = 4.6220, Probabilitas = 0.1149
# Iterasi 537: Skor Heuristik = 1808, Temperatur = 4.5758, Probabilitas = 1.0000
# Iterasi 538: Skor Heuristik = 1808, Temperatur = 4.5300, Probabilitas = 0.0882
# Iterasi 539: Skor Heuristik = 1808, Temperatur = 4.4847, Probabilitas = 0.0441
# Iterasi 540: Skor Heuristik = 1808, Temperatur = 4.4399, Probabilitas = 0.0000
# Iterasi 541: Skor Heuristik = 1808, Temperatur = 4.3955, Probabilitas = 0.0000
# Iterasi 542: Skor Heuristik = 1808, Temperatur = 4.3515, Probabilitas = 0.0000
# Iterasi 543: Skor Heuristik = 1790, Temperatur = 4.3080, Probabilitas = 1.0000
# Iterasi 544: Skor Heuristik = 1790, Temperatur = 4.2649, Probabilitas = 0.3096
# Iterasi 545: Skor Heuristik = 1790, Temperatur = 4.2223, Probabilitas = 0.0000
# Iterasi 546: Skor Heuristik = 1790, Temperatur = 4.1800, Probabilitas = 0.0000
# Iterasi 547: Skor Heuristik = 1790, Temperatur = 4.1382, Probabilitas = 0.0000
# Iterasi 548: Skor Heuristik = 1790, Temperatur = 4.0969, Probabilitas = 0.0000
# Iterasi 549: Skor Heuristik = 1790, Temperatur = 4.0559, Probabilitas = 0.0004
# Iterasi 550: Skor Heuristik = 1790, Temperatur = 4.0153, Probabilitas = 0.0000
# Iterasi 551: Skor Heuristik = 1790, Temperatur = 3.9752, Probabilitas = 0.0051
# Iterasi 552: Skor Heuristik = 1790, Temperatur = 3.9354, Probabilitas = 0.0000
# Iterasi 553: Skor Heuristik = 1790, Temperatur = 3.8961, Probabilitas = 0.0000
# Iterasi 554: Skor Heuristik = 1781, Temperatur = 3.8571, Probabilitas = 1.0000
# Iterasi 555: Skor Heuristik = 1778, Temperatur = 3.8185, Probabilitas = 1.0000
# Iterasi 556: Skor Heuristik = 1765, Temperatur = 3.7804, Probabilitas = 1.0000
# Iterasi 557: Skor Heuristik = 1765, Temperatur = 3.7426, Probabilitas = 0.0000
# Iterasi 558: Skor Heuristik = 1765, Temperatur = 3.7051, Probabilitas = 0.0000
# Iterasi 559: Skor Heuristik = 1765, Temperatur = 3.6681, Probabilitas = 1.0000
# Iterasi 560: Skor Heuristik = 1765, Temperatur = 3.6314, Probabilitas = 0.0000
# Iterasi 561: Skor Heuristik = 1765, Temperatur = 3.5951, Probabilitas = 0.0000
# Iterasi 562: Skor Heuristik = 1667, Temperatur = 3.5591, Probabilitas = 1.0000
# Iterasi 563: Skor Heuristik = 1551, Temperatur = 3.5235, Probabilitas = 1.0000
# Iterasi 564: Skor Heuristik = 1551, Temperatur = 3.4883, Probabilitas = 1.0000
# Iterasi 565: Skor Heuristik = 1549, Temperatur = 3.4534, Probabilitas = 1.0000
# Iterasi 566: Skor Heuristik = 1549, Temperatur = 3.4189, Probabilitas = 0.0000
# Iterasi 567: Skor Heuristik = 1549, Temperatur = 3.3847, Probabilitas = 0.0000
# Iterasi 568: Skor Heuristik = 1549, Temperatur = 3.3509, Probabilitas = 0.0000
# Iterasi 569: Skor Heuristik = 1549, Temperatur = 3.3173, Probabilitas = 0.0000
# Iterasi 570: Skor Heuristik = 1511, Temperatur = 3.2842, Probabilitas = 1.0000
# Iterasi 571: Skor Heuristik = 1511, Temperatur = 3.2513, Probabilitas = 0.0135
# Iterasi 572: Skor Heuristik = 1497, Temperatur = 3.2188, Probabilitas = 1.0000
# Iterasi 573: Skor Heuristik = 1497, Temperatur = 3.1866, Probabilitas = 0.0000
# Iterasi 574: Skor Heuristik = 1497, Temperatur = 3.1548, Probabilitas = 0.0000
# Iterasi 575: Skor Heuristik = 1497, Temperatur = 3.1232, Probabilitas = 0.0000
# Iterasi 576: Skor Heuristik = 1497, Temperatur = 3.0920, Probabilitas = 0.0000
# Iterasi 577: Skor Heuristik = 1441, Temperatur = 3.0611, Probabilitas = 1.0000
# Iterasi 578: Skor Heuristik = 1441, Temperatur = 3.0305, Probabilitas = 0.0000
# Iterasi 579: Skor Heuristik = 1441, Temperatur = 3.0001, Probabilitas = 0.0025
# Iterasi 580: Skor Heuristik = 1441, Temperatur = 2.9701, Probabilitas = 0.0000
# Iterasi 581: Skor Heuristik = 1439, Temperatur = 2.9404, Probabilitas = 1.0000
# Iterasi 582: Skor Heuristik = 1439, Temperatur = 2.9110, Probabilitas = 0.0000
# Iterasi 583: Skor Heuristik = 1439, Temperatur = 2.8819, Probabilitas = 0.0010
# Iterasi 584: Skor Heuristik = 1439, Temperatur = 2.8531, Probabilitas = 0.0427
# Iterasi 585: Skor Heuristik = 1439, Temperatur = 2.8246, Probabilitas = 0.0004
# Iterasi 586: Skor Heuristik = 1439, Temperatur = 2.7963, Probabilitas = 0.0000
# Iterasi 587: Skor Heuristik = 1439, Temperatur = 2.7684, Probabilitas = 0.0000
# Iterasi 588: Skor Heuristik = 1439, Temperatur = 2.7407, Probabilitas = 0.0000
# Iterasi 589: Skor Heuristik = 1439, Temperatur = 2.7133, Probabilitas = 1.0000
# Iterasi 590: Skor Heuristik = 1439, Temperatur = 2.6861, Probabilitas = 0.0000
# Iterasi 591: Skor Heuristik = 1441, Temperatur = 2.6593, Probabilitas = 0.4714
# Iterasi 592: Skor Heuristik = 1441, Temperatur = 2.6327, Probabilitas = 0.0000
# Iterasi 593: Skor Heuristik = 1441, Temperatur = 2.6064, Probabilitas = 0.0000
# Iterasi 594: Skor Heuristik = 1441, Temperatur = 2.5803, Probabilitas = 0.0014
# Iterasi 595: Skor Heuristik = 1441, Temperatur = 2.5545, Probabilitas = 0.0000
# Iterasi 596: Skor Heuristik = 1441, Temperatur = 2.5290, Probabilitas = 0.0000
# Iterasi 597: Skor Heuristik = 1443, Temperatur = 2.5037, Probabilitas = 0.4499
# Iterasi 598: Skor Heuristik = 1435, Temperatur = 2.4786, Probabilitas = 1.0000
# Iterasi 599: Skor Heuristik = 1435, Temperatur = 2.4538, Probabilitas = 0.0000
# Iterasi 600: Skor Heuristik = 1435, Temperatur = 2.4293, Probabilitas = 0.0000
# ...
# Stuck di local optima pada iterasi 1218 dengan skor 974
# Iterasi 1218: Skor Heuristik = 974, Temperatur = 0.0049, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1219 dengan skor 974
# Iterasi 1219: Skor Heuristik = 974, Temperatur = 0.0048, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1220 dengan skor 974
# Iterasi 1220: Skor Heuristik = 974, Temperatur = 0.0048, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1221 dengan skor 974
# Iterasi 1221: Skor Heuristik = 974, Temperatur = 0.0047, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1222 dengan skor 974
# Iterasi 1222: Skor Heuristik = 974, Temperatur = 0.0047, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1223 dengan skor 974
# Iterasi 1223: Skor Heuristik = 974, Temperatur = 0.0046, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1224 dengan skor 974
# Iterasi 1224: Skor Heuristik = 974, Temperatur = 0.0046, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1225 dengan skor 974
# Iterasi 1225: Skor Heuristik = 974, Temperatur = 0.0045, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1226 dengan skor 974
# Iterasi 1226: Skor Heuristik = 974, Temperatur = 0.0045, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1227 dengan skor 974
# Iterasi 1227: Skor Heuristik = 974, Temperatur = 0.0045, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1228 dengan skor 974
# Iterasi 1228: Skor Heuristik = 974, Temperatur = 0.0044, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1229 dengan skor 974
# Iterasi 1229: Skor Heuristik = 974, Temperatur = 0.0044, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1230 dengan skor 974
# Iterasi 1230: Skor Heuristik = 974, Temperatur = 0.0043, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1231 dengan skor 974
# Iterasi 1231: Skor Heuristik = 974, Temperatur = 0.0043, Probabilitas = 0.0000
# Iterasi 1232: Skor Heuristik = 950, Temperatur = 0.0042, Probabilitas = 1.0000
# Iterasi 1233: Skor Heuristik = 950, Temperatur = 0.0042, Probabilitas = 0.0000
# Iterasi 1234: Skor Heuristik = 950, Temperatur = 0.0042, Probabilitas = 0.0000
# Iterasi 1235: Skor Heuristik = 950, Temperatur = 0.0041, Probabilitas = 0.0000
# Iterasi 1236: Skor Heuristik = 949, Temperatur = 0.0041, Probabilitas = 1.0000
# Iterasi 1237: Skor Heuristik = 949, Temperatur = 0.0040, Probabilitas = 0.0000
# Iterasi 1238: Skor Heuristik = 949, Temperatur = 0.0040, Probabilitas = 0.0000
# Iterasi 1239: Skor Heuristik = 949, Temperatur = 0.0039, Probabilitas = 0.0000
# Iterasi 1240: Skor Heuristik = 949, Temperatur = 0.0039, Probabilitas = 0.0000
# Iterasi 1241: Skor Heuristik = 949, Temperatur = 0.0039, Probabilitas = 0.0000
# Iterasi 1242: Skor Heuristik = 949, Temperatur = 0.0038, Probabilitas = 0.0000
# Iterasi 1243: Skor Heuristik = 949, Temperatur = 0.0038, Probabilitas = 0.0000
# Iterasi 1244: Skor Heuristik = 949, Temperatur = 0.0038, Probabilitas = 0.0000
# Iterasi 1245: Skor Heuristik = 948, Temperatur = 0.0037, Probabilitas = 1.0000
# Iterasi 1246: Skor Heuristik = 948, Temperatur = 0.0037, Probabilitas = 0.0000
# Iterasi 1247: Skor Heuristik = 948, Temperatur = 0.0036, Probabilitas = 0.0000
# Iterasi 1248: Skor Heuristik = 948, Temperatur = 0.0036, Probabilitas = 0.0000
# Iterasi 1249: Skor Heuristik = 948, Temperatur = 0.0036, Probabilitas = 0.0000
# Iterasi 1250: Skor Heuristik = 948, Temperatur = 0.0035, Probabilitas = 0.0000
# Iterasi 1251: Skor Heuristik = 948, Temperatur = 0.0035, Probabilitas = 0.0000
# Iterasi 1252: Skor Heuristik = 948, Temperatur = 0.0035, Probabilitas = 0.0000
# Iterasi 1253: Skor Heuristik = 948, Temperatur = 0.0034, Probabilitas = 0.0000
# Iterasi 1254: Skor Heuristik = 948, Temperatur = 0.0034, Probabilitas = 0.0000
# Iterasi 1255: Skor Heuristik = 948, Temperatur = 0.0034, Probabilitas = 0.0000
# Iterasi 1256: Skor Heuristik = 948, Temperatur = 0.0033, Probabilitas = 0.0000
# Iterasi 1257: Skor Heuristik = 948, Temperatur = 0.0033, Probabilitas = 0.0000
# Iterasi 1258: Skor Heuristik = 948, Temperatur = 0.0033, Probabilitas = 0.0000
# Iterasi 1259: Skor Heuristik = 948, Temperatur = 0.0032, Probabilitas = 0.0000
# Iterasi 1260: Skor Heuristik = 948, Temperatur = 0.0032, Probabilitas = 0.0000
# Iterasi 1261: Skor Heuristik = 948, Temperatur = 0.0032, Probabilitas = 0.0000
# Iterasi 1262: Skor Heuristik = 948, Temperatur = 0.0031, Probabilitas = 0.0000
# Iterasi 1263: Skor Heuristik = 948, Temperatur = 0.0031, Probabilitas = 0.0000
# Iterasi 1264: Skor Heuristik = 948, Temperatur = 0.0031, Probabilitas = 0.0000
# Iterasi 1265: Skor Heuristik = 948, Temperatur = 0.0030, Probabilitas = 0.0000
# Iterasi 1266: Skor Heuristik = 948, Temperatur = 0.0030, Probabilitas = 0.0000
# Iterasi 1267: Skor Heuristik = 948, Temperatur = 0.0030, Probabilitas = 0.0000
# Iterasi 1268: Skor Heuristik = 948, Temperatur = 0.0029, Probabilitas = 0.0000
# Iterasi 1269: Skor Heuristik = 948, Temperatur = 0.0029, Probabilitas = 0.0000
# Iterasi 1270: Skor Heuristik = 948, Temperatur = 0.0029, Probabilitas = 0.0000
# Iterasi 1271: Skor Heuristik = 948, Temperatur = 0.0029, Probabilitas = 0.0000
# Iterasi 1272: Skor Heuristik = 948, Temperatur = 0.0028, Probabilitas = 0.0000
# Iterasi 1273: Skor Heuristik = 948, Temperatur = 0.0028, Probabilitas = 0.0000
# Iterasi 1274: Skor Heuristik = 948, Temperatur = 0.0028, Probabilitas = 0.0000
# Iterasi 1275: Skor Heuristik = 948, Temperatur = 0.0027, Probabilitas = 0.0000
# Iterasi 1276: Skor Heuristik = 948, Temperatur = 0.0027, Probabilitas = 0.0000
# Iterasi 1277: Skor Heuristik = 948, Temperatur = 0.0027, Probabilitas = 0.0000
# Iterasi 1278: Skor Heuristik = 948, Temperatur = 0.0027, Probabilitas = 0.0000
# Iterasi 1279: Skor Heuristik = 948, Temperatur = 0.0026, Probabilitas = 0.0000
# Iterasi 1280: Skor Heuristik = 948, Temperatur = 0.0026, Probabilitas = 0.0000
# Iterasi 1281: Skor Heuristik = 948, Temperatur = 0.0026, Probabilitas = 0.0000
# Iterasi 1282: Skor Heuristik = 948, Temperatur = 0.0026, Probabilitas = 0.0000
# Iterasi 1283: Skor Heuristik = 948, Temperatur = 0.0025, Probabilitas = 0.0000
# Iterasi 1284: Skor Heuristik = 948, Temperatur = 0.0025, Probabilitas = 0.0000
# Iterasi 1285: Skor Heuristik = 948, Temperatur = 0.0025, Probabilitas = 0.0000
# Iterasi 1286: Skor Heuristik = 948, Temperatur = 0.0025, Probabilitas = 0.0000
# Iterasi 1287: Skor Heuristik = 948, Temperatur = 0.0024, Probabilitas = 0.0000
# Iterasi 1288: Skor Heuristik = 948, Temperatur = 0.0024, Probabilitas = 0.0000
# Iterasi 1289: Skor Heuristik = 948, Temperatur = 0.0024, Probabilitas = 0.0000
# Iterasi 1290: Skor Heuristik = 948, Temperatur = 0.0024, Probabilitas = 0.0000
# Iterasi 1291: Skor Heuristik = 948, Temperatur = 0.0023, Probabilitas = 0.0000
# Iterasi 1292: Skor Heuristik = 948, Temperatur = 0.0023, Probabilitas = 0.0000
# Iterasi 1293: Skor Heuristik = 948, Temperatur = 0.0023, Probabilitas = 0.0000
# Iterasi 1294: Skor Heuristik = 948, Temperatur = 0.0023, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1295 dengan skor 948
# Iterasi 1295: Skor Heuristik = 948, Temperatur = 0.0022, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1296 dengan skor 948
# Iterasi 1296: Skor Heuristik = 948, Temperatur = 0.0022, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1297 dengan skor 948
# Iterasi 1297: Skor Heuristik = 948, Temperatur = 0.0022, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1298 dengan skor 948
# Iterasi 1298: Skor Heuristik = 948, Temperatur = 0.0022, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1299 dengan skor 948
# Iterasi 1299: Skor Heuristik = 948, Temperatur = 0.0022, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1300 dengan skor 948
# Iterasi 1300: Skor Heuristik = 948, Temperatur = 0.0021, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1301 dengan skor 948
# Iterasi 1301: Skor Heuristik = 948, Temperatur = 0.0021, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1302 dengan skor 948
# Iterasi 1302: Skor Heuristik = 948, Temperatur = 0.0021, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1303 dengan skor 948
# Iterasi 1303: Skor Heuristik = 948, Temperatur = 0.0021, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1304 dengan skor 948
# Iterasi 1304: Skor Heuristik = 948, Temperatur = 0.0021, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1305 dengan skor 948
# Iterasi 1305: Skor Heuristik = 948, Temperatur = 0.0020, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1306 dengan skor 948
# Iterasi 1306: Skor Heuristik = 948, Temperatur = 0.0020, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1307 dengan skor 948
# Iterasi 1307: Skor Heuristik = 948, Temperatur = 0.0020, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1308 dengan skor 948
# Iterasi 1308: Skor Heuristik = 948, Temperatur = 0.0020, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1309 dengan skor 948
# Iterasi 1309: Skor Heuristik = 948, Temperatur = 0.0020, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1310 dengan skor 948
# Iterasi 1310: Skor Heuristik = 948, Temperatur = 0.0019, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1311 dengan skor 948
# Iterasi 1311: Skor Heuristik = 948, Temperatur = 0.0019, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1312 dengan skor 948
# Iterasi 1312: Skor Heuristik = 948, Temperatur = 0.0019, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1313 dengan skor 948
# Iterasi 1313: Skor Heuristik = 948, Temperatur = 0.0019, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1314 dengan skor 948
# Iterasi 1314: Skor Heuristik = 948, Temperatur = 0.0019, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1315 dengan skor 948
# Iterasi 1315: Skor Heuristik = 948, Temperatur = 0.0018, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1316 dengan skor 948
# Iterasi 1316: Skor Heuristik = 948, Temperatur = 0.0018, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1317 dengan skor 948
# Iterasi 1317: Skor Heuristik = 948, Temperatur = 0.0018, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1318 dengan skor 948
# Iterasi 1318: Skor Heuristik = 948, Temperatur = 0.0018, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1319 dengan skor 948
# Iterasi 1319: Skor Heuristik = 948, Temperatur = 0.0018, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1320 dengan skor 948
# Iterasi 1320: Skor Heuristik = 948, Temperatur = 0.0017, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1321 dengan skor 948
# Iterasi 1321: Skor Heuristik = 948, Temperatur = 0.0017, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1322 dengan skor 948
# Iterasi 1322: Skor Heuristik = 948, Temperatur = 0.0017, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1323 dengan skor 948
# Iterasi 1323: Skor Heuristik = 948, Temperatur = 0.0017, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1324 dengan skor 948
# Iterasi 1324: Skor Heuristik = 948, Temperatur = 0.0017, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1325 dengan skor 948
# Iterasi 1325: Skor Heuristik = 948, Temperatur = 0.0017, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1326 dengan skor 948
# Iterasi 1326: Skor Heuristik = 948, Temperatur = 0.0016, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1327 dengan skor 948
# Iterasi 1327: Skor Heuristik = 948, Temperatur = 0.0016, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1328 dengan skor 948
# Iterasi 1328: Skor Heuristik = 948, Temperatur = 0.0016, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1329 dengan skor 948
# Iterasi 1329: Skor Heuristik = 948, Temperatur = 0.0016, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1330 dengan skor 948
# Iterasi 1330: Skor Heuristik = 948, Temperatur = 0.0016, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1331 dengan skor 948
# Iterasi 1331: Skor Heuristik = 948, Temperatur = 0.0016, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1332 dengan skor 948
# Iterasi 1332: Skor Heuristik = 948, Temperatur = 0.0016, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1333 dengan skor 948
# Iterasi 1333: Skor Heuristik = 948, Temperatur = 0.0015, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1334 dengan skor 948
# Iterasi 1334: Skor Heuristik = 948, Temperatur = 0.0015, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1335 dengan skor 948
# Iterasi 1335: Skor Heuristik = 948, Temperatur = 0.0015, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1336 dengan skor 948
# Iterasi 1336: Skor Heuristik = 948, Temperatur = 0.0015, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1337 dengan skor 948
# Iterasi 1337: Skor Heuristik = 948, Temperatur = 0.0015, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1338 dengan skor 948
# Iterasi 1338: Skor Heuristik = 948, Temperatur = 0.0015, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1339 dengan skor 948
# Iterasi 1339: Skor Heuristik = 948, Temperatur = 0.0014, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1340 dengan skor 948
# Iterasi 1340: Skor Heuristik = 948, Temperatur = 0.0014, Probabilitas = 0.0000
# Iterasi 1341: Skor Heuristik = 942, Temperatur = 0.0014, Probabilitas = 1.0000
# Iterasi 1342: Skor Heuristik = 942, Temperatur = 0.0014, Probabilitas = 0.0000
# Iterasi 1343: Skor Heuristik = 942, Temperatur = 0.0014, Probabilitas = 0.0000
# Iterasi 1344: Skor Heuristik = 942, Temperatur = 0.0014, Probabilitas = 0.0000
# Iterasi 1345: Skor Heuristik = 942, Temperatur = 0.0014, Probabilitas = 0.0000
# Iterasi 1346: Skor Heuristik = 942, Temperatur = 0.0013, Probabilitas = 0.0000
# Iterasi 1347: Skor Heuristik = 942, Temperatur = 0.0013, Probabilitas = 0.0000
# Iterasi 1348: Skor Heuristik = 942, Temperatur = 0.0013, Probabilitas = 0.0000
# Iterasi 1349: Skor Heuristik = 942, Temperatur = 0.0013, Probabilitas = 0.0000
# Iterasi 1350: Skor Heuristik = 942, Temperatur = 0.0013, Probabilitas = 0.0000
# Iterasi 1351: Skor Heuristik = 942, Temperatur = 0.0013, Probabilitas = 0.0000
# Iterasi 1352: Skor Heuristik = 942, Temperatur = 0.0013, Probabilitas = 0.0000
# Iterasi 1353: Skor Heuristik = 942, Temperatur = 0.0013, Probabilitas = 0.0000
# Iterasi 1354: Skor Heuristik = 942, Temperatur = 0.0012, Probabilitas = 0.0000
# Iterasi 1355: Skor Heuristik = 942, Temperatur = 0.0012, Probabilitas = 0.0000
# Iterasi 1356: Skor Heuristik = 942, Temperatur = 0.0012, Probabilitas = 0.0000
# Iterasi 1357: Skor Heuristik = 942, Temperatur = 0.0012, Probabilitas = 0.0000
# Iterasi 1358: Skor Heuristik = 942, Temperatur = 0.0012, Probabilitas = 0.0000
# Iterasi 1359: Skor Heuristik = 942, Temperatur = 0.0012, Probabilitas = 0.0000
# Iterasi 1360: Skor Heuristik = 942, Temperatur = 0.0012, Probabilitas = 0.0000
# Iterasi 1361: Skor Heuristik = 907, Temperatur = 0.0012, Probabilitas = 1.0000
# Iterasi 1362: Skor Heuristik = 907, Temperatur = 0.0011, Probabilitas = 0.0000
# Iterasi 1363: Skor Heuristik = 907, Temperatur = 0.0011, Probabilitas = 0.0000
# Iterasi 1364: Skor Heuristik = 883, Temperatur = 0.0011, Probabilitas = 1.0000
# Iterasi 1365: Skor Heuristik = 883, Temperatur = 0.0011, Probabilitas = 0.0000
# Iterasi 1366: Skor Heuristik = 883, Temperatur = 0.0011, Probabilitas = 0.0000
# Iterasi 1367: Skor Heuristik = 883, Temperatur = 0.0011, Probabilitas = 0.0000
# Iterasi 1368: Skor Heuristik = 883, Temperatur = 0.0011, Probabilitas = 0.0000
# Iterasi 1369: Skor Heuristik = 883, Temperatur = 0.0011, Probabilitas = 0.0000
# Iterasi 1370: Skor Heuristik = 883, Temperatur = 0.0011, Probabilitas = 0.0000
# Iterasi 1371: Skor Heuristik = 883, Temperatur = 0.0010, Probabilitas = 0.0000
# Iterasi 1372: Skor Heuristik = 883, Temperatur = 0.0010, Probabilitas = 0.0000
# Iterasi 1373: Skor Heuristik = 883, Temperatur = 0.0010, Probabilitas = 0.0000
# Iterasi 1374: Skor Heuristik = 883, Temperatur = 0.0010, Probabilitas = 0.0000
# Iterasi 1375: Skor Heuristik = 883, Temperatur = 0.0010, Probabilitas = 0.0000
# Waktu yang dibutuhkan: 8.420294523239136 detik
# Total frekuensi stuck di local optima: 159

# %%
plot_cube(final_state, f"Final State of the Cube (Score: {final_score})")

# %%
# Plotting hasil objective function dan probabilitas
main.plot_objective_function()
