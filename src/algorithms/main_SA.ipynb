# %%
import sys
import os

# Menambahkan folder root proyek ke sys.path
sys.path.append(os.path.abspath(".."))

from simulated_annealing import SimulatedAnnealing
from cube.visual import plot_cube

# %%
main = SimulatedAnnealing(initial_temperature=1000, cooling_rate=0.99, temperature_threshold=0.001, stagnation_threshold=50)
initial_state = main.initial_state
initial_score = main.objective_function

# %%
# Visualisasi kondisi awal
plot_cube(initial_state, f"Initial State of the Cube (Score: {initial_score})")

# %%
# Menjalankan pencarian lokal
final_state, final_score = main.search()
# Out:
# Iterasi 1: Skor Heuristik = 4366, Temperatur = 1000.0000, Probabilitas = 1.0000
# Iterasi 2: Skor Heuristik = 4366, Temperatur = 990.0000, Probabilitas = 1.0000
# Iterasi 3: Skor Heuristik = 4271, Temperatur = 980.1000, Probabilitas = 1.0000
# Iterasi 4: Skor Heuristik = 4377, Temperatur = 970.2990, Probabilitas = 0.8965
# Iterasi 5: Skor Heuristik = 4276, Temperatur = 960.5960, Probabilitas = 1.0000
# Iterasi 6: Skor Heuristik = 4255, Temperatur = 950.9900, Probabilitas = 1.0000
# Iterasi 7: Skor Heuristik = 4363, Temperatur = 941.4801, Probabilitas = 0.8916
# Iterasi 8: Skor Heuristik = 4396, Temperatur = 932.0653, Probabilitas = 0.9652
# Iterasi 9: Skor Heuristik = 4356, Temperatur = 922.7447, Probabilitas = 1.0000
# Iterasi 10: Skor Heuristik = 4392, Temperatur = 913.5172, Probabilitas = 0.9614
# Iterasi 11: Skor Heuristik = 4410, Temperatur = 904.3821, Probabilitas = 0.9803
# Iterasi 12: Skor Heuristik = 4410, Temperatur = 895.3383, Probabilitas = 1.0000
# Iterasi 13: Skor Heuristik = 4443, Temperatur = 886.3849, Probabilitas = 0.9635
# Iterasi 14: Skor Heuristik = 4443, Temperatur = 877.5210, Probabilitas = 1.0000
# Iterasi 15: Skor Heuristik = 4687, Temperatur = 868.7458, Probabilitas = 0.7551
# Iterasi 16: Skor Heuristik = 4687, Temperatur = 860.0584, Probabilitas = 1.0000
# Iterasi 17: Skor Heuristik = 4665, Temperatur = 851.4578, Probabilitas = 1.0000
# Iterasi 18: Skor Heuristik = 4623, Temperatur = 842.9432, Probabilitas = 1.0000
# Iterasi 19: Skor Heuristik = 4623, Temperatur = 834.5138, Probabilitas = 1.0000
# Iterasi 20: Skor Heuristik = 4659, Temperatur = 826.1686, Probabilitas = 0.9574
# Iterasi 21: Skor Heuristik = 4437, Temperatur = 817.9069, Probabilitas = 1.0000
# Iterasi 22: Skor Heuristik = 4423, Temperatur = 809.7279, Probabilitas = 1.0000
# Iterasi 23: Skor Heuristik = 4419, Temperatur = 801.6306, Probabilitas = 1.0000
# Iterasi 24: Skor Heuristik = 4401, Temperatur = 793.6143, Probabilitas = 1.0000
# Iterasi 25: Skor Heuristik = 4443, Temperatur = 785.6781, Probabilitas = 0.9479
# Iterasi 26: Skor Heuristik = 4497, Temperatur = 777.8214, Probabilitas = 0.9329
# Iterasi 27: Skor Heuristik = 4530, Temperatur = 770.0431, Probabilitas = 0.9581
# Iterasi 28: Skor Heuristik = 4227, Temperatur = 762.3427, Probabilitas = 1.0000
# Iterasi 29: Skor Heuristik = 4256, Temperatur = 754.7193, Probabilitas = 0.9623
# Iterasi 30: Skor Heuristik = 4303, Temperatur = 747.1721, Probabilitas = 0.9390
# Iterasi 31: Skor Heuristik = 4289, Temperatur = 739.7004, Probabilitas = 1.0000
# Iterasi 32: Skor Heuristik = 4405, Temperatur = 732.3034, Probabilitas = 0.8535
# Iterasi 33: Skor Heuristik = 4513, Temperatur = 724.9803, Probabilitas = 0.8616
# Iterasi 34: Skor Heuristik = 4501, Temperatur = 717.7305, Probabilitas = 1.0000
# Iterasi 35: Skor Heuristik = 4654, Temperatur = 710.5532, Probabilitas = 0.8063
# Iterasi 36: Skor Heuristik = 4658, Temperatur = 703.4477, Probabilitas = 0.9943
# Iterasi 37: Skor Heuristik = 4658, Temperatur = 696.4132, Probabilitas = 0.8625
# Iterasi 38: Skor Heuristik = 4650, Temperatur = 689.4491, Probabilitas = 1.0000
# Iterasi 39: Skor Heuristik = 4650, Temperatur = 682.5546, Probabilitas = 1.0000
# Iterasi 40: Skor Heuristik = 4644, Temperatur = 675.7290, Probabilitas = 1.0000
# Iterasi 41: Skor Heuristik = 4644, Temperatur = 668.9718, Probabilitas = 1.0000
# Iterasi 42: Skor Heuristik = 4599, Temperatur = 662.2820, Probabilitas = 1.0000
# Iterasi 43: Skor Heuristik = 4557, Temperatur = 655.6592, Probabilitas = 1.0000
# Iterasi 44: Skor Heuristik = 4391, Temperatur = 649.1026, Probabilitas = 1.0000
# Iterasi 45: Skor Heuristik = 4411, Temperatur = 642.6116, Probabilitas = 0.9694
# Iterasi 46: Skor Heuristik = 4411, Temperatur = 636.1855, Probabilitas = 1.0000
# Iterasi 47: Skor Heuristik = 4374, Temperatur = 629.8236, Probabilitas = 1.0000
# Iterasi 48: Skor Heuristik = 4520, Temperatur = 623.5254, Probabilitas = 0.7912
# Iterasi 49: Skor Heuristik = 4517, Temperatur = 617.2901, Probabilitas = 1.0000
# Iterasi 50: Skor Heuristik = 4463, Temperatur = 611.1172, Probabilitas = 1.0000
# Iterasi 51: Skor Heuristik = 4439, Temperatur = 605.0061, Probabilitas = 1.0000
# Iterasi 52: Skor Heuristik = 4185, Temperatur = 598.9560, Probabilitas = 1.0000
# Iterasi 53: Skor Heuristik = 4363, Temperatur = 592.9664, Probabilitas = 0.7407
# Iterasi 54: Skor Heuristik = 4551, Temperatur = 587.0368, Probabilitas = 0.7260
# Iterasi 55: Skor Heuristik = 4551, Temperatur = 581.1664, Probabilitas = 1.0000
# Iterasi 56: Skor Heuristik = 4542, Temperatur = 575.3547, Probabilitas = 1.0000
# Iterasi 57: Skor Heuristik = 4545, Temperatur = 569.6012, Probabilitas = 0.9947
# Iterasi 58: Skor Heuristik = 4321, Temperatur = 563.9052, Probabilitas = 1.0000
# Iterasi 59: Skor Heuristik = 4269, Temperatur = 558.2661, Probabilitas = 1.0000
# Iterasi 60: Skor Heuristik = 4067, Temperatur = 552.6835, Probabilitas = 1.0000
# Iterasi 61: Skor Heuristik = 4066, Temperatur = 547.1566, Probabilitas = 1.0000
# Iterasi 62: Skor Heuristik = 4000, Temperatur = 541.6851, Probabilitas = 1.0000
# Iterasi 63: Skor Heuristik = 4008, Temperatur = 536.2682, Probabilitas = 0.9852
# Iterasi 64: Skor Heuristik = 4044, Temperatur = 530.9055, Probabilitas = 0.9344
# Iterasi 65: Skor Heuristik = 4052, Temperatur = 525.5965, Probabilitas = 0.9849
# Iterasi 66: Skor Heuristik = 4037, Temperatur = 520.3405, Probabilitas = 1.0000
# Iterasi 67: Skor Heuristik = 4195, Temperatur = 515.1371, Probabilitas = 0.7359
# Iterasi 68: Skor Heuristik = 4539, Temperatur = 509.9857, Probabilitas = 0.5094
# Iterasi 69: Skor Heuristik = 4532, Temperatur = 504.8859, Probabilitas = 1.0000
# Iterasi 70: Skor Heuristik = 4524, Temperatur = 499.8370, Probabilitas = 1.0000
# Iterasi 71: Skor Heuristik = 4374, Temperatur = 494.8387, Probabilitas = 1.0000
# Iterasi 72: Skor Heuristik = 4450, Temperatur = 489.8903, Probabilitas = 0.8563
# Iterasi 73: Skor Heuristik = 4480, Temperatur = 484.9914, Probabilitas = 0.9400
# Iterasi 74: Skor Heuristik = 4489, Temperatur = 480.1415, Probabilitas = 0.9814
# Iterasi 75: Skor Heuristik = 4507, Temperatur = 475.3400, Probabilitas = 0.9628
# Iterasi 76: Skor Heuristik = 4497, Temperatur = 470.5866, Probabilitas = 1.0000
# Iterasi 77: Skor Heuristik = 4530, Temperatur = 465.8808, Probabilitas = 0.9316
# Iterasi 78: Skor Heuristik = 4530, Temperatur = 461.2220, Probabilitas = 0.3902
# Iterasi 79: Skor Heuristik = 4540, Temperatur = 456.6097, Probabilitas = 0.9783
# Iterasi 80: Skor Heuristik = 4458, Temperatur = 452.0437, Probabilitas = 1.0000
# Iterasi 81: Skor Heuristik = 4372, Temperatur = 447.5232, Probabilitas = 1.0000
# Iterasi 82: Skor Heuristik = 4260, Temperatur = 443.0480, Probabilitas = 1.0000
# Iterasi 83: Skor Heuristik = 4266, Temperatur = 438.6175, Probabilitas = 0.9864
# Iterasi 84: Skor Heuristik = 4266, Temperatur = 434.2313, Probabilitas = 0.4808
# Iterasi 85: Skor Heuristik = 4348, Temperatur = 429.8890, Probabilitas = 0.8263
# Iterasi 86: Skor Heuristik = 4348, Temperatur = 425.5901, Probabilitas = 0.4918
# Iterasi 87: Skor Heuristik = 4330, Temperatur = 421.3342, Probabilitas = 1.0000
# Iterasi 88: Skor Heuristik = 4304, Temperatur = 417.1209, Probabilitas = 1.0000
# Iterasi 89: Skor Heuristik = 4376, Temperatur = 412.9497, Probabilitas = 0.8400
# Iterasi 90: Skor Heuristik = 4331, Temperatur = 408.8202, Probabilitas = 1.0000
# Iterasi 91: Skor Heuristik = 4271, Temperatur = 404.7320, Probabilitas = 1.0000
# Iterasi 92: Skor Heuristik = 4205, Temperatur = 400.6847, Probabilitas = 1.0000
# Iterasi 93: Skor Heuristik = 4194, Temperatur = 396.6778, Probabilitas = 1.0000
# Iterasi 94: Skor Heuristik = 4212, Temperatur = 392.7110, Probabilitas = 0.9552
# Iterasi 95: Skor Heuristik = 4319, Temperatur = 388.7839, Probabilitas = 0.7594
# Iterasi 96: Skor Heuristik = 4302, Temperatur = 384.8961, Probabilitas = 1.0000
# Iterasi 97: Skor Heuristik = 4128, Temperatur = 381.0471, Probabilitas = 1.0000
# Iterasi 98: Skor Heuristik = 4128, Temperatur = 377.2366, Probabilitas = 1.0000
# Iterasi 99: Skor Heuristik = 4266, Temperatur = 373.4643, Probabilitas = 0.6911
# Iterasi 100: Skor Heuristik = 4296, Temperatur = 369.7296, Probabilitas = 0.9221
# Iterasi 101: Skor Heuristik = 4216, Temperatur = 366.0323, Probabilitas = 1.0000
# Iterasi 102: Skor Heuristik = 4402, Temperatur = 362.3720, Probabilitas = 0.5985
# Iterasi 103: Skor Heuristik = 4574, Temperatur = 358.7483, Probabilitas = 0.6191
# Iterasi 104: Skor Heuristik = 4534, Temperatur = 355.1608, Probabilitas = 1.0000
# Iterasi 105: Skor Heuristik = 4592, Temperatur = 351.6092, Probabilitas = 0.8479
# Iterasi 106: Skor Heuristik = 4371, Temperatur = 348.0931, Probabilitas = 1.0000
# Iterasi 107: Skor Heuristik = 4371, Temperatur = 344.6122, Probabilitas = 0.7059
# Iterasi 108: Skor Heuristik = 4404, Temperatur = 341.1661, Probabilitas = 0.9078
# Iterasi 109: Skor Heuristik = 4472, Temperatur = 337.7544, Probabilitas = 0.8176
# Iterasi 110: Skor Heuristik = 4420, Temperatur = 334.3769, Probabilitas = 1.0000
# Iterasi 111: Skor Heuristik = 4365, Temperatur = 331.0331, Probabilitas = 1.0000
# Iterasi 112: Skor Heuristik = 4365, Temperatur = 327.7228, Probabilitas = 0.5989
# Iterasi 113: Skor Heuristik = 4681, Temperatur = 324.4455, Probabilitas = 0.3776
# Iterasi 114: Skor Heuristik = 4770, Temperatur = 321.2011, Probabilitas = 0.7580
# Iterasi 115: Skor Heuristik = 4737, Temperatur = 317.9891, Probabilitas = 1.0000
# Iterasi 116: Skor Heuristik = 4737, Temperatur = 314.8092, Probabilitas = 1.0000
# Iterasi 117: Skor Heuristik = 4811, Temperatur = 311.6611, Probabilitas = 0.7886
# Iterasi 118: Skor Heuristik = 4811, Temperatur = 308.5445, Probabilitas = 0.5653
# Iterasi 119: Skor Heuristik = 4730, Temperatur = 305.4590, Probabilitas = 1.0000
# Iterasi 120: Skor Heuristik = 4763, Temperatur = 302.4044, Probabilitas = 0.8966
# Iterasi 121: Skor Heuristik = 4757, Temperatur = 299.3804, Probabilitas = 1.0000
# Iterasi 122: Skor Heuristik = 4762, Temperatur = 296.3866, Probabilitas = 0.9833
# Iterasi 123: Skor Heuristik = 4620, Temperatur = 293.4227, Probabilitas = 1.0000
# Iterasi 124: Skor Heuristik = 4616, Temperatur = 290.4885, Probabilitas = 1.0000
# Iterasi 125: Skor Heuristik = 4637, Temperatur = 287.5836, Probabilitas = 0.9296
# Iterasi 126: Skor Heuristik = 4727, Temperatur = 284.7078, Probabilitas = 0.7290
# Iterasi 127: Skor Heuristik = 4692, Temperatur = 281.8607, Probabilitas = 1.0000
# Iterasi 128: Skor Heuristik = 4698, Temperatur = 279.0421, Probabilitas = 0.9787
# Iterasi 129: Skor Heuristik = 4732, Temperatur = 276.2517, Probabilitas = 0.8842
# Iterasi 130: Skor Heuristik = 4713, Temperatur = 273.4892, Probabilitas = 1.0000
# Iterasi 131: Skor Heuristik = 4777, Temperatur = 270.7543, Probabilitas = 0.7895
# Iterasi 132: Skor Heuristik = 4787, Temperatur = 268.0467, Probabilitas = 0.9634
# Iterasi 133: Skor Heuristik = 4698, Temperatur = 265.3662, Probabilitas = 1.0000
# Iterasi 134: Skor Heuristik = 4696, Temperatur = 262.7126, Probabilitas = 1.0000
# Iterasi 135: Skor Heuristik = 4696, Temperatur = 260.0855, Probabilitas = 0.5553
# Iterasi 136: Skor Heuristik = 4592, Temperatur = 257.4846, Probabilitas = 1.0000
# Iterasi 137: Skor Heuristik = 4592, Temperatur = 254.9098, Probabilitas = 0.7025
# Iterasi 138: Skor Heuristik = 4592, Temperatur = 252.3607, Probabilitas = 1.0000
# Iterasi 139: Skor Heuristik = 4476, Temperatur = 249.8371, Probabilitas = 1.0000
# Iterasi 140: Skor Heuristik = 4414, Temperatur = 247.3387, Probabilitas = 1.0000
# Iterasi 141: Skor Heuristik = 4414, Temperatur = 244.8653, Probabilitas = 0.6434
# Iterasi 142: Skor Heuristik = 4202, Temperatur = 242.4166, Probabilitas = 1.0000
# Iterasi 143: Skor Heuristik = 4202, Temperatur = 239.9925, Probabilitas = 0.8752
# Iterasi 144: Skor Heuristik = 4080, Temperatur = 237.5926, Probabilitas = 1.0000
# Iterasi 145: Skor Heuristik = 3968, Temperatur = 235.2166, Probabilitas = 1.0000
# Iterasi 146: Skor Heuristik = 3936, Temperatur = 232.8645, Probabilitas = 1.0000
# Iterasi 147: Skor Heuristik = 3936, Temperatur = 230.5358, Probabilitas = 0.9617
# Iterasi 148: Skor Heuristik = 3936, Temperatur = 228.2305, Probabilitas = 0.3494
# Iterasi 149: Skor Heuristik = 3910, Temperatur = 225.9482, Probabilitas = 1.0000
# Iterasi 150: Skor Heuristik = 3921, Temperatur = 223.6887, Probabilitas = 0.9520
# Iterasi 151: Skor Heuristik = 3923, Temperatur = 221.4518, Probabilitas = 0.9910
# Iterasi 152: Skor Heuristik = 3923, Temperatur = 219.2373, Probabilitas = 0.7746
# Iterasi 153: Skor Heuristik = 3923, Temperatur = 217.0449, Probabilitas = 0.3765
# Iterasi 154: Skor Heuristik = 3958, Temperatur = 214.8744, Probabilitas = 0.8497
# Iterasi 155: Skor Heuristik = 3907, Temperatur = 212.7257, Probabilitas = 1.0000
# Iterasi 156: Skor Heuristik = 4162, Temperatur = 210.5984, Probabilitas = 0.2979
# Iterasi 157: Skor Heuristik = 4277, Temperatur = 208.4925, Probabilitas = 0.5760
# Iterasi 158: Skor Heuristik = 4277, Temperatur = 206.4075, Probabilitas = 0.5869
# Iterasi 159: Skor Heuristik = 4215, Temperatur = 204.3435, Probabilitas = 1.0000
# Iterasi 160: Skor Heuristik = 4215, Temperatur = 202.3000, Probabilitas = 0.4741
# Iterasi 161: Skor Heuristik = 4215, Temperatur = 200.2770, Probabilitas = 0.6707
# Iterasi 162: Skor Heuristik = 4281, Temperatur = 198.2743, Probabilitas = 0.7169
# Iterasi 163: Skor Heuristik = 4176, Temperatur = 196.2915, Probabilitas = 1.0000
# Iterasi 164: Skor Heuristik = 4144, Temperatur = 194.3286, Probabilitas = 1.0000
# Iterasi 165: Skor Heuristik = 4134, Temperatur = 192.3853, Probabilitas = 1.0000
# Iterasi 166: Skor Heuristik = 4064, Temperatur = 190.4615, Probabilitas = 1.0000
# Iterasi 167: Skor Heuristik = 4050, Temperatur = 188.5568, Probabilitas = 1.0000
# Iterasi 168: Skor Heuristik = 4092, Temperatur = 186.6713, Probabilitas = 0.7985
# Iterasi 169: Skor Heuristik = 4200, Temperatur = 184.8046, Probabilitas = 0.5574
# Iterasi 170: Skor Heuristik = 4194, Temperatur = 182.9565, Probabilitas = 1.0000
# Iterasi 171: Skor Heuristik = 4215, Temperatur = 181.1270, Probabilitas = 0.8905
# Iterasi 172: Skor Heuristik = 4219, Temperatur = 179.3157, Probabilitas = 0.9779
# Iterasi 173: Skor Heuristik = 4219, Temperatur = 177.5225, Probabilitas = 0.6301
# Iterasi 174: Skor Heuristik = 4227, Temperatur = 175.7473, Probabilitas = 0.9555
# Iterasi 175: Skor Heuristik = 4143, Temperatur = 173.9898, Probabilitas = 1.0000
# Iterasi 176: Skor Heuristik = 4321, Temperatur = 172.2499, Probabilitas = 0.3558
# Iterasi 177: Skor Heuristik = 4271, Temperatur = 170.5274, Probabilitas = 1.0000
# Iterasi 178: Skor Heuristik = 4222, Temperatur = 168.8222, Probabilitas = 1.0000
# Iterasi 179: Skor Heuristik = 4146, Temperatur = 167.1339, Probabilitas = 1.0000
# Iterasi 180: Skor Heuristik = 4152, Temperatur = 165.4626, Probabilitas = 0.9644
# Iterasi 181: Skor Heuristik = 4152, Temperatur = 163.8080, Probabilitas = 0.4152
# Iterasi 182: Skor Heuristik = 4152, Temperatur = 162.1699, Probabilitas = 0.1846
# Iterasi 183: Skor Heuristik = 4152, Temperatur = 160.5482, Probabilitas = 0.5499
# Iterasi 184: Skor Heuristik = 4122, Temperatur = 158.9427, Probabilitas = 1.0000
# Iterasi 185: Skor Heuristik = 4122, Temperatur = 157.3533, Probabilitas = 0.8108
# Iterasi 186: Skor Heuristik = 4165, Temperatur = 155.7797, Probabilitas = 0.7588
# Iterasi 187: Skor Heuristik = 4223, Temperatur = 154.2220, Probabilitas = 0.6865
# Iterasi 188: Skor Heuristik = 4076, Temperatur = 152.6797, Probabilitas = 1.0000
# Iterasi 189: Skor Heuristik = 4028, Temperatur = 151.1529, Probabilitas = 1.0000
# Iterasi 190: Skor Heuristik = 4028, Temperatur = 149.6414, Probabilitas = 0.4030
# Iterasi 191: Skor Heuristik = 4028, Temperatur = 148.1450, Probabilitas = 0.1234
# Iterasi 192: Skor Heuristik = 4028, Temperatur = 146.6635, Probabilitas = 1.0000
# Iterasi 193: Skor Heuristik = 3812, Temperatur = 145.1969, Probabilitas = 1.0000
# Iterasi 194: Skor Heuristik = 3746, Temperatur = 143.7449, Probabilitas = 1.0000
# Iterasi 195: Skor Heuristik = 3530, Temperatur = 142.3075, Probabilitas = 1.0000
# Iterasi 196: Skor Heuristik = 3530, Temperatur = 140.8844, Probabilitas = 1.0000
# Iterasi 197: Skor Heuristik = 3515, Temperatur = 139.4756, Probabilitas = 1.0000
# Iterasi 198: Skor Heuristik = 3501, Temperatur = 138.0808, Probabilitas = 1.0000
# Iterasi 199: Skor Heuristik = 3512, Temperatur = 136.7000, Probabilitas = 0.9227
# Iterasi 200: Skor Heuristik = 3512, Temperatur = 135.3330, Probabilitas = 0.2420
# Iterasi 201: Skor Heuristik = 3564, Temperatur = 133.9797, Probabilitas = 0.6783
# Iterasi 202: Skor Heuristik = 3564, Temperatur = 132.6399, Probabilitas = 1.0000
# Iterasi 203: Skor Heuristik = 3564, Temperatur = 131.3135, Probabilitas = 0.6938
# Iterasi 204: Skor Heuristik = 3565, Temperatur = 130.0003, Probabilitas = 0.9923
# Iterasi 205: Skor Heuristik = 3565, Temperatur = 128.7003, Probabilitas = 1.0000
# Iterasi 206: Skor Heuristik = 3565, Temperatur = 127.4133, Probabilitas = 0.2634
# Iterasi 207: Skor Heuristik = 3550, Temperatur = 126.1392, Probabilitas = 1.0000
# Iterasi 208: Skor Heuristik = 3562, Temperatur = 124.8778, Probabilitas = 0.9084
# Iterasi 209: Skor Heuristik = 3495, Temperatur = 123.6290, Probabilitas = 1.0000
# Iterasi 210: Skor Heuristik = 3495, Temperatur = 122.3927, Probabilitas = 0.5117
# Iterasi 211: Skor Heuristik = 3497, Temperatur = 121.1688, Probabilitas = 0.9836
# Iterasi 212: Skor Heuristik = 3487, Temperatur = 119.9571, Probabilitas = 1.0000
# Iterasi 213: Skor Heuristik = 3487, Temperatur = 118.7576, Probabilitas = 0.0855
# Iterasi 214: Skor Heuristik = 3365, Temperatur = 117.5700, Probabilitas = 1.0000
# Iterasi 215: Skor Heuristik = 3423, Temperatur = 116.3943, Probabilitas = 0.6076
# Iterasi 216: Skor Heuristik = 3423, Temperatur = 115.2303, Probabilitas = 0.1020
# Iterasi 217: Skor Heuristik = 3463, Temperatur = 114.0780, Probabilitas = 0.7042
# Iterasi 218: Skor Heuristik = 3362, Temperatur = 112.9373, Probabilitas = 1.0000
# Iterasi 219: Skor Heuristik = 3362, Temperatur = 111.8079, Probabilitas = 0.4889
# Iterasi 220: Skor Heuristik = 3362, Temperatur = 110.6898, Probabilitas = 0.7422
# Iterasi 221: Skor Heuristik = 3343, Temperatur = 109.5829, Probabilitas = 1.0000
# Iterasi 222: Skor Heuristik = 3517, Temperatur = 108.4871, Probabilitas = 0.2011
# Iterasi 223: Skor Heuristik = 3257, Temperatur = 107.4022, Probabilitas = 1.0000
# Iterasi 224: Skor Heuristik = 3257, Temperatur = 106.3282, Probabilitas = 0.0900
# Iterasi 225: Skor Heuristik = 3268, Temperatur = 105.2649, Probabilitas = 0.9008
# Iterasi 226: Skor Heuristik = 3498, Temperatur = 104.2123, Probabilitas = 0.1100
# Iterasi 227: Skor Heuristik = 3498, Temperatur = 103.1701, Probabilitas = 1.0000
# Iterasi 228: Skor Heuristik = 3503, Temperatur = 102.1384, Probabilitas = 0.9522
# Iterasi 229: Skor Heuristik = 3503, Temperatur = 101.1170, Probabilitas = 0.0979
# Iterasi 230: Skor Heuristik = 3396, Temperatur = 100.1059, Probabilitas = 1.0000
# Iterasi 231: Skor Heuristik = 3396, Temperatur = 99.1048, Probabilitas = 0.4199
# Iterasi 232: Skor Heuristik = 3052, Temperatur = 98.1138, Probabilitas = 1.0000
# Iterasi 233: Skor Heuristik = 2959, Temperatur = 97.1326, Probabilitas = 1.0000
# Iterasi 234: Skor Heuristik = 2985, Temperatur = 96.1613, Probabilitas = 0.7631
# Iterasi 235: Skor Heuristik = 2931, Temperatur = 95.1997, Probabilitas = 1.0000
# Iterasi 236: Skor Heuristik = 2842, Temperatur = 94.2477, Probabilitas = 1.0000
# Iterasi 237: Skor Heuristik = 2842, Temperatur = 93.3052, Probabilitas = 0.7815
# Iterasi 238: Skor Heuristik = 2842, Temperatur = 92.3722, Probabilitas = 0.3244
# Iterasi 239: Skor Heuristik = 2842, Temperatur = 91.4484, Probabilitas = 0.6181
# Iterasi 240: Skor Heuristik = 2842, Temperatur = 90.5340, Probabilitas = 0.6572
# Iterasi 241: Skor Heuristik = 2842, Temperatur = 89.6286, Probabilitas = 0.0225
# Iterasi 242: Skor Heuristik = 2744, Temperatur = 88.7323, Probabilitas = 1.0000
# Iterasi 243: Skor Heuristik = 2823, Temperatur = 87.8450, Probabilitas = 0.4068
# Iterasi 244: Skor Heuristik = 2752, Temperatur = 86.9666, Probabilitas = 1.0000
# Iterasi 245: Skor Heuristik = 2752, Temperatur = 86.0969, Probabilitas = 0.0102
# Iterasi 246: Skor Heuristik = 2760, Temperatur = 85.2359, Probabilitas = 0.9104
# Iterasi 247: Skor Heuristik = 2760, Temperatur = 84.3836, Probabilitas = 0.1466
# Iterasi 248: Skor Heuristik = 2760, Temperatur = 83.5397, Probabilitas = 0.9532
# Iterasi 249: Skor Heuristik = 2616, Temperatur = 82.7043, Probabilitas = 1.0000
# Iterasi 250: Skor Heuristik = 2616, Temperatur = 81.8773, Probabilitas = 0.3673
# Iterasi 251: Skor Heuristik = 2649, Temperatur = 81.0585, Probabilitas = 0.6656
# Iterasi 252: Skor Heuristik = 2673, Temperatur = 80.2479, Probabilitas = 0.7415
# Iterasi 253: Skor Heuristik = 2673, Temperatur = 79.4455, Probabilitas = 0.0001
# Iterasi 254: Skor Heuristik = 2629, Temperatur = 78.6510, Probabilitas = 1.0000
# Iterasi 255: Skor Heuristik = 2645, Temperatur = 77.8645, Probabilitas = 0.8143
# Iterasi 256: Skor Heuristik = 2675, Temperatur = 77.0858, Probabilitas = 0.6776
# Iterasi 257: Skor Heuristik = 2683, Temperatur = 76.3150, Probabilitas = 0.9005
# Iterasi 258: Skor Heuristik = 2683, Temperatur = 75.5518, Probabilitas = 1.0000
# Iterasi 259: Skor Heuristik = 2683, Temperatur = 74.7963, Probabilitas = 0.3572
# Iterasi 260: Skor Heuristik = 2677, Temperatur = 74.0484, Probabilitas = 1.0000
# Iterasi 261: Skor Heuristik = 2585, Temperatur = 73.3079, Probabilitas = 1.0000
# Iterasi 262: Skor Heuristik = 2541, Temperatur = 72.5748, Probabilitas = 1.0000
# Iterasi 263: Skor Heuristik = 2517, Temperatur = 71.8490, Probabilitas = 1.0000
# Iterasi 264: Skor Heuristik = 2517, Temperatur = 71.1306, Probabilitas = 0.1437
# Iterasi 265: Skor Heuristik = 2517, Temperatur = 70.4192, Probabilitas = 0.0137
# Iterasi 266: Skor Heuristik = 2507, Temperatur = 69.7151, Probabilitas = 1.0000
# Iterasi 267: Skor Heuristik = 2426, Temperatur = 69.0179, Probabilitas = 1.0000
# Iterasi 268: Skor Heuristik = 2392, Temperatur = 68.3277, Probabilitas = 1.0000
# Iterasi 269: Skor Heuristik = 2392, Temperatur = 67.6444, Probabilitas = 1.0000
# Iterasi 270: Skor Heuristik = 2392, Temperatur = 66.9680, Probabilitas = 0.0005
# Iterasi 271: Skor Heuristik = 2392, Temperatur = 66.2983, Probabilitas = 0.0080
# Iterasi 272: Skor Heuristik = 2386, Temperatur = 65.6353, Probabilitas = 1.0000
# Iterasi 273: Skor Heuristik = 2455, Temperatur = 64.9790, Probabilitas = 0.3458
# Iterasi 274: Skor Heuristik = 2455, Temperatur = 64.3292, Probabilitas = 0.5626
# Iterasi 275: Skor Heuristik = 2433, Temperatur = 63.6859, Probabilitas = 1.0000
# Iterasi 276: Skor Heuristik = 2433, Temperatur = 63.0490, Probabilitas = 0.0336
# Iterasi 277: Skor Heuristik = 2433, Temperatur = 62.4186, Probabilitas = 1.0000
# Iterasi 278: Skor Heuristik = 2451, Temperatur = 61.7944, Probabilitas = 0.7473
# Iterasi 279: Skor Heuristik = 2451, Temperatur = 61.1764, Probabilitas = 0.0621
# Iterasi 280: Skor Heuristik = 2451, Temperatur = 60.5647, Probabilitas = 0.4602
# Iterasi 281: Skor Heuristik = 2431, Temperatur = 59.9590, Probabilitas = 1.0000
# Iterasi 282: Skor Heuristik = 2431, Temperatur = 59.3594, Probabilitas = 0.0089
# Iterasi 283: Skor Heuristik = 2477, Temperatur = 58.7658, Probabilitas = 0.4571
# Iterasi 284: Skor Heuristik = 2477, Temperatur = 58.1782, Probabilitas = 0.5294
# Iterasi 285: Skor Heuristik = 2477, Temperatur = 57.5964, Probabilitas = 0.3653
# Iterasi 286: Skor Heuristik = 2477, Temperatur = 57.0204, Probabilitas = 0.4234
# Iterasi 287: Skor Heuristik = 2495, Temperatur = 56.4502, Probabilitas = 0.7270
# Iterasi 288: Skor Heuristik = 2429, Temperatur = 55.8857, Probabilitas = 1.0000
# Iterasi 289: Skor Heuristik = 2375, Temperatur = 55.3269, Probabilitas = 1.0000
# Iterasi 290: Skor Heuristik = 2345, Temperatur = 54.7736, Probabilitas = 1.0000
# Iterasi 291: Skor Heuristik = 2345, Temperatur = 54.2259, Probabilitas = 0.2124
# Iterasi 292: Skor Heuristik = 2355, Temperatur = 53.6836, Probabilitas = 0.8300
# Iterasi 293: Skor Heuristik = 2355, Temperatur = 53.1468, Probabilitas = 0.1983
# Iterasi 294: Skor Heuristik = 2355, Temperatur = 52.6153, Probabilitas = 0.0001
# Iterasi 295: Skor Heuristik = 2355, Temperatur = 52.0891, Probabilitas = 0.5410
# Iterasi 296: Skor Heuristik = 2352, Temperatur = 51.5683, Probabilitas = 1.0000
# Iterasi 297: Skor Heuristik = 2352, Temperatur = 51.0526, Probabilitas = 0.0055
# Iterasi 298: Skor Heuristik = 2384, Temperatur = 50.5420, Probabilitas = 0.5309
# Iterasi 299: Skor Heuristik = 2318, Temperatur = 50.0366, Probabilitas = 1.0000
# Iterasi 300: Skor Heuristik = 2318, Temperatur = 49.5363, Probabilitas = 0.0041
# Iterasi 301: Skor Heuristik = 2312, Temperatur = 49.0409, Probabilitas = 1.0000
# Iterasi 302: Skor Heuristik = 2312, Temperatur = 48.5505, Probabilitas = 0.1127
# Iterasi 303: Skor Heuristik = 2312, Temperatur = 48.0650, Probabilitas = 0.0173
# Iterasi 304: Skor Heuristik = 2312, Temperatur = 47.5843, Probabilitas = 0.1124
# Iterasi 305: Skor Heuristik = 2312, Temperatur = 47.1085, Probabilitas = 0.5070
# Iterasi 306: Skor Heuristik = 2312, Temperatur = 46.6374, Probabilitas = 0.0476
# Iterasi 307: Skor Heuristik = 2312, Temperatur = 46.1710, Probabilitas = 0.2500
# Iterasi 308: Skor Heuristik = 2446, Temperatur = 45.7093, Probabilitas = 0.0533
# Iterasi 309: Skor Heuristik = 2446, Temperatur = 45.2522, Probabilitas = 0.0001
# Iterasi 310: Skor Heuristik = 2410, Temperatur = 44.7997, Probabilitas = 1.0000
# Iterasi 311: Skor Heuristik = 2410, Temperatur = 44.3517, Probabilitas = 0.3545
# Iterasi 312: Skor Heuristik = 2442, Temperatur = 43.9082, Probabilitas = 0.4825
# Iterasi 313: Skor Heuristik = 2442, Temperatur = 43.4691, Probabilitas = 1.0000
# Iterasi 314: Skor Heuristik = 2442, Temperatur = 43.0344, Probabilitas = 0.1026
# Iterasi 315: Skor Heuristik = 2442, Temperatur = 42.6041, Probabilitas = 0.0000
# Iterasi 316: Skor Heuristik = 2442, Temperatur = 42.1780, Probabilitas = 0.0005
# Iterasi 317: Skor Heuristik = 2442, Temperatur = 41.7563, Probabilitas = 0.0052
# Iterasi 318: Skor Heuristik = 2442, Temperatur = 41.3387, Probabilitas = 0.0160
# Iterasi 319: Skor Heuristik = 2420, Temperatur = 40.9253, Probabilitas = 1.0000
# Iterasi 320: Skor Heuristik = 2420, Temperatur = 40.5160, Probabilitas = 1.0000
# Iterasi 321: Skor Heuristik = 2420, Temperatur = 40.1109, Probabilitas = 0.0694
# Iterasi 322: Skor Heuristik = 2420, Temperatur = 39.7098, Probabilitas = 0.0008
# Iterasi 323: Skor Heuristik = 2420, Temperatur = 39.3127, Probabilitas = 1.0000
# Iterasi 324: Skor Heuristik = 2399, Temperatur = 38.9196, Probabilitas = 1.0000
# Iterasi 325: Skor Heuristik = 2399, Temperatur = 38.5304, Probabilitas = 0.0746
# Iterasi 326: Skor Heuristik = 2399, Temperatur = 38.1451, Probabilitas = 0.0015
# Iterasi 327: Skor Heuristik = 2399, Temperatur = 37.7636, Probabilitas = 0.0001
# Iterasi 328: Skor Heuristik = 2399, Temperatur = 37.3860, Probabilitas = 1.0000
# Iterasi 329: Skor Heuristik = 2419, Temperatur = 37.0121, Probabilitas = 0.5825
# Iterasi 330: Skor Heuristik = 2419, Temperatur = 36.6420, Probabilitas = 0.8490
# Iterasi 331: Skor Heuristik = 2409, Temperatur = 36.2756, Probabilitas = 1.0000
# Iterasi 332: Skor Heuristik = 2419, Temperatur = 35.9128, Probabilitas = 0.7570
# Iterasi 333: Skor Heuristik = 2419, Temperatur = 35.5537, Probabilitas = 0.0053
# Iterasi 334: Skor Heuristik = 2419, Temperatur = 35.1981, Probabilitas = 0.0000
# Iterasi 335: Skor Heuristik = 2401, Temperatur = 34.8462, Probabilitas = 1.0000
# Iterasi 336: Skor Heuristik = 2367, Temperatur = 34.4977, Probabilitas = 1.0000
# Iterasi 337: Skor Heuristik = 2367, Temperatur = 34.1527, Probabilitas = 0.0104
# Iterasi 338: Skor Heuristik = 2367, Temperatur = 33.8112, Probabilitas = 1.0000
# Iterasi 339: Skor Heuristik = 2367, Temperatur = 33.4731, Probabilitas = 0.4081
# Iterasi 340: Skor Heuristik = 2347, Temperatur = 33.1384, Probabilitas = 1.0000
# Iterasi 341: Skor Heuristik = 2358, Temperatur = 32.8070, Probabilitas = 0.7151
# Iterasi 342: Skor Heuristik = 2358, Temperatur = 32.4789, Probabilitas = 0.0299
# Iterasi 343: Skor Heuristik = 2300, Temperatur = 32.1541, Probabilitas = 1.0000
# Iterasi 344: Skor Heuristik = 2300, Temperatur = 31.8326, Probabilitas = 0.0191
# Iterasi 345: Skor Heuristik = 2288, Temperatur = 31.5142, Probabilitas = 1.0000
# Iterasi 346: Skor Heuristik = 2274, Temperatur = 31.1991, Probabilitas = 1.0000
# Iterasi 347: Skor Heuristik = 2237, Temperatur = 30.8871, Probabilitas = 1.0000
# Iterasi 348: Skor Heuristik = 2237, Temperatur = 30.5782, Probabilitas = 0.0333
# Iterasi 349: Skor Heuristik = 2237, Temperatur = 30.2725, Probabilitas = 0.0004
# Iterasi 350: Skor Heuristik = 2237, Temperatur = 29.9697, Probabilitas = 0.0496
# Iterasi 351: Skor Heuristik = 2194, Temperatur = 29.6700, Probabilitas = 1.0000
# Iterasi 352: Skor Heuristik = 2194, Temperatur = 29.3733, Probabilitas = 0.0029
# Iterasi 353: Skor Heuristik = 2194, Temperatur = 29.0796, Probabilitas = 0.0000
# Iterasi 354: Skor Heuristik = 2286, Temperatur = 28.7888, Probabilitas = 0.0409
# Iterasi 355: Skor Heuristik = 2286, Temperatur = 28.5009, Probabilitas = 0.9322
# Iterasi 356: Skor Heuristik = 2286, Temperatur = 28.2159, Probabilitas = 0.2997
# Iterasi 357: Skor Heuristik = 2286, Temperatur = 27.9338, Probabilitas = 0.0002
# Iterasi 358: Skor Heuristik = 2269, Temperatur = 27.6544, Probabilitas = 1.0000
# Iterasi 359: Skor Heuristik = 2100, Temperatur = 27.3779, Probabilitas = 1.0000
# Iterasi 360: Skor Heuristik = 2106, Temperatur = 27.1041, Probabilitas = 0.8014
# Iterasi 361: Skor Heuristik = 2087, Temperatur = 26.8331, Probabilitas = 1.0000
# Iterasi 362: Skor Heuristik = 2094, Temperatur = 26.5647, Probabilitas = 0.7684
# Iterasi 363: Skor Heuristik = 2094, Temperatur = 26.2991, Probabilitas = 0.0006
# Iterasi 364: Skor Heuristik = 2090, Temperatur = 26.0361, Probabilitas = 1.0000
# Iterasi 365: Skor Heuristik = 2090, Temperatur = 25.7757, Probabilitas = 0.0975
# Iterasi 366: Skor Heuristik = 2072, Temperatur = 25.5180, Probabilitas = 1.0000
# Iterasi 367: Skor Heuristik = 2072, Temperatur = 25.2628, Probabilitas = 0.0000
# Iterasi 368: Skor Heuristik = 2062, Temperatur = 25.0102, Probabilitas = 1.0000
# Iterasi 369: Skor Heuristik = 2062, Temperatur = 24.7601, Probabilitas = 0.0642
# Iterasi 370: Skor Heuristik = 2062, Temperatur = 24.5125, Probabilitas = 0.0030
# Iterasi 371: Skor Heuristik = 2062, Temperatur = 24.2673, Probabilitas = 0.0184
# Iterasi 372: Skor Heuristik = 2062, Temperatur = 24.0247, Probabilitas = 0.0032
# Iterasi 373: Skor Heuristik = 2016, Temperatur = 23.7844, Probabilitas = 1.0000
# Iterasi 374: Skor Heuristik = 2016, Temperatur = 23.5466, Probabilitas = 0.0000
# Iterasi 375: Skor Heuristik = 2010, Temperatur = 23.3111, Probabilitas = 1.0000
# Iterasi 376: Skor Heuristik = 2056, Temperatur = 23.0780, Probabilitas = 0.1363
# Iterasi 377: Skor Heuristik = 2056, Temperatur = 22.8472, Probabilitas = 0.0002
# Iterasi 378: Skor Heuristik = 2050, Temperatur = 22.6187, Probabilitas = 1.0000
# Iterasi 379: Skor Heuristik = 2050, Temperatur = 22.3926, Probabilitas = 0.2395
# Iterasi 380: Skor Heuristik = 2050, Temperatur = 22.1686, Probabilitas = 0.0407
# Iterasi 381: Skor Heuristik = 1988, Temperatur = 21.9469, Probabilitas = 1.0000
# Iterasi 382: Skor Heuristik = 1988, Temperatur = 21.7275, Probabilitas = 0.2091
# Iterasi 383: Skor Heuristik = 1988, Temperatur = 21.5102, Probabilitas = 0.0000
# Iterasi 384: Skor Heuristik = 1942, Temperatur = 21.2951, Probabilitas = 1.0000
# Iterasi 385: Skor Heuristik = 1942, Temperatur = 21.0821, Probabilitas = 0.0019
# Iterasi 386: Skor Heuristik = 1942, Temperatur = 20.8713, Probabilitas = 0.4221
# Iterasi 387: Skor Heuristik = 1942, Temperatur = 20.6626, Probabilitas = 0.0128
# Iterasi 388: Skor Heuristik = 1922, Temperatur = 20.4560, Probabilitas = 1.0000
# Iterasi 389: Skor Heuristik = 1916, Temperatur = 20.2514, Probabilitas = 1.0000
# Iterasi 390: Skor Heuristik = 1930, Temperatur = 20.0489, Probabilitas = 0.4974
# Iterasi 391: Skor Heuristik = 1930, Temperatur = 19.8484, Probabilitas = 0.0050
# Iterasi 392: Skor Heuristik = 1930, Temperatur = 19.6499, Probabilitas = 0.0037
# Iterasi 393: Skor Heuristik = 1930, Temperatur = 19.4534, Probabilitas = 0.0000
# Iterasi 394: Skor Heuristik = 1912, Temperatur = 19.2589, Probabilitas = 1.0000
# Iterasi 395: Skor Heuristik = 1912, Temperatur = 19.0663, Probabilitas = 0.0099
# Iterasi 396: Skor Heuristik = 1912, Temperatur = 18.8756, Probabilitas = 0.1651
# Iterasi 397: Skor Heuristik = 1912, Temperatur = 18.6869, Probabilitas = 0.0556
# Iterasi 398: Skor Heuristik = 1917, Temperatur = 18.5000, Probabilitas = 0.7632
# Iterasi 399: Skor Heuristik = 1917, Temperatur = 18.3150, Probabilitas = 0.1009
# Iterasi 400: Skor Heuristik = 1917, Temperatur = 18.1319, Probabilitas = 0.0109
# Iterasi 401: Skor Heuristik = 1917, Temperatur = 17.9506, Probabilitas = 0.0010
# Iterasi 402: Skor Heuristik = 1917, Temperatur = 17.7710, Probabilitas = 0.0006
# Iterasi 403: Skor Heuristik = 1917, Temperatur = 17.5933, Probabilitas = 0.0119
# Iterasi 404: Skor Heuristik = 1917, Temperatur = 17.4174, Probabilitas = 0.1420
# Iterasi 405: Skor Heuristik = 1864, Temperatur = 17.2432, Probabilitas = 1.0000
# Iterasi 406: Skor Heuristik = 1864, Temperatur = 17.0708, Probabilitas = 0.0010
# Iterasi 407: Skor Heuristik = 1892, Temperatur = 16.9001, Probabilitas = 0.1907
# Iterasi 408: Skor Heuristik = 1892, Temperatur = 16.7311, Probabilitas = 0.0447
# Iterasi 409: Skor Heuristik = 1906, Temperatur = 16.5638, Probabilitas = 0.4295
# Iterasi 410: Skor Heuristik = 1906, Temperatur = 16.3981, Probabilitas = 0.0018
# Iterasi 411: Skor Heuristik = 1906, Temperatur = 16.2342, Probabilitas = 1.0000
# Iterasi 412: Skor Heuristik = 1906, Temperatur = 16.0718, Probabilitas = 0.0006
# Iterasi 413: Skor Heuristik = 1906, Temperatur = 15.9111, Probabilitas = 0.0000
# Iterasi 414: Skor Heuristik = 1906, Temperatur = 15.7520, Probabilitas = 0.0000
# Iterasi 415: Skor Heuristik = 1906, Temperatur = 15.5945, Probabilitas = 1.0000
# Iterasi 416: Skor Heuristik = 1906, Temperatur = 15.4385, Probabilitas = 0.0000
# Iterasi 417: Skor Heuristik = 1906, Temperatur = 15.2841, Probabilitas = 0.0000
# Iterasi 418: Skor Heuristik = 1906, Temperatur = 15.1313, Probabilitas = 0.0039
# Iterasi 419: Skor Heuristik = 1906, Temperatur = 14.9800, Probabilitas = 0.0055
# Iterasi 420: Skor Heuristik = 1896, Temperatur = 14.8302, Probabilitas = 1.0000
# Iterasi 421: Skor Heuristik = 1890, Temperatur = 14.6819, Probabilitas = 1.0000
# Iterasi 422: Skor Heuristik = 1890, Temperatur = 14.5351, Probabilitas = 0.0000
# Iterasi 423: Skor Heuristik = 1904, Temperatur = 14.3897, Probabilitas = 0.3780
# Iterasi 424: Skor Heuristik = 1904, Temperatur = 14.2458, Probabilitas = 0.0000
# Iterasi 425: Skor Heuristik = 1904, Temperatur = 14.1034, Probabilitas = 0.0026
# Iterasi 426: Skor Heuristik = 1904, Temperatur = 13.9623, Probabilitas = 0.0000
# Iterasi 427: Skor Heuristik = 1904, Temperatur = 13.8227, Probabilitas = 0.0000
# Iterasi 428: Skor Heuristik = 1904, Temperatur = 13.6845, Probabilitas = 0.0002
# Iterasi 429: Skor Heuristik = 1904, Temperatur = 13.5476, Probabilitas = 0.0000
# Iterasi 430: Skor Heuristik = 1904, Temperatur = 13.4122, Probabilitas = 0.0793
# Iterasi 431: Skor Heuristik = 1904, Temperatur = 13.2780, Probabilitas = 0.0000
# Iterasi 432: Skor Heuristik = 1904, Temperatur = 13.1453, Probabilitas = 0.0000
# Iterasi 433: Skor Heuristik = 1904, Temperatur = 13.0138, Probabilitas = 0.2508
# Iterasi 434: Skor Heuristik = 1904, Temperatur = 12.8837, Probabilitas = 0.0111
# Iterasi 435: Skor Heuristik = 1904, Temperatur = 12.7548, Probabilitas = 0.0000
# Iterasi 436: Skor Heuristik = 1785, Temperatur = 12.6273, Probabilitas = 1.0000
# Iterasi 437: Skor Heuristik = 1785, Temperatur = 12.5010, Probabilitas = 0.0183
# Iterasi 438: Skor Heuristik = 1785, Temperatur = 12.3760, Probabilitas = 0.0001
# Iterasi 439: Skor Heuristik = 1785, Temperatur = 12.2522, Probabilitas = 0.0276
# Iterasi 440: Skor Heuristik = 1785, Temperatur = 12.1297, Probabilitas = 0.3153
# Iterasi 441: Skor Heuristik = 1785, Temperatur = 12.0084, Probabilitas = 0.0000
# Iterasi 442: Skor Heuristik = 1785, Temperatur = 11.8883, Probabilitas = 0.0004
# Iterasi 443: Skor Heuristik = 1785, Temperatur = 11.7694, Probabilitas = 0.0000
# Iterasi 444: Skor Heuristik = 1785, Temperatur = 11.6518, Probabilitas = 0.0001
# Iterasi 445: Skor Heuristik = 1785, Temperatur = 11.5352, Probabilitas = 0.0000
# Iterasi 446: Skor Heuristik = 1773, Temperatur = 11.4199, Probabilitas = 1.0000
# Iterasi 447: Skor Heuristik = 1773, Temperatur = 11.3057, Probabilitas = 0.2429
# Iterasi 448: Skor Heuristik = 1773, Temperatur = 11.1926, Probabilitas = 0.0000
# Iterasi 449: Skor Heuristik = 1775, Temperatur = 11.0807, Probabilitas = 0.8349
# Iterasi 450: Skor Heuristik = 1775, Temperatur = 10.9699, Probabilitas = 0.5283
# Iterasi 451: Skor Heuristik = 1775, Temperatur = 10.8602, Probabilitas = 0.0000
# Iterasi 452: Skor Heuristik = 1775, Temperatur = 10.7516, Probabilitas = 0.0096
# Iterasi 453: Skor Heuristik = 1775, Temperatur = 10.6441, Probabilitas = 0.0001
# Iterasi 454: Skor Heuristik = 1775, Temperatur = 10.5376, Probabilitas = 0.0000
# Iterasi 455: Skor Heuristik = 1775, Temperatur = 10.4323, Probabilitas = 0.1002
# Iterasi 456: Skor Heuristik = 1775, Temperatur = 10.3279, Probabilitas = 0.0000
# Iterasi 457: Skor Heuristik = 1775, Temperatur = 10.2247, Probabilitas = 0.1559
# Iterasi 458: Skor Heuristik = 1775, Temperatur = 10.1224, Probabilitas = 0.0005
# Iterasi 459: Skor Heuristik = 1775, Temperatur = 10.0212, Probabilitas = 0.0000
# Iterasi 460: Skor Heuristik = 1781, Temperatur = 9.9210, Probabilitas = 0.5462
# Iterasi 461: Skor Heuristik = 1781, Temperatur = 9.8218, Probabilitas = 1.0000
# Iterasi 462: Skor Heuristik = 1781, Temperatur = 9.7235, Probabilitas = 0.0457
# Iterasi 463: Skor Heuristik = 1781, Temperatur = 9.6263, Probabilitas = 0.0443
# Iterasi 464: Skor Heuristik = 1781, Temperatur = 9.5300, Probabilitas = 1.0000
# Iterasi 465: Skor Heuristik = 1781, Temperatur = 9.4347, Probabilitas = 0.0002
# Iterasi 466: Skor Heuristik = 1781, Temperatur = 9.3404, Probabilitas = 0.0000
# Iterasi 467: Skor Heuristik = 1781, Temperatur = 9.2470, Probabilitas = 0.0019
# Iterasi 468: Skor Heuristik = 1781, Temperatur = 9.1545, Probabilitas = 0.0000
# Iterasi 469: Skor Heuristik = 1781, Temperatur = 9.0630, Probabilitas = 0.0000
# Iterasi 470: Skor Heuristik = 1781, Temperatur = 8.9724, Probabilitas = 0.0000
# Iterasi 471: Skor Heuristik = 1781, Temperatur = 8.8826, Probabilitas = 0.0000
# Iterasi 472: Skor Heuristik = 1781, Temperatur = 8.7938, Probabilitas = 0.0030
# Iterasi 473: Skor Heuristik = 1781, Temperatur = 8.7059, Probabilitas = 0.0000
# Iterasi 474: Skor Heuristik = 1781, Temperatur = 8.6188, Probabilitas = 0.0153
# Iterasi 475: Skor Heuristik = 1781, Temperatur = 8.5326, Probabilitas = 0.0422
# Iterasi 476: Skor Heuristik = 1781, Temperatur = 8.4473, Probabilitas = 0.0000
# Iterasi 477: Skor Heuristik = 1781, Temperatur = 8.3628, Probabilitas = 0.0000
# Iterasi 478: Skor Heuristik = 1781, Temperatur = 8.2792, Probabilitas = 0.1137
# Iterasi 479: Skor Heuristik = 1781, Temperatur = 8.1964, Probabilitas = 0.0014
# Iterasi 480: Skor Heuristik = 1781, Temperatur = 8.1144, Probabilitas = 0.0000
# Iterasi 481: Skor Heuristik = 1753, Temperatur = 8.0333, Probabilitas = 1.0000
# Iterasi 482: Skor Heuristik = 1753, Temperatur = 7.9530, Probabilitas = 0.3657
# Iterasi 483: Skor Heuristik = 1753, Temperatur = 7.8734, Probabilitas = 0.0002
# Iterasi 484: Skor Heuristik = 1749, Temperatur = 7.7947, Probabilitas = 1.0000
# Iterasi 485: Skor Heuristik = 1749, Temperatur = 7.7167, Probabilitas = 0.0000
# Iterasi 486: Skor Heuristik = 1703, Temperatur = 7.6396, Probabilitas = 1.0000
# Iterasi 487: Skor Heuristik = 1648, Temperatur = 7.5632, Probabilitas = 1.0000
# Iterasi 488: Skor Heuristik = 1648, Temperatur = 7.4876, Probabilitas = 0.0000
# Iterasi 489: Skor Heuristik = 1648, Temperatur = 7.4127, Probabilitas = 0.0000
# Iterasi 490: Skor Heuristik = 1648, Temperatur = 7.3385, Probabilitas = 0.0252
# Iterasi 491: Skor Heuristik = 1599, Temperatur = 7.2652, Probabilitas = 1.0000
# Iterasi 492: Skor Heuristik = 1599, Temperatur = 7.1925, Probabilitas = 0.0000
# Iterasi 493: Skor Heuristik = 1599, Temperatur = 7.1206, Probabilitas = 0.0000
# Iterasi 494: Skor Heuristik = 1599, Temperatur = 7.0494, Probabilitas = 0.0000
# Iterasi 495: Skor Heuristik = 1599, Temperatur = 6.9789, Probabilitas = 0.0000
# Iterasi 496: Skor Heuristik = 1599, Temperatur = 6.9091, Probabilitas = 0.0000
# Iterasi 497: Skor Heuristik = 1599, Temperatur = 6.8400, Probabilitas = 0.0001
# Iterasi 498: Skor Heuristik = 1570, Temperatur = 6.7716, Probabilitas = 1.0000
# Iterasi 499: Skor Heuristik = 1570, Temperatur = 6.7039, Probabilitas = 0.0000
# Iterasi 500: Skor Heuristik = 1570, Temperatur = 6.6369, Probabilitas = 1.0000
# Iterasi 501: Skor Heuristik = 1570, Temperatur = 6.5705, Probabilitas = 0.0007
# Iterasi 502: Skor Heuristik = 1570, Temperatur = 6.5048, Probabilitas = 0.3976
# Iterasi 503: Skor Heuristik = 1570, Temperatur = 6.4397, Probabilitas = 0.0000
# Iterasi 504: Skor Heuristik = 1570, Temperatur = 6.3753, Probabilitas = 0.0813
# Iterasi 505: Skor Heuristik = 1570, Temperatur = 6.3116, Probabilitas = 0.0306
# Iterasi 506: Skor Heuristik = 1570, Temperatur = 6.2485, Probabilitas = 0.0000
# Iterasi 507: Skor Heuristik = 1570, Temperatur = 6.1860, Probabilitas = 0.0000
# Iterasi 508: Skor Heuristik = 1570, Temperatur = 6.1241, Probabilitas = 0.0000
# Iterasi 509: Skor Heuristik = 1570, Temperatur = 6.0629, Probabilitas = 0.0000
# Iterasi 510: Skor Heuristik = 1570, Temperatur = 6.0022, Probabilitas = 0.0498
# Iterasi 511: Skor Heuristik = 1570, Temperatur = 5.9422, Probabilitas = 0.0000
# Iterasi 512: Skor Heuristik = 1570, Temperatur = 5.8828, Probabilitas = 0.0000
# Iterasi 513: Skor Heuristik = 1570, Temperatur = 5.8240, Probabilitas = 0.0000
# Iterasi 514: Skor Heuristik = 1570, Temperatur = 5.7657, Probabilitas = 0.0001
# Iterasi 515: Skor Heuristik = 1570, Temperatur = 5.7081, Probabilitas = 0.0000
# Iterasi 516: Skor Heuristik = 1570, Temperatur = 5.6510, Probabilitas = 0.0000
# Iterasi 517: Skor Heuristik = 1570, Temperatur = 5.5945, Probabilitas = 0.0000
# Iterasi 518: Skor Heuristik = 1570, Temperatur = 5.5385, Probabilitas = 0.0000
# Iterasi 519: Skor Heuristik = 1570, Temperatur = 5.4832, Probabilitas = 0.0000
# Iterasi 520: Skor Heuristik = 1570, Temperatur = 5.4283, Probabilitas = 0.0000
# Iterasi 521: Skor Heuristik = 1570, Temperatur = 5.3740, Probabilitas = 0.0000
# Iterasi 522: Skor Heuristik = 1570, Temperatur = 5.3203, Probabilitas = 1.0000
# Iterasi 523: Skor Heuristik = 1570, Temperatur = 5.2671, Probabilitas = 0.0000
# Iterasi 524: Skor Heuristik = 1566, Temperatur = 5.2144, Probabilitas = 1.0000
# Iterasi 525: Skor Heuristik = 1549, Temperatur = 5.1623, Probabilitas = 1.0000
# Iterasi 526: Skor Heuristik = 1549, Temperatur = 5.1107, Probabilitas = 0.0000
# Iterasi 527: Skor Heuristik = 1549, Temperatur = 5.0596, Probabilitas = 0.0000
# Iterasi 528: Skor Heuristik = 1549, Temperatur = 5.0090, Probabilitas = 0.0000
# Iterasi 529: Skor Heuristik = 1549, Temperatur = 4.9589, Probabilitas = 0.0000
# Iterasi 530: Skor Heuristik = 1549, Temperatur = 4.9093, Probabilitas = 0.0000
# Iterasi 531: Skor Heuristik = 1549, Temperatur = 4.8602, Probabilitas = 0.0000
# Iterasi 532: Skor Heuristik = 1549, Temperatur = 4.8116, Probabilitas = 0.0000
# Iterasi 533: Skor Heuristik = 1549, Temperatur = 4.7635, Probabilitas = 0.1225
# Iterasi 534: Skor Heuristik = 1549, Temperatur = 4.7158, Probabilitas = 0.0000
# Iterasi 535: Skor Heuristik = 1549, Temperatur = 4.6687, Probabilitas = 0.0000
# Iterasi 536: Skor Heuristik = 1549, Temperatur = 4.6220, Probabilitas = 0.0000
# Iterasi 537: Skor Heuristik = 1481, Temperatur = 4.5758, Probabilitas = 1.0000
# Iterasi 538: Skor Heuristik = 1481, Temperatur = 4.5300, Probabilitas = 0.0004
# Iterasi 539: Skor Heuristik = 1481, Temperatur = 4.4847, Probabilitas = 0.0000
# Iterasi 540: Skor Heuristik = 1481, Temperatur = 4.4399, Probabilitas = 0.0173
# Iterasi 541: Skor Heuristik = 1457, Temperatur = 4.3955, Probabilitas = 1.0000
# Iterasi 542: Skor Heuristik = 1445, Temperatur = 4.3515, Probabilitas = 1.0000
# Iterasi 543: Skor Heuristik = 1445, Temperatur = 4.3080, Probabilitas = 0.0000
# Iterasi 544: Skor Heuristik = 1445, Temperatur = 4.2649, Probabilitas = 0.0000
# Iterasi 545: Skor Heuristik = 1445, Temperatur = 4.2223, Probabilitas = 0.0000
# Iterasi 546: Skor Heuristik = 1436, Temperatur = 4.1800, Probabilitas = 1.0000
# Iterasi 547: Skor Heuristik = 1434, Temperatur = 4.1382, Probabilitas = 1.0000
# Iterasi 548: Skor Heuristik = 1434, Temperatur = 4.0969, Probabilitas = 0.0000
# Iterasi 549: Skor Heuristik = 1434, Temperatur = 4.0559, Probabilitas = 0.0000
# Iterasi 550: Skor Heuristik = 1434, Temperatur = 4.0153, Probabilitas = 0.0000
# Iterasi 551: Skor Heuristik = 1436, Temperatur = 3.9752, Probabilitas = 0.6046
# Iterasi 552: Skor Heuristik = 1436, Temperatur = 3.9354, Probabilitas = 0.0000
# Iterasi 553: Skor Heuristik = 1402, Temperatur = 3.8961, Probabilitas = 1.0000
# Iterasi 554: Skor Heuristik = 1406, Temperatur = 3.8571, Probabilitas = 0.3545
# Iterasi 555: Skor Heuristik = 1406, Temperatur = 3.8185, Probabilitas = 0.0004
# Iterasi 556: Skor Heuristik = 1406, Temperatur = 3.7804, Probabilitas = 0.0000
# Iterasi 557: Skor Heuristik = 1406, Temperatur = 3.7426, Probabilitas = 0.0000
# Iterasi 558: Skor Heuristik = 1406, Temperatur = 3.7051, Probabilitas = 0.0000
# Iterasi 559: Skor Heuristik = 1406, Temperatur = 3.6681, Probabilitas = 0.0000
# Iterasi 560: Skor Heuristik = 1406, Temperatur = 3.6314, Probabilitas = 0.0000
# Iterasi 561: Skor Heuristik = 1406, Temperatur = 3.5951, Probabilitas = 0.0004
# Iterasi 562: Skor Heuristik = 1406, Temperatur = 3.5591, Probabilitas = 0.0000
# Iterasi 563: Skor Heuristik = 1406, Temperatur = 3.5235, Probabilitas = 0.0000
# Iterasi 564: Skor Heuristik = 1406, Temperatur = 3.4883, Probabilitas = 0.0000
# Iterasi 565: Skor Heuristik = 1406, Temperatur = 3.4534, Probabilitas = 0.0000
# Iterasi 566: Skor Heuristik = 1372, Temperatur = 3.4189, Probabilitas = 1.0000
# Iterasi 567: Skor Heuristik = 1362, Temperatur = 3.3847, Probabilitas = 1.0000
# Iterasi 568: Skor Heuristik = 1362, Temperatur = 3.3509, Probabilitas = 0.0000
# Iterasi 569: Skor Heuristik = 1362, Temperatur = 3.3173, Probabilitas = 0.0000
# Iterasi 570: Skor Heuristik = 1362, Temperatur = 3.2842, Probabilitas = 0.1609
# Iterasi 571: Skor Heuristik = 1362, Temperatur = 3.2513, Probabilitas = 0.0135
# Iterasi 572: Skor Heuristik = 1362, Temperatur = 3.2188, Probabilitas = 0.0015
# Iterasi 573: Skor Heuristik = 1362, Temperatur = 3.1866, Probabilitas = 0.0000
# Iterasi 574: Skor Heuristik = 1362, Temperatur = 3.1548, Probabilitas = 0.0000
# Iterasi 575: Skor Heuristik = 1362, Temperatur = 3.1232, Probabilitas = 0.0000
# Iterasi 576: Skor Heuristik = 1362, Temperatur = 3.0920, Probabilitas = 0.0000
# Iterasi 577: Skor Heuristik = 1362, Temperatur = 3.0611, Probabilitas = 0.0000
# Iterasi 578: Skor Heuristik = 1362, Temperatur = 3.0305, Probabilitas = 0.0000
# Iterasi 579: Skor Heuristik = 1362, Temperatur = 3.0001, Probabilitas = 0.0000
# Iterasi 580: Skor Heuristik = 1362, Temperatur = 2.9701, Probabilitas = 0.0000
# Iterasi 581: Skor Heuristik = 1366, Temperatur = 2.9404, Probabilitas = 0.2566
# Iterasi 582: Skor Heuristik = 1366, Temperatur = 2.9110, Probabilitas = 0.0000
# Iterasi 583: Skor Heuristik = 1366, Temperatur = 2.8819, Probabilitas = 0.0000
# Iterasi 584: Skor Heuristik = 1366, Temperatur = 2.8531, Probabilitas = 0.0037
# Iterasi 585: Skor Heuristik = 1366, Temperatur = 2.8246, Probabilitas = 0.0000
# Iterasi 586: Skor Heuristik = 1366, Temperatur = 2.7963, Probabilitas = 0.0008
# Iterasi 587: Skor Heuristik = 1366, Temperatur = 2.7684, Probabilitas = 0.0000
# Iterasi 588: Skor Heuristik = 1366, Temperatur = 2.7407, Probabilitas = 0.0000
# Iterasi 589: Skor Heuristik = 1369, Temperatur = 2.7133, Probabilitas = 0.3310
# Iterasi 590: Skor Heuristik = 1369, Temperatur = 2.6861, Probabilitas = 0.0000
# Iterasi 591: Skor Heuristik = 1369, Temperatur = 2.6593, Probabilitas = 0.0000
# Iterasi 592: Skor Heuristik = 1369, Temperatur = 2.6327, Probabilitas = 0.0479
# Iterasi 593: Skor Heuristik = 1369, Temperatur = 2.6064, Probabilitas = 0.0000
# Iterasi 594: Skor Heuristik = 1369, Temperatur = 2.5803, Probabilitas = 0.0000
# Iterasi 595: Skor Heuristik = 1369, Temperatur = 2.5545, Probabilitas = 0.0000
# Iterasi 596: Skor Heuristik = 1369, Temperatur = 2.5290, Probabilitas = 0.0000
# Iterasi 597: Skor Heuristik = 1369, Temperatur = 2.5037, Probabilitas = 0.0000
# Iterasi 598: Skor Heuristik = 1369, Temperatur = 2.4786, Probabilitas = 0.0594
# Iterasi 599: Skor Heuristik = 1369, Temperatur = 2.4538, Probabilitas = 0.0000
# Iterasi 600: Skor Heuristik = 1349, Temperatur = 2.4293, Probabilitas = 1.0000
# ...
# Iterasi 1191: Skor Heuristik = 994, Temperatur = 0.0064, Probabilitas = 0.0000
# Iterasi 1192: Skor Heuristik = 994, Temperatur = 0.0063, Probabilitas = 0.0000
# Iterasi 1193: Skor Heuristik = 994, Temperatur = 0.0063, Probabilitas = 0.0000
# Iterasi 1194: Skor Heuristik = 994, Temperatur = 0.0062, Probabilitas = 0.0000
# Iterasi 1195: Skor Heuristik = 994, Temperatur = 0.0061, Probabilitas = 0.0000
# Iterasi 1196: Skor Heuristik = 994, Temperatur = 0.0061, Probabilitas = 0.0000
# Iterasi 1197: Skor Heuristik = 994, Temperatur = 0.0060, Probabilitas = 0.0000
# Iterasi 1198: Skor Heuristik = 994, Temperatur = 0.0060, Probabilitas = 0.0000
# Iterasi 1199: Skor Heuristik = 994, Temperatur = 0.0059, Probabilitas = 0.0000
# Iterasi 1200: Skor Heuristik = 994, Temperatur = 0.0058, Probabilitas = 0.0000
# Iterasi 1201: Skor Heuristik = 994, Temperatur = 0.0058, Probabilitas = 0.0000
# Iterasi 1202: Skor Heuristik = 994, Temperatur = 0.0057, Probabilitas = 0.0000
# Iterasi 1203: Skor Heuristik = 994, Temperatur = 0.0057, Probabilitas = 0.0000
# Iterasi 1204: Skor Heuristik = 994, Temperatur = 0.0056, Probabilitas = 0.0000
# Iterasi 1205: Skor Heuristik = 994, Temperatur = 0.0056, Probabilitas = 0.0000
# Iterasi 1206: Skor Heuristik = 994, Temperatur = 0.0055, Probabilitas = 0.0000
# Iterasi 1207: Skor Heuristik = 994, Temperatur = 0.0054, Probabilitas = 0.0000
# Iterasi 1208: Skor Heuristik = 994, Temperatur = 0.0054, Probabilitas = 0.0000
# Iterasi 1209: Skor Heuristik = 982, Temperatur = 0.0053, Probabilitas = 1.0000
# Iterasi 1210: Skor Heuristik = 982, Temperatur = 0.0053, Probabilitas = 0.0000
# Iterasi 1211: Skor Heuristik = 982, Temperatur = 0.0052, Probabilitas = 1.0000
# Iterasi 1212: Skor Heuristik = 982, Temperatur = 0.0052, Probabilitas = 0.0000
# Iterasi 1213: Skor Heuristik = 982, Temperatur = 0.0051, Probabilitas = 0.0000
# Iterasi 1214: Skor Heuristik = 982, Temperatur = 0.0051, Probabilitas = 0.0000
# Iterasi 1215: Skor Heuristik = 982, Temperatur = 0.0050, Probabilitas = 0.0000
# Iterasi 1216: Skor Heuristik = 982, Temperatur = 0.0050, Probabilitas = 0.0000
# Iterasi 1217: Skor Heuristik = 982, Temperatur = 0.0049, Probabilitas = 0.0000
# Iterasi 1218: Skor Heuristik = 982, Temperatur = 0.0049, Probabilitas = 0.0000
# Iterasi 1219: Skor Heuristik = 982, Temperatur = 0.0048, Probabilitas = 0.0000
# Iterasi 1220: Skor Heuristik = 982, Temperatur = 0.0048, Probabilitas = 0.0000
# Iterasi 1221: Skor Heuristik = 982, Temperatur = 0.0047, Probabilitas = 0.0000
# Iterasi 1222: Skor Heuristik = 982, Temperatur = 0.0047, Probabilitas = 0.0000
# Iterasi 1223: Skor Heuristik = 982, Temperatur = 0.0046, Probabilitas = 0.0000
# Iterasi 1224: Skor Heuristik = 982, Temperatur = 0.0046, Probabilitas = 0.0000
# Iterasi 1225: Skor Heuristik = 982, Temperatur = 0.0045, Probabilitas = 0.0000
# Iterasi 1226: Skor Heuristik = 982, Temperatur = 0.0045, Probabilitas = 0.0000
# Iterasi 1227: Skor Heuristik = 982, Temperatur = 0.0045, Probabilitas = 0.0000
# Iterasi 1228: Skor Heuristik = 982, Temperatur = 0.0044, Probabilitas = 0.0000
# Iterasi 1229: Skor Heuristik = 982, Temperatur = 0.0044, Probabilitas = 0.0000
# Iterasi 1230: Skor Heuristik = 982, Temperatur = 0.0043, Probabilitas = 0.0000
# Iterasi 1231: Skor Heuristik = 982, Temperatur = 0.0043, Probabilitas = 0.0000
# Iterasi 1232: Skor Heuristik = 982, Temperatur = 0.0042, Probabilitas = 0.0000
# Iterasi 1233: Skor Heuristik = 982, Temperatur = 0.0042, Probabilitas = 0.0000
# Iterasi 1234: Skor Heuristik = 976, Temperatur = 0.0042, Probabilitas = 1.0000
# Iterasi 1235: Skor Heuristik = 976, Temperatur = 0.0041, Probabilitas = 0.0000
# Iterasi 1236: Skor Heuristik = 976, Temperatur = 0.0041, Probabilitas = 0.0000
# Iterasi 1237: Skor Heuristik = 976, Temperatur = 0.0040, Probabilitas = 0.0000
# Iterasi 1238: Skor Heuristik = 976, Temperatur = 0.0040, Probabilitas = 0.0000
# Iterasi 1239: Skor Heuristik = 976, Temperatur = 0.0039, Probabilitas = 0.0000
# Iterasi 1240: Skor Heuristik = 976, Temperatur = 0.0039, Probabilitas = 0.0000
# Iterasi 1241: Skor Heuristik = 976, Temperatur = 0.0039, Probabilitas = 0.0000
# Iterasi 1242: Skor Heuristik = 976, Temperatur = 0.0038, Probabilitas = 1.0000
# Iterasi 1243: Skor Heuristik = 976, Temperatur = 0.0038, Probabilitas = 0.0000
# Iterasi 1244: Skor Heuristik = 976, Temperatur = 0.0038, Probabilitas = 0.0000
# Iterasi 1245: Skor Heuristik = 976, Temperatur = 0.0037, Probabilitas = 0.0000
# Iterasi 1246: Skor Heuristik = 976, Temperatur = 0.0037, Probabilitas = 0.0000
# Iterasi 1247: Skor Heuristik = 976, Temperatur = 0.0036, Probabilitas = 0.0000
# Iterasi 1248: Skor Heuristik = 976, Temperatur = 0.0036, Probabilitas = 0.0000
# Iterasi 1249: Skor Heuristik = 976, Temperatur = 0.0036, Probabilitas = 0.0000
# Iterasi 1250: Skor Heuristik = 976, Temperatur = 0.0035, Probabilitas = 0.0000
# Iterasi 1251: Skor Heuristik = 976, Temperatur = 0.0035, Probabilitas = 0.0000
# Iterasi 1252: Skor Heuristik = 976, Temperatur = 0.0035, Probabilitas = 0.0000
# Iterasi 1253: Skor Heuristik = 976, Temperatur = 0.0034, Probabilitas = 0.0000
# Iterasi 1254: Skor Heuristik = 976, Temperatur = 0.0034, Probabilitas = 0.0000
# Iterasi 1255: Skor Heuristik = 976, Temperatur = 0.0034, Probabilitas = 0.0000
# Iterasi 1256: Skor Heuristik = 976, Temperatur = 0.0033, Probabilitas = 0.0000
# Iterasi 1257: Skor Heuristik = 976, Temperatur = 0.0033, Probabilitas = 0.0000
# Iterasi 1258: Skor Heuristik = 976, Temperatur = 0.0033, Probabilitas = 0.0000
# Iterasi 1259: Skor Heuristik = 976, Temperatur = 0.0032, Probabilitas = 0.0000
# Iterasi 1260: Skor Heuristik = 976, Temperatur = 0.0032, Probabilitas = 0.0000
# Iterasi 1261: Skor Heuristik = 976, Temperatur = 0.0032, Probabilitas = 0.0000
# Iterasi 1262: Skor Heuristik = 976, Temperatur = 0.0031, Probabilitas = 0.0000
# Iterasi 1263: Skor Heuristik = 976, Temperatur = 0.0031, Probabilitas = 0.0000
# Iterasi 1264: Skor Heuristik = 976, Temperatur = 0.0031, Probabilitas = 0.0000
# Iterasi 1265: Skor Heuristik = 976, Temperatur = 0.0030, Probabilitas = 0.0000
# Iterasi 1266: Skor Heuristik = 976, Temperatur = 0.0030, Probabilitas = 0.0000
# Iterasi 1267: Skor Heuristik = 976, Temperatur = 0.0030, Probabilitas = 0.0000
# Iterasi 1268: Skor Heuristik = 976, Temperatur = 0.0029, Probabilitas = 0.0000
# Iterasi 1269: Skor Heuristik = 976, Temperatur = 0.0029, Probabilitas = 0.0000
# Iterasi 1270: Skor Heuristik = 976, Temperatur = 0.0029, Probabilitas = 0.0000
# Iterasi 1271: Skor Heuristik = 976, Temperatur = 0.0029, Probabilitas = 0.0000
# Iterasi 1272: Skor Heuristik = 976, Temperatur = 0.0028, Probabilitas = 0.0000
# Iterasi 1273: Skor Heuristik = 976, Temperatur = 0.0028, Probabilitas = 0.0000
# Iterasi 1274: Skor Heuristik = 976, Temperatur = 0.0028, Probabilitas = 0.0000
# Iterasi 1275: Skor Heuristik = 976, Temperatur = 0.0027, Probabilitas = 0.0000
# Iterasi 1276: Skor Heuristik = 976, Temperatur = 0.0027, Probabilitas = 0.0000
# Iterasi 1277: Skor Heuristik = 976, Temperatur = 0.0027, Probabilitas = 0.0000
# Iterasi 1278: Skor Heuristik = 976, Temperatur = 0.0027, Probabilitas = 0.0000
# Iterasi 1279: Skor Heuristik = 976, Temperatur = 0.0026, Probabilitas = 0.0000
# Iterasi 1280: Skor Heuristik = 976, Temperatur = 0.0026, Probabilitas = 0.0000
# Iterasi 1281: Skor Heuristik = 976, Temperatur = 0.0026, Probabilitas = 0.0000
# Iterasi 1282: Skor Heuristik = 976, Temperatur = 0.0026, Probabilitas = 1.0000
# Iterasi 1283: Skor Heuristik = 976, Temperatur = 0.0025, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1284 dengan skor 976
# Iterasi 1284: Skor Heuristik = 976, Temperatur = 0.0025, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1285 dengan skor 976
# Iterasi 1285: Skor Heuristik = 976, Temperatur = 0.0025, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1286 dengan skor 976
# Iterasi 1286: Skor Heuristik = 976, Temperatur = 0.0025, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1287 dengan skor 976
# Iterasi 1287: Skor Heuristik = 976, Temperatur = 0.0024, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1288 dengan skor 976
# Iterasi 1288: Skor Heuristik = 976, Temperatur = 0.0024, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1289 dengan skor 976
# Iterasi 1289: Skor Heuristik = 976, Temperatur = 0.0024, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1290 dengan skor 976
# Iterasi 1290: Skor Heuristik = 976, Temperatur = 0.0024, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1291 dengan skor 976
# Iterasi 1291: Skor Heuristik = 976, Temperatur = 0.0023, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1292 dengan skor 976
# Iterasi 1292: Skor Heuristik = 976, Temperatur = 0.0023, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1293 dengan skor 976
# Iterasi 1293: Skor Heuristik = 976, Temperatur = 0.0023, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1294 dengan skor 976
# Iterasi 1294: Skor Heuristik = 976, Temperatur = 0.0023, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1295 dengan skor 976
# Iterasi 1295: Skor Heuristik = 976, Temperatur = 0.0022, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1296 dengan skor 976
# Iterasi 1296: Skor Heuristik = 976, Temperatur = 0.0022, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1297 dengan skor 976
# Iterasi 1297: Skor Heuristik = 976, Temperatur = 0.0022, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1298 dengan skor 976
# Iterasi 1298: Skor Heuristik = 976, Temperatur = 0.0022, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1299 dengan skor 976
# Iterasi 1299: Skor Heuristik = 976, Temperatur = 0.0022, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1300 dengan skor 976
# Iterasi 1300: Skor Heuristik = 976, Temperatur = 0.0021, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1301 dengan skor 976
# Iterasi 1301: Skor Heuristik = 976, Temperatur = 0.0021, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1302 dengan skor 976
# Iterasi 1302: Skor Heuristik = 976, Temperatur = 0.0021, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1303 dengan skor 976
# Iterasi 1303: Skor Heuristik = 976, Temperatur = 0.0021, Probabilitas = 1.0000
# Stuck di local optima pada iterasi 1304 dengan skor 976
# Iterasi 1304: Skor Heuristik = 976, Temperatur = 0.0021, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1305 dengan skor 976
# Iterasi 1305: Skor Heuristik = 976, Temperatur = 0.0020, Probabilitas = 0.0000
# Stuck di local optima pada iterasi 1306 dengan skor 976
# Iterasi 1306: Skor Heuristik = 976, Temperatur = 0.0020, Probabilitas = 0.0000
# Iterasi 1307: Skor Heuristik = 967, Temperatur = 0.0020, Probabilitas = 1.0000
# Iterasi 1308: Skor Heuristik = 967, Temperatur = 0.0020, Probabilitas = 0.0000
# Iterasi 1309: Skor Heuristik = 961, Temperatur = 0.0020, Probabilitas = 1.0000
# Iterasi 1310: Skor Heuristik = 961, Temperatur = 0.0019, Probabilitas = 0.0000
# Iterasi 1311: Skor Heuristik = 961, Temperatur = 0.0019, Probabilitas = 0.0000
# Iterasi 1312: Skor Heuristik = 961, Temperatur = 0.0019, Probabilitas = 0.0000
# Iterasi 1313: Skor Heuristik = 961, Temperatur = 0.0019, Probabilitas = 0.0000
# Iterasi 1314: Skor Heuristik = 961, Temperatur = 0.0019, Probabilitas = 0.0000
# Iterasi 1315: Skor Heuristik = 961, Temperatur = 0.0018, Probabilitas = 0.0000
# Iterasi 1316: Skor Heuristik = 961, Temperatur = 0.0018, Probabilitas = 0.0000
# Iterasi 1317: Skor Heuristik = 961, Temperatur = 0.0018, Probabilitas = 0.0000
# Iterasi 1318: Skor Heuristik = 961, Temperatur = 0.0018, Probabilitas = 0.0000
# Iterasi 1319: Skor Heuristik = 961, Temperatur = 0.0018, Probabilitas = 0.0000
# Iterasi 1320: Skor Heuristik = 961, Temperatur = 0.0017, Probabilitas = 0.0000
# Iterasi 1321: Skor Heuristik = 961, Temperatur = 0.0017, Probabilitas = 0.0000
# Iterasi 1322: Skor Heuristik = 961, Temperatur = 0.0017, Probabilitas = 0.0000
# Iterasi 1323: Skor Heuristik = 961, Temperatur = 0.0017, Probabilitas = 0.0000
# Iterasi 1324: Skor Heuristik = 961, Temperatur = 0.0017, Probabilitas = 0.0000
# Iterasi 1325: Skor Heuristik = 961, Temperatur = 0.0017, Probabilitas = 0.0000
# Iterasi 1326: Skor Heuristik = 961, Temperatur = 0.0016, Probabilitas = 0.0000
# Iterasi 1327: Skor Heuristik = 961, Temperatur = 0.0016, Probabilitas = 0.0000
# Iterasi 1328: Skor Heuristik = 961, Temperatur = 0.0016, Probabilitas = 0.0000
# Iterasi 1329: Skor Heuristik = 961, Temperatur = 0.0016, Probabilitas = 0.0000
# Iterasi 1330: Skor Heuristik = 961, Temperatur = 0.0016, Probabilitas = 0.0000
# Iterasi 1331: Skor Heuristik = 961, Temperatur = 0.0016, Probabilitas = 0.0000
# Iterasi 1332: Skor Heuristik = 961, Temperatur = 0.0016, Probabilitas = 0.0000
# Iterasi 1333: Skor Heuristik = 961, Temperatur = 0.0015, Probabilitas = 0.0000
# Iterasi 1334: Skor Heuristik = 961, Temperatur = 0.0015, Probabilitas = 0.0000
# Iterasi 1335: Skor Heuristik = 961, Temperatur = 0.0015, Probabilitas = 0.0000
# Iterasi 1336: Skor Heuristik = 961, Temperatur = 0.0015, Probabilitas = 0.0000
# Iterasi 1337: Skor Heuristik = 961, Temperatur = 0.0015, Probabilitas = 0.0000
# Iterasi 1338: Skor Heuristik = 949, Temperatur = 0.0015, Probabilitas = 1.0000
# Iterasi 1339: Skor Heuristik = 949, Temperatur = 0.0014, Probabilitas = 0.0000
# Iterasi 1340: Skor Heuristik = 949, Temperatur = 0.0014, Probabilitas = 0.0000
# Iterasi 1341: Skor Heuristik = 949, Temperatur = 0.0014, Probabilitas = 0.0000
# Iterasi 1342: Skor Heuristik = 949, Temperatur = 0.0014, Probabilitas = 0.0000
# Iterasi 1343: Skor Heuristik = 949, Temperatur = 0.0014, Probabilitas = 0.0000
# Iterasi 1344: Skor Heuristik = 949, Temperatur = 0.0014, Probabilitas = 0.0000
# Iterasi 1345: Skor Heuristik = 949, Temperatur = 0.0014, Probabilitas = 0.0000
# Iterasi 1346: Skor Heuristik = 949, Temperatur = 0.0013, Probabilitas = 0.0000
# Iterasi 1347: Skor Heuristik = 949, Temperatur = 0.0013, Probabilitas = 0.0000
# Iterasi 1348: Skor Heuristik = 949, Temperatur = 0.0013, Probabilitas = 0.0000
# Iterasi 1349: Skor Heuristik = 949, Temperatur = 0.0013, Probabilitas = 0.0000
# Iterasi 1350: Skor Heuristik = 949, Temperatur = 0.0013, Probabilitas = 0.0000
# Iterasi 1351: Skor Heuristik = 949, Temperatur = 0.0013, Probabilitas = 0.0000
# Iterasi 1352: Skor Heuristik = 949, Temperatur = 0.0013, Probabilitas = 0.0000
# Iterasi 1353: Skor Heuristik = 949, Temperatur = 0.0013, Probabilitas = 0.0000
# Iterasi 1354: Skor Heuristik = 949, Temperatur = 0.0012, Probabilitas = 0.0000
# Iterasi 1355: Skor Heuristik = 949, Temperatur = 0.0012, Probabilitas = 0.0000
# Iterasi 1356: Skor Heuristik = 949, Temperatur = 0.0012, Probabilitas = 0.0000
# Iterasi 1357: Skor Heuristik = 949, Temperatur = 0.0012, Probabilitas = 0.0000
# Iterasi 1358: Skor Heuristik = 949, Temperatur = 0.0012, Probabilitas = 0.0000
# Iterasi 1359: Skor Heuristik = 949, Temperatur = 0.0012, Probabilitas = 0.0000
# Iterasi 1360: Skor Heuristik = 949, Temperatur = 0.0012, Probabilitas = 0.0000
# Iterasi 1361: Skor Heuristik = 949, Temperatur = 0.0012, Probabilitas = 0.0000
# Iterasi 1362: Skor Heuristik = 949, Temperatur = 0.0011, Probabilitas = 0.0000
# Iterasi 1363: Skor Heuristik = 949, Temperatur = 0.0011, Probabilitas = 0.0000
# Iterasi 1364: Skor Heuristik = 949, Temperatur = 0.0011, Probabilitas = 0.0000
# Iterasi 1365: Skor Heuristik = 949, Temperatur = 0.0011, Probabilitas = 0.0000
# Iterasi 1366: Skor Heuristik = 949, Temperatur = 0.0011, Probabilitas = 0.0000
# Iterasi 1367: Skor Heuristik = 937, Temperatur = 0.0011, Probabilitas = 1.0000
# Iterasi 1368: Skor Heuristik = 937, Temperatur = 0.0011, Probabilitas = 0.0000
# Iterasi 1369: Skor Heuristik = 937, Temperatur = 0.0011, Probabilitas = 0.0000
# Iterasi 1370: Skor Heuristik = 937, Temperatur = 0.0011, Probabilitas = 0.0000
# Iterasi 1371: Skor Heuristik = 937, Temperatur = 0.0010, Probabilitas = 0.0000
# Iterasi 1372: Skor Heuristik = 937, Temperatur = 0.0010, Probabilitas = 0.0000
# Iterasi 1373: Skor Heuristik = 937, Temperatur = 0.0010, Probabilitas = 0.0000
# Iterasi 1374: Skor Heuristik = 937, Temperatur = 0.0010, Probabilitas = 0.0000
# Iterasi 1375: Skor Heuristik = 937, Temperatur = 0.0010, Probabilitas = 0.0000
# Waktu yang dibutuhkan: 12.627627611160278 detik
# Total frekuensi stuck di local optima: 161

# %%
plot_cube(final_state, f"Final State of the Cube (Score: {final_score})")

# %%
# Plotting hasil objective function dan probabilitas
main.plot_objective_function()
