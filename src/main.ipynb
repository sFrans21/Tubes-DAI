# %% [markdown]
# # MAIN PROGRAM UNTUK SEMUA ALGORITMA

# %% [markdown]
# ### Kubus akan di generate dari lapisan bawah ke lapisan atas. Jadi bayangkan saja layer1 ditumpuk layer2 ditumpuk layer3 dan seterusnya

# %%
from cube.visual import plot_cube
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Steepest Ascendt Hill Climbing

# %%
from algorithms.SteepestHillClimb import SteepestHillClimbing

# %%
main = SteepestHillClimbing(max_iterations=100)
initial_state = main.initial_state
initial_score = main.objective_function


# Visualisasi kondisi awal
plot_cube(initial_state, f"Initial State of the Cube (Score: {initial_score})")

# %%
final_state, final_score, execution_time, history, iteration_count = main.search()
# Out:
# Iterasi 1: Skor sekarang = 3550
# Iterasi 2: Skor sekarang = 3212
# Iterasi 3: Skor sekarang = 2918
# Iterasi 4: Skor sekarang = 2670
# Iterasi 5: Skor sekarang = 2490
# Iterasi 6: Skor sekarang = 2324
# Iterasi 7: Skor sekarang = 2124
# Iterasi 8: Skor sekarang = 2031
# Iterasi 9: Skor sekarang = 1820
# Iterasi 10: Skor sekarang = 1710
# Iterasi 11: Skor sekarang = 1638
# Iterasi 12: Skor sekarang = 1554
# Iterasi 13: Skor sekarang = 1492
# Iterasi 14: Skor sekarang = 1452
# Iterasi 15: Skor sekarang = 1393
# Iterasi 16: Skor sekarang = 1335
# Iterasi 17: Skor sekarang = 1230
# Iterasi 18: Skor sekarang = 1195
# Iterasi 19: Skor sekarang = 1165
# Iterasi 20: Skor sekarang = 1099
# Iterasi 21: Skor sekarang = 1063
# Iterasi 22: Skor sekarang = 1042
# Iterasi 23: Skor sekarang = 1020
# Iterasi 24: Skor sekarang = 1002
# Iterasi 25: Skor sekarang = 984
# Iterasi 26: Skor sekarang = 968
# Iterasi 27: Skor sekarang = 946
# Iterasi 28: Skor sekarang = 866
# Iterasi 29: Skor sekarang = 821
# Iterasi 30: Skor sekarang = 805
# Iterasi 31: Skor sekarang = 792
# Iterasi 32: Skor sekarang = 782
# Iterasi 33: Skor sekarang = 773
# Iterasi 34: Skor sekarang = 757
# Iterasi 35: Skor sekarang = 730
# Iterasi 36: Skor sekarang = 718
# Iterasi 37: Skor sekarang = 710
# Iterasi 38: Skor sekarang = 705
# Iterasi 39: Skor sekarang = 700
# Iterasi 40: Skor sekarang = 694
# Iterasi 41: Skor sekarang = 683
# Iterasi 42: Skor sekarang = 673
# Iterasi 43: Skor sekarang = 664
# Iterasi 44: Skor sekarang = 659
# Iterasi 45: Skor sekarang = 653
# Iterasi 46: Skor sekarang = 647
# Iterasi 47: Skor sekarang = 639
# Iterasi 48: Skor sekarang = 633
# Iterasi 49: Skor sekarang = 629
# Iterasi 50: Skor sekarang = 625
# Iterasi 51: Skor sekarang = 621
# Iterasi 52: Skor sekarang = 618
# Iterasi 53: Skor sekarang = 616
# Iterasi 54: Skor sekarang = 614
# Iterasi 55: Skor sekarang = 610

# %%
# Visualisasi kondisi akhir
plot_cube(final_state, f"Final State of the Cube (Score: {final_score}, Time: {execution_time:.2f} seconds, Iteration: {iteration_count-1})")

# %%
# Visualisasi skor tiap iterasi
plt.plot(history)
plt.xlabel('Iteration')
plt.ylabel('Score')
plt.title('Score per Iteration')
plt.show()

# %% [markdown]
# 2. Simulated Annealing

# %%
import sys
import os

# Menambahkan folder root proyek ke sys.path
sys.path.append(os.path.abspath(".."))

from algorithms.simulated_annealing import SimulatedAnnealing
from cube.visual import plot_cube

# %%
main = SimulatedAnnealing(initial_temperature=1000, cooling_rate=0.99, temperature_threshold=0.001, stagnation_threshold=50)
initial_state = main.initial_state
initial_score = main.objective_function

# %%
# Visualisasi kondisi awal
plot_cube(initial_state, f"Initial State of the Cube (Score: {initial_score})")

# %%
# Menjalankan pencarian lokal
final_state, final_score = main.search()
# Out:
# Iterasi 1: Skor Heuristik = 4915, Temperatur = 1000.0000, Probabilitas = 0.9399
# Iterasi 2: Skor Heuristik = 4954, Temperatur = 990.0000, Probabilitas = 0.9614
# Iterasi 3: Skor Heuristik = 4710, Temperatur = 980.1000, Probabilitas = 1.0000
# Iterasi 4: Skor Heuristik = 4691, Temperatur = 970.2990, Probabilitas = 1.0000
# Iterasi 5: Skor Heuristik = 4579, Temperatur = 960.5960, Probabilitas = 1.0000
# Iterasi 6: Skor Heuristik = 4737, Temperatur = 950.9900, Probabilitas = 0.8469
# Iterasi 7: Skor Heuristik = 4807, Temperatur = 941.4801, Probabilitas = 0.9283
# Iterasi 8: Skor Heuristik = 4768, Temperatur = 932.0653, Probabilitas = 1.0000
# Iterasi 9: Skor Heuristik = 4779, Temperatur = 922.7447, Probabilitas = 0.9881
# Iterasi 10: Skor Heuristik = 4833, Temperatur = 913.5172, Probabilitas = 0.9426
# Iterasi 11: Skor Heuristik = 4801, Temperatur = 904.3821, Probabilitas = 1.0000
# Iterasi 12: Skor Heuristik = 4599, Temperatur = 895.3383, Probabilitas = 1.0000
# Iterasi 13: Skor Heuristik = 4659, Temperatur = 886.3849, Probabilitas = 0.9345
# Iterasi 14: Skor Heuristik = 4585, Temperatur = 877.5210, Probabilitas = 1.0000
# Iterasi 15: Skor Heuristik = 4754, Temperatur = 868.7458, Probabilitas = 0.8232
# Iterasi 16: Skor Heuristik = 4778, Temperatur = 860.0584, Probabilitas = 0.9725
# Iterasi 17: Skor Heuristik = 4814, Temperatur = 851.4578, Probabilitas = 0.9586
# Iterasi 18: Skor Heuristik = 4814, Temperatur = 842.9432, Probabilitas = 1.0000
# Iterasi 19: Skor Heuristik = 4736, Temperatur = 834.5138, Probabilitas = 1.0000
# Iterasi 20: Skor Heuristik = 4736, Temperatur = 826.1686, Probabilitas = 0.9044
# Iterasi 21: Skor Heuristik = 4632, Temperatur = 817.9069, Probabilitas = 1.0000
# Iterasi 22: Skor Heuristik = 4396, Temperatur = 809.7279, Probabilitas = 1.0000
# Iterasi 23: Skor Heuristik = 4557, Temperatur = 801.6306, Probabilitas = 0.8180
# Iterasi 24: Skor Heuristik = 4577, Temperatur = 793.6143, Probabilitas = 0.9751
# Iterasi 25: Skor Heuristik = 4533, Temperatur = 785.6781, Probabilitas = 1.0000
# Iterasi 26: Skor Heuristik = 3882, Temperatur = 777.8214, Probabilitas = 1.0000
# Iterasi 27: Skor Heuristik = 3874, Temperatur = 770.0431, Probabilitas = 1.0000
# Iterasi 28: Skor Heuristik = 3848, Temperatur = 762.3427, Probabilitas = 1.0000
# Iterasi 29: Skor Heuristik = 3926, Temperatur = 754.7193, Probabilitas = 0.9018
# Iterasi 30: Skor Heuristik = 3926, Temperatur = 747.1721, Probabilitas = 1.0000
# Iterasi 31: Skor Heuristik = 3945, Temperatur = 739.7004, Probabilitas = 0.9746
# Iterasi 32: Skor Heuristik = 4038, Temperatur = 732.3034, Probabilitas = 0.8807
# Iterasi 33: Skor Heuristik = 4038, Temperatur = 724.9803, Probabilitas = 0.4182
# Iterasi 34: Skor Heuristik = 3954, Temperatur = 717.7305, Probabilitas = 1.0000
# Iterasi 35: Skor Heuristik = 3850, Temperatur = 710.5532, Probabilitas = 1.0000
# Iterasi 36: Skor Heuristik = 3850, Temperatur = 703.4477, Probabilitas = 0.8565
# Iterasi 37: Skor Heuristik = 3970, Temperatur = 696.4132, Probabilitas = 0.8417
# Iterasi 38: Skor Heuristik = 3990, Temperatur = 689.4491, Probabilitas = 0.9714
# Iterasi 39: Skor Heuristik = 3990, Temperatur = 682.5546, Probabilitas = 1.0000
# Iterasi 40: Skor Heuristik = 3935, Temperatur = 675.7290, Probabilitas = 1.0000
# Iterasi 41: Skor Heuristik = 3925, Temperatur = 668.9718, Probabilitas = 1.0000
# Iterasi 42: Skor Heuristik = 3959, Temperatur = 662.2820, Probabilitas = 0.9500
# Iterasi 43: Skor Heuristik = 3825, Temperatur = 655.6592, Probabilitas = 1.0000
# Iterasi 44: Skor Heuristik = 3799, Temperatur = 649.1026, Probabilitas = 1.0000
# Iterasi 45: Skor Heuristik = 3891, Temperatur = 642.6116, Probabilitas = 0.8666
# Iterasi 46: Skor Heuristik = 3987, Temperatur = 636.1855, Probabilitas = 0.8599
# Iterasi 47: Skor Heuristik = 3997, Temperatur = 629.8236, Probabilitas = 0.9842
# Iterasi 48: Skor Heuristik = 4026, Temperatur = 623.5254, Probabilitas = 0.9546
# Iterasi 49: Skor Heuristik = 3886, Temperatur = 617.2901, Probabilitas = 1.0000
# Iterasi 50: Skor Heuristik = 3890, Temperatur = 611.1172, Probabilitas = 0.9935
# Iterasi 51: Skor Heuristik = 3976, Temperatur = 605.0061, Probabilitas = 0.8675
# Iterasi 52: Skor Heuristik = 3980, Temperatur = 598.9560, Probabilitas = 0.9933
# Iterasi 53: Skor Heuristik = 3980, Temperatur = 592.9664, Probabilitas = 1.0000
# Iterasi 54: Skor Heuristik = 4074, Temperatur = 587.0368, Probabilitas = 0.8520
# Iterasi 55: Skor Heuristik = 4088, Temperatur = 581.1664, Probabilitas = 0.9762
# Iterasi 56: Skor Heuristik = 4164, Temperatur = 575.3547, Probabilitas = 0.8763
# Iterasi 57: Skor Heuristik = 4127, Temperatur = 569.6012, Probabilitas = 1.0000
# Iterasi 58: Skor Heuristik = 4011, Temperatur = 563.9052, Probabilitas = 1.0000
# Iterasi 59: Skor Heuristik = 4171, Temperatur = 558.2661, Probabilitas = 0.7508
# Iterasi 60: Skor Heuristik = 4171, Temperatur = 552.6835, Probabilitas = 1.0000
# Iterasi 61: Skor Heuristik = 4094, Temperatur = 547.1566, Probabilitas = 1.0000
# Iterasi 62: Skor Heuristik = 4154, Temperatur = 541.6851, Probabilitas = 0.8951
# Iterasi 63: Skor Heuristik = 4154, Temperatur = 536.2682, Probabilitas = 0.6204
# Iterasi 64: Skor Heuristik = 4154, Temperatur = 530.9055, Probabilitas = 1.0000
# Iterasi 65: Skor Heuristik = 4152, Temperatur = 525.5965, Probabilitas = 1.0000
# Iterasi 66: Skor Heuristik = 4122, Temperatur = 520.3405, Probabilitas = 1.0000
# Iterasi 67: Skor Heuristik = 4113, Temperatur = 515.1371, Probabilitas = 1.0000
# Iterasi 68: Skor Heuristik = 4168, Temperatur = 509.9857, Probabilitas = 0.8978
# Iterasi 69: Skor Heuristik = 3955, Temperatur = 504.8859, Probabilitas = 1.0000
# Iterasi 70: Skor Heuristik = 3961, Temperatur = 499.8370, Probabilitas = 0.9881
# Iterasi 71: Skor Heuristik = 3965, Temperatur = 494.8387, Probabilitas = 0.9919
# Iterasi 72: Skor Heuristik = 3761, Temperatur = 489.8903, Probabilitas = 1.0000
# Iterasi 73: Skor Heuristik = 3911, Temperatur = 484.9914, Probabilitas = 0.7340
# Iterasi 74: Skor Heuristik = 3911, Temperatur = 480.1415, Probabilitas = 1.0000
# Iterasi 75: Skor Heuristik = 3859, Temperatur = 475.3400, Probabilitas = 1.0000
# Iterasi 76: Skor Heuristik = 3851, Temperatur = 470.5866, Probabilitas = 1.0000
# Iterasi 77: Skor Heuristik = 3851, Temperatur = 465.8808, Probabilitas = 0.7630
# Iterasi 78: Skor Heuristik = 3851, Temperatur = 461.2220, Probabilitas = 1.0000
# Iterasi 79: Skor Heuristik = 3818, Temperatur = 456.6097, Probabilitas = 1.0000
# Iterasi 80: Skor Heuristik = 3826, Temperatur = 452.0437, Probabilitas = 0.9825
# Iterasi 81: Skor Heuristik = 3826, Temperatur = 447.5232, Probabilitas = 1.0000
# Iterasi 82: Skor Heuristik = 3826, Temperatur = 443.0480, Probabilitas = 1.0000
# Iterasi 83: Skor Heuristik = 3848, Temperatur = 438.6175, Probabilitas = 0.9511
# Iterasi 84: Skor Heuristik = 3824, Temperatur = 434.2313, Probabilitas = 1.0000
# Iterasi 85: Skor Heuristik = 3824, Temperatur = 429.8890, Probabilitas = 0.4908
# Iterasi 86: Skor Heuristik = 4364, Temperatur = 425.5901, Probabilitas = 0.2812
# Iterasi 87: Skor Heuristik = 4326, Temperatur = 421.3342, Probabilitas = 1.0000
# Iterasi 88: Skor Heuristik = 4342, Temperatur = 417.1209, Probabilitas = 0.9624
# Iterasi 89: Skor Heuristik = 4386, Temperatur = 412.9497, Probabilitas = 0.8989
# Iterasi 90: Skor Heuristik = 4234, Temperatur = 408.8202, Probabilitas = 1.0000
# Iterasi 91: Skor Heuristik = 4264, Temperatur = 404.7320, Probabilitas = 0.9286
# Iterasi 92: Skor Heuristik = 4178, Temperatur = 400.6847, Probabilitas = 1.0000
# Iterasi 93: Skor Heuristik = 4267, Temperatur = 396.6778, Probabilitas = 0.7990
# Iterasi 94: Skor Heuristik = 4267, Temperatur = 392.7110, Probabilitas = 1.0000
# Iterasi 95: Skor Heuristik = 4189, Temperatur = 388.7839, Probabilitas = 1.0000
# Iterasi 96: Skor Heuristik = 4549, Temperatur = 384.8961, Probabilitas = 0.3925
# Iterasi 97: Skor Heuristik = 4637, Temperatur = 381.0471, Probabilitas = 0.7938
# Iterasi 98: Skor Heuristik = 4721, Temperatur = 377.2366, Probabilitas = 0.8004
# Iterasi 99: Skor Heuristik = 4721, Temperatur = 373.4643, Probabilitas = 1.0000
# Iterasi 100: Skor Heuristik = 4739, Temperatur = 369.7296, Probabilitas = 0.9525
# Iterasi 101: Skor Heuristik = 4661, Temperatur = 366.0323, Probabilitas = 1.0000
# Iterasi 102: Skor Heuristik = 4619, Temperatur = 362.3720, Probabilitas = 1.0000
# Iterasi 103: Skor Heuristik = 4579, Temperatur = 358.7483, Probabilitas = 1.0000
# Iterasi 104: Skor Heuristik = 4725, Temperatur = 355.1608, Probabilitas = 0.6629
# Iterasi 105: Skor Heuristik = 4735, Temperatur = 351.6092, Probabilitas = 0.9720
# Iterasi 106: Skor Heuristik = 4659, Temperatur = 348.0931, Probabilitas = 1.0000
# Iterasi 107: Skor Heuristik = 4652, Temperatur = 344.6122, Probabilitas = 1.0000
# Iterasi 108: Skor Heuristik = 4634, Temperatur = 341.1661, Probabilitas = 1.0000
# Iterasi 109: Skor Heuristik = 4638, Temperatur = 337.7544, Probabilitas = 0.9882
# Iterasi 110: Skor Heuristik = 4562, Temperatur = 334.3769, Probabilitas = 1.0000
# Iterasi 111: Skor Heuristik = 4561, Temperatur = 331.0331, Probabilitas = 1.0000
# Iterasi 112: Skor Heuristik = 4543, Temperatur = 327.7228, Probabilitas = 1.0000
# Iterasi 113: Skor Heuristik = 4542, Temperatur = 324.4455, Probabilitas = 1.0000
# Iterasi 114: Skor Heuristik = 4426, Temperatur = 321.2011, Probabilitas = 1.0000
# Iterasi 115: Skor Heuristik = 4270, Temperatur = 317.9891, Probabilitas = 1.0000
# Iterasi 116: Skor Heuristik = 4218, Temperatur = 314.8092, Probabilitas = 1.0000
# Iterasi 117: Skor Heuristik = 4332, Temperatur = 311.6611, Probabilitas = 0.6937
# Iterasi 118: Skor Heuristik = 4513, Temperatur = 308.5445, Probabilitas = 0.5562
# Iterasi 119: Skor Heuristik = 4513, Temperatur = 305.4590, Probabilitas = 1.0000
# Iterasi 120: Skor Heuristik = 4139, Temperatur = 302.4044, Probabilitas = 1.0000
# Iterasi 121: Skor Heuristik = 4067, Temperatur = 299.3804, Probabilitas = 1.0000
# Iterasi 122: Skor Heuristik = 3961, Temperatur = 296.3866, Probabilitas = 1.0000
# Iterasi 123: Skor Heuristik = 3939, Temperatur = 293.4227, Probabilitas = 1.0000
# Iterasi 124: Skor Heuristik = 3939, Temperatur = 290.4885, Probabilitas = 1.0000
# Iterasi 125: Skor Heuristik = 3920, Temperatur = 287.5836, Probabilitas = 1.0000
# Iterasi 126: Skor Heuristik = 3866, Temperatur = 284.7078, Probabilitas = 1.0000
# Iterasi 127: Skor Heuristik = 3812, Temperatur = 281.8607, Probabilitas = 1.0000
# Iterasi 128: Skor Heuristik = 3832, Temperatur = 279.0421, Probabilitas = 0.9308
# Iterasi 129: Skor Heuristik = 3856, Temperatur = 276.2517, Probabilitas = 0.9168
# Iterasi 130: Skor Heuristik = 3938, Temperatur = 273.4892, Probabilitas = 0.7409
# Iterasi 131: Skor Heuristik = 4220, Temperatur = 270.7543, Probabilitas = 0.3529
# Iterasi 132: Skor Heuristik = 4094, Temperatur = 268.0467, Probabilitas = 1.0000
# Iterasi 133: Skor Heuristik = 4112, Temperatur = 265.3662, Probabilitas = 0.9344
# Iterasi 134: Skor Heuristik = 4112, Temperatur = 262.7126, Probabilitas = 1.0000
# Iterasi 135: Skor Heuristik = 4072, Temperatur = 260.0855, Probabilitas = 1.0000
# Iterasi 136: Skor Heuristik = 4098, Temperatur = 257.4846, Probabilitas = 0.9040
# Iterasi 137: Skor Heuristik = 4061, Temperatur = 254.9098, Probabilitas = 1.0000
# Iterasi 138: Skor Heuristik = 4061, Temperatur = 252.3607, Probabilitas = 0.6240
# Iterasi 139: Skor Heuristik = 4021, Temperatur = 249.8371, Probabilitas = 1.0000
# Iterasi 140: Skor Heuristik = 4021, Temperatur = 247.3387, Probabilitas = 1.0000
# Iterasi 141: Skor Heuristik = 3997, Temperatur = 244.8653, Probabilitas = 1.0000
# Iterasi 142: Skor Heuristik = 3904, Temperatur = 242.4166, Probabilitas = 1.0000
# Iterasi 143: Skor Heuristik = 3927, Temperatur = 239.9925, Probabilitas = 0.9086
# Iterasi 144: Skor Heuristik = 3819, Temperatur = 237.5926, Probabilitas = 1.0000
# Iterasi 145: Skor Heuristik = 3875, Temperatur = 235.2166, Probabilitas = 0.7881
# Iterasi 146: Skor Heuristik = 3889, Temperatur = 232.8645, Probabilitas = 0.9417
# Iterasi 147: Skor Heuristik = 3849, Temperatur = 230.5358, Probabilitas = 1.0000
# Iterasi 148: Skor Heuristik = 3803, Temperatur = 228.2305, Probabilitas = 1.0000
# Iterasi 149: Skor Heuristik = 3841, Temperatur = 225.9482, Probabilitas = 0.8452
# Iterasi 150: Skor Heuristik = 3853, Temperatur = 223.6887, Probabilitas = 0.9478
# Iterasi 151: Skor Heuristik = 3843, Temperatur = 221.4518, Probabilitas = 1.0000
# Iterasi 152: Skor Heuristik = 3828, Temperatur = 219.2373, Probabilitas = 1.0000
# Iterasi 153: Skor Heuristik = 3799, Temperatur = 217.0449, Probabilitas = 1.0000
# Iterasi 154: Skor Heuristik = 3957, Temperatur = 214.8744, Probabilitas = 0.4794
# Iterasi 155: Skor Heuristik = 3953, Temperatur = 212.7257, Probabilitas = 1.0000
# Iterasi 156: Skor Heuristik = 3933, Temperatur = 210.5984, Probabilitas = 1.0000
# Iterasi 157: Skor Heuristik = 3973, Temperatur = 208.4925, Probabilitas = 0.8254
# Iterasi 158: Skor Heuristik = 4036, Temperatur = 206.4075, Probabilitas = 0.7370
# Iterasi 159: Skor Heuristik = 4072, Temperatur = 204.3435, Probabilitas = 0.8385
# Iterasi 160: Skor Heuristik = 4072, Temperatur = 202.3000, Probabilitas = 0.7810
# Iterasi 161: Skor Heuristik = 4130, Temperatur = 200.2770, Probabilitas = 0.7486
# Iterasi 162: Skor Heuristik = 4130, Temperatur = 198.2743, Probabilitas = 0.8256
# Iterasi 163: Skor Heuristik = 4130, Temperatur = 196.2915, Probabilitas = 0.5623
# Iterasi 164: Skor Heuristik = 4130, Temperatur = 194.3286, Probabilitas = 1.0000
# Iterasi 165: Skor Heuristik = 4130, Temperatur = 192.3853, Probabilitas = 0.2843
# Iterasi 166: Skor Heuristik = 3754, Temperatur = 190.4615, Probabilitas = 1.0000
# Iterasi 167: Skor Heuristik = 3754, Temperatur = 188.5568, Probabilitas = 0.3593
# Iterasi 168: Skor Heuristik = 3714, Temperatur = 186.6713, Probabilitas = 1.0000
# Iterasi 169: Skor Heuristik = 3674, Temperatur = 184.8046, Probabilitas = 1.0000
# Iterasi 170: Skor Heuristik = 3677, Temperatur = 182.9565, Probabilitas = 0.9837
# Iterasi 171: Skor Heuristik = 3701, Temperatur = 181.1270, Probabilitas = 0.8759
# Iterasi 172: Skor Heuristik = 3701, Temperatur = 179.3157, Probabilitas = 0.4606
# Iterasi 173: Skor Heuristik = 3830, Temperatur = 177.5225, Probabilitas = 0.4835
# Iterasi 174: Skor Heuristik = 3678, Temperatur = 175.7473, Probabilitas = 1.0000
# Iterasi 175: Skor Heuristik = 3526, Temperatur = 173.9898, Probabilitas = 1.0000
# Iterasi 176: Skor Heuristik = 3582, Temperatur = 172.2499, Probabilitas = 0.7224
# Iterasi 177: Skor Heuristik = 3693, Temperatur = 170.5274, Probabilitas = 0.5216
# Iterasi 178: Skor Heuristik = 3645, Temperatur = 168.8222, Probabilitas = 1.0000
# Iterasi 179: Skor Heuristik = 3756, Temperatur = 167.1339, Probabilitas = 0.5147
# Iterasi 180: Skor Heuristik = 3756, Temperatur = 165.4626, Probabilitas = 0.3059
# Iterasi 181: Skor Heuristik = 3776, Temperatur = 163.8080, Probabilitas = 0.8851
# Iterasi 182: Skor Heuristik = 3876, Temperatur = 162.1699, Probabilitas = 0.5398
# Iterasi 183: Skor Heuristik = 3756, Temperatur = 160.5482, Probabilitas = 1.0000
# Iterasi 184: Skor Heuristik = 3790, Temperatur = 158.9427, Probabilitas = 0.8074
# Iterasi 185: Skor Heuristik = 3792, Temperatur = 157.3533, Probabilitas = 0.9874
# Iterasi 186: Skor Heuristik = 3712, Temperatur = 155.7797, Probabilitas = 1.0000
# Iterasi 187: Skor Heuristik = 3881, Temperatur = 154.2220, Probabilitas = 0.3343
# Iterasi 188: Skor Heuristik = 3861, Temperatur = 152.6797, Probabilitas = 1.0000
# Iterasi 189: Skor Heuristik = 3653, Temperatur = 151.1529, Probabilitas = 1.0000
# Iterasi 190: Skor Heuristik = 3645, Temperatur = 149.6414, Probabilitas = 1.0000
# Iterasi 191: Skor Heuristik = 3605, Temperatur = 148.1450, Probabilitas = 1.0000
# Iterasi 192: Skor Heuristik = 3577, Temperatur = 146.6635, Probabilitas = 1.0000
# Iterasi 193: Skor Heuristik = 3527, Temperatur = 145.1969, Probabilitas = 1.0000
# Iterasi 194: Skor Heuristik = 3527, Temperatur = 143.7449, Probabilitas = 1.0000
# Iterasi 195: Skor Heuristik = 3527, Temperatur = 142.3075, Probabilitas = 0.0645
# Iterasi 196: Skor Heuristik = 3326, Temperatur = 140.8844, Probabilitas = 1.0000
# Iterasi 197: Skor Heuristik = 3288, Temperatur = 139.4756, Probabilitas = 1.0000
# Iterasi 198: Skor Heuristik = 3338, Temperatur = 138.0808, Probabilitas = 0.6962
# Iterasi 199: Skor Heuristik = 3470, Temperatur = 136.7000, Probabilitas = 0.3807
# Iterasi 200: Skor Heuristik = 3402, Temperatur = 135.3330, Probabilitas = 1.0000
# Iterasi 201: Skor Heuristik = 3404, Temperatur = 133.9797, Probabilitas = 0.9852
# Iterasi 202: Skor Heuristik = 3364, Temperatur = 132.6399, Probabilitas = 1.0000
# Iterasi 203: Skor Heuristik = 3384, Temperatur = 131.3135, Probabilitas = 0.8587
# Iterasi 204: Skor Heuristik = 3214, Temperatur = 130.0003, Probabilitas = 1.0000
# Iterasi 205: Skor Heuristik = 3232, Temperatur = 128.7003, Probabilitas = 0.8695
# Iterasi 206: Skor Heuristik = 3172, Temperatur = 127.4133, Probabilitas = 1.0000
# Iterasi 207: Skor Heuristik = 3113, Temperatur = 126.1392, Probabilitas = 1.0000
# Iterasi 208: Skor Heuristik = 2986, Temperatur = 124.8778, Probabilitas = 1.0000
# Iterasi 209: Skor Heuristik = 2986, Temperatur = 123.6290, Probabilitas = 0.0518
# Iterasi 210: Skor Heuristik = 2934, Temperatur = 122.3927, Probabilitas = 1.0000
# Iterasi 211: Skor Heuristik = 2934, Temperatur = 121.1688, Probabilitas = 0.2852
# Iterasi 212: Skor Heuristik = 2909, Temperatur = 119.9571, Probabilitas = 1.0000
# Iterasi 213: Skor Heuristik = 2949, Temperatur = 118.7576, Probabilitas = 0.7140
# Iterasi 214: Skor Heuristik = 2935, Temperatur = 117.5700, Probabilitas = 1.0000
# Iterasi 215: Skor Heuristik = 2987, Temperatur = 116.3943, Probabilitas = 0.6397
# Iterasi 216: Skor Heuristik = 2987, Temperatur = 115.2303, Probabilitas = 0.7381
# Iterasi 217: Skor Heuristik = 3078, Temperatur = 114.0780, Probabilitas = 0.4504
# Iterasi 218: Skor Heuristik = 3108, Temperatur = 112.9373, Probabilitas = 0.7667
# Iterasi 219: Skor Heuristik = 3212, Temperatur = 111.8079, Probabilitas = 0.3945
# Iterasi 220: Skor Heuristik = 3195, Temperatur = 110.6898, Probabilitas = 1.0000
# Iterasi 221: Skor Heuristik = 3251, Temperatur = 109.5829, Probabilitas = 0.5999
# Iterasi 222: Skor Heuristik = 3252, Temperatur = 108.4871, Probabilitas = 0.9908
# Iterasi 223: Skor Heuristik = 3246, Temperatur = 107.4022, Probabilitas = 1.0000
# Iterasi 224: Skor Heuristik = 3283, Temperatur = 106.3282, Probabilitas = 0.7061
# Iterasi 225: Skor Heuristik = 3421, Temperatur = 105.2649, Probabilitas = 0.2696
# Iterasi 226: Skor Heuristik = 3476, Temperatur = 104.2123, Probabilitas = 0.5899
# Iterasi 227: Skor Heuristik = 3428, Temperatur = 103.1701, Probabilitas = 1.0000
# Iterasi 228: Skor Heuristik = 3428, Temperatur = 102.1384, Probabilitas = 0.1930
# Iterasi 229: Skor Heuristik = 3518, Temperatur = 101.1170, Probabilitas = 0.4106
# Iterasi 230: Skor Heuristik = 3518, Temperatur = 100.1059, Probabilitas = 0.0274
# Iterasi 231: Skor Heuristik = 3516, Temperatur = 99.1048, Probabilitas = 1.0000
# Iterasi 232: Skor Heuristik = 3482, Temperatur = 98.1138, Probabilitas = 1.0000
# Iterasi 233: Skor Heuristik = 3482, Temperatur = 97.1326, Probabilitas = 0.5677
# Iterasi 234: Skor Heuristik = 3318, Temperatur = 96.1613, Probabilitas = 1.0000
# Iterasi 235: Skor Heuristik = 3318, Temperatur = 95.1997, Probabilitas = 0.0108
# Iterasi 236: Skor Heuristik = 3206, Temperatur = 94.2477, Probabilitas = 1.0000
# Iterasi 237: Skor Heuristik = 3174, Temperatur = 93.3052, Probabilitas = 1.0000
# Iterasi 238: Skor Heuristik = 3030, Temperatur = 92.3722, Probabilitas = 1.0000
# Iterasi 239: Skor Heuristik = 3026, Temperatur = 91.4484, Probabilitas = 1.0000
# Iterasi 240: Skor Heuristik = 3000, Temperatur = 90.5340, Probabilitas = 1.0000
# Iterasi 241: Skor Heuristik = 3000, Temperatur = 89.6286, Probabilitas = 0.1834
# Iterasi 242: Skor Heuristik = 3000, Temperatur = 88.7323, Probabilitas = 0.6972
# Iterasi 243: Skor Heuristik = 3000, Temperatur = 87.8450, Probabilitas = 0.0228
# Iterasi 244: Skor Heuristik = 2911, Temperatur = 86.9666, Probabilitas = 1.0000
# Iterasi 245: Skor Heuristik = 2791, Temperatur = 86.0969, Probabilitas = 1.0000
# Iterasi 246: Skor Heuristik = 2791, Temperatur = 85.2359, Probabilitas = 0.7909
# Iterasi 247: Skor Heuristik = 2787, Temperatur = 84.3836, Probabilitas = 1.0000
# Iterasi 248: Skor Heuristik = 2807, Temperatur = 83.5397, Probabilitas = 0.7871
# Iterasi 249: Skor Heuristik = 2807, Temperatur = 82.7043, Probabilitas = 0.0327
# Iterasi 250: Skor Heuristik = 2807, Temperatur = 81.8773, Probabilitas = 0.0788
# Iterasi 251: Skor Heuristik = 2833, Temperatur = 81.0585, Probabilitas = 0.7256
# Iterasi 252: Skor Heuristik = 2833, Temperatur = 80.2479, Probabilitas = 0.2539
# Iterasi 253: Skor Heuristik = 2833, Temperatur = 79.4455, Probabilitas = 0.3387
# Iterasi 254: Skor Heuristik = 2833, Temperatur = 78.6510, Probabilitas = 0.3351
# Iterasi 255: Skor Heuristik = 2833, Temperatur = 77.8645, Probabilitas = 0.0000
# Iterasi 256: Skor Heuristik = 2833, Temperatur = 77.0858, Probabilitas = 0.0673
# Iterasi 257: Skor Heuristik = 2807, Temperatur = 76.3150, Probabilitas = 1.0000
# Iterasi 258: Skor Heuristik = 2814, Temperatur = 75.5518, Probabilitas = 0.9115
# Iterasi 259: Skor Heuristik = 2826, Temperatur = 74.7963, Probabilitas = 0.8518
# Iterasi 260: Skor Heuristik = 2994, Temperatur = 74.0484, Probabilitas = 0.1034
# Iterasi 261: Skor Heuristik = 2972, Temperatur = 73.3079, Probabilitas = 1.0000
# Iterasi 262: Skor Heuristik = 2972, Temperatur = 72.5748, Probabilitas = 0.5606
# Iterasi 263: Skor Heuristik = 2932, Temperatur = 71.8490, Probabilitas = 1.0000
# Iterasi 264: Skor Heuristik = 2983, Temperatur = 71.1306, Probabilitas = 0.4882
# Iterasi 265: Skor Heuristik = 3031, Temperatur = 70.4192, Probabilitas = 0.5058
# Iterasi 266: Skor Heuristik = 3045, Temperatur = 69.7151, Probabilitas = 0.8181
# Iterasi 267: Skor Heuristik = 3007, Temperatur = 69.0179, Probabilitas = 1.0000
# Iterasi 268: Skor Heuristik = 3007, Temperatur = 68.3277, Probabilitas = 0.0281
# Iterasi 269: Skor Heuristik = 2978, Temperatur = 67.6444, Probabilitas = 1.0000
# Iterasi 270: Skor Heuristik = 2978, Temperatur = 66.9680, Probabilitas = 0.7530
# Iterasi 271: Skor Heuristik = 2978, Temperatur = 66.2983, Probabilitas = 0.4429
# Iterasi 272: Skor Heuristik = 2978, Temperatur = 65.6353, Probabilitas = 0.0728
# Iterasi 273: Skor Heuristik = 2768, Temperatur = 64.9790, Probabilitas = 1.0000
# Iterasi 274: Skor Heuristik = 2784, Temperatur = 64.3292, Probabilitas = 0.7798
# Iterasi 275: Skor Heuristik = 2826, Temperatur = 63.6859, Probabilitas = 0.5171
# Iterasi 276: Skor Heuristik = 2826, Temperatur = 63.0490, Probabilitas = 0.5925
# Iterasi 277: Skor Heuristik = 2826, Temperatur = 62.4186, Probabilitas = 0.0964
# Iterasi 278: Skor Heuristik = 2797, Temperatur = 61.7944, Probabilitas = 1.0000
# Iterasi 279: Skor Heuristik = 2731, Temperatur = 61.1764, Probabilitas = 1.0000
# Iterasi 280: Skor Heuristik = 2705, Temperatur = 60.5647, Probabilitas = 1.0000
# Iterasi 281: Skor Heuristik = 2705, Temperatur = 59.9590, Probabilitas = 0.0115
# Iterasi 282: Skor Heuristik = 2653, Temperatur = 59.3594, Probabilitas = 1.0000
# Iterasi 283: Skor Heuristik = 2638, Temperatur = 58.7658, Probabilitas = 1.0000
# Iterasi 284: Skor Heuristik = 2638, Temperatur = 58.1782, Probabilitas = 0.1987
# Iterasi 285: Skor Heuristik = 2638, Temperatur = 57.5964, Probabilitas = 0.0600
# Iterasi 286: Skor Heuristik = 2638, Temperatur = 57.0204, Probabilitas = 0.1923
# Iterasi 287: Skor Heuristik = 2634, Temperatur = 56.4502, Probabilitas = 1.0000
# Iterasi 288: Skor Heuristik = 2634, Temperatur = 55.8857, Probabilitas = 0.5846
# Iterasi 289: Skor Heuristik = 2634, Temperatur = 55.3269, Probabilitas = 0.0689
# Iterasi 290: Skor Heuristik = 2600, Temperatur = 54.7736, Probabilitas = 1.0000
# Iterasi 291: Skor Heuristik = 2604, Temperatur = 54.2259, Probabilitas = 0.9289
# Iterasi 292: Skor Heuristik = 2591, Temperatur = 53.6836, Probabilitas = 1.0000
# Iterasi 293: Skor Heuristik = 2605, Temperatur = 53.1468, Probabilitas = 0.7684
# Iterasi 294: Skor Heuristik = 2605, Temperatur = 52.6153, Probabilitas = 0.1103
# Iterasi 295: Skor Heuristik = 2601, Temperatur = 52.0891, Probabilitas = 1.0000
# Iterasi 296: Skor Heuristik = 2601, Temperatur = 51.5683, Probabilitas = 0.2781
# Iterasi 297: Skor Heuristik = 2601, Temperatur = 51.0526, Probabilitas = 0.1356
# Iterasi 298: Skor Heuristik = 2601, Temperatur = 50.5420, Probabilitas = 0.0000
# Iterasi 299: Skor Heuristik = 2549, Temperatur = 50.0366, Probabilitas = 1.0000
# Iterasi 300: Skor Heuristik = 2578, Temperatur = 49.5363, Probabilitas = 0.5569
# Iterasi 301: Skor Heuristik = 2546, Temperatur = 49.0409, Probabilitas = 1.0000
# Iterasi 302: Skor Heuristik = 2546, Temperatur = 48.5505, Probabilitas = 1.0000
# Iterasi 303: Skor Heuristik = 2546, Temperatur = 48.0650, Probabilitas = 0.0001
# Iterasi 304: Skor Heuristik = 2546, Temperatur = 47.5843, Probabilitas = 0.3353
# Iterasi 305: Skor Heuristik = 2546, Temperatur = 47.1085, Probabilitas = 0.1950
# Iterasi 306: Skor Heuristik = 2442, Temperatur = 46.6374, Probabilitas = 1.0000
# Iterasi 307: Skor Heuristik = 2442, Temperatur = 46.1710, Probabilitas = 0.5946
# Iterasi 308: Skor Heuristik = 2406, Temperatur = 45.7093, Probabilitas = 1.0000
# Iterasi 309: Skor Heuristik = 2406, Temperatur = 45.2522, Probabilitas = 0.0068
# Iterasi 310: Skor Heuristik = 2406, Temperatur = 44.7997, Probabilitas = 0.0033
# Iterasi 311: Skor Heuristik = 2406, Temperatur = 44.3517, Probabilitas = 0.0077
# Iterasi 312: Skor Heuristik = 2433, Temperatur = 43.9082, Probabilitas = 0.5407
# Iterasi 313: Skor Heuristik = 2429, Temperatur = 43.4691, Probabilitas = 1.0000
# Iterasi 314: Skor Heuristik = 2369, Temperatur = 43.0344, Probabilitas = 1.0000
# Iterasi 315: Skor Heuristik = 2369, Temperatur = 42.6041, Probabilitas = 0.2624
# Iterasi 316: Skor Heuristik = 2332, Temperatur = 42.1780, Probabilitas = 1.0000
# Iterasi 317: Skor Heuristik = 2352, Temperatur = 41.7563, Probabilitas = 0.6194
# Iterasi 318: Skor Heuristik = 2382, Temperatur = 41.3387, Probabilitas = 0.4840
# Iterasi 319: Skor Heuristik = 2370, Temperatur = 40.9253, Probabilitas = 1.0000
# Iterasi 320: Skor Heuristik = 2370, Temperatur = 40.5160, Probabilitas = 0.0557
# Iterasi 321: Skor Heuristik = 2370, Temperatur = 40.1109, Probabilitas = 0.2875
# Iterasi 322: Skor Heuristik = 2366, Temperatur = 39.7098, Probabilitas = 1.0000
# Iterasi 323: Skor Heuristik = 2260, Temperatur = 39.3127, Probabilitas = 1.0000
# Iterasi 324: Skor Heuristik = 2260, Temperatur = 38.9196, Probabilitas = 1.0000
# Iterasi 325: Skor Heuristik = 2265, Temperatur = 38.5304, Probabilitas = 0.8783
# Iterasi 326: Skor Heuristik = 2265, Temperatur = 38.1451, Probabilitas = 0.0065
# Iterasi 327: Skor Heuristik = 2265, Temperatur = 37.7636, Probabilitas = 0.3656
# Iterasi 328: Skor Heuristik = 2265, Temperatur = 37.3860, Probabilitas = 0.2922
# Iterasi 329: Skor Heuristik = 2265, Temperatur = 37.0121, Probabilitas = 0.0341
# Iterasi 330: Skor Heuristik = 2265, Temperatur = 36.6420, Probabilitas = 0.0013
# Iterasi 331: Skor Heuristik = 2265, Temperatur = 36.2756, Probabilitas = 0.5453
# Iterasi 332: Skor Heuristik = 2265, Temperatur = 35.9128, Probabilitas = 0.0020
# Iterasi 333: Skor Heuristik = 2279, Temperatur = 35.5537, Probabilitas = 0.6745
# Iterasi 334: Skor Heuristik = 2279, Temperatur = 35.1981, Probabilitas = 0.0370
# Iterasi 335: Skor Heuristik = 2279, Temperatur = 34.8462, Probabilitas = 0.0005
# Iterasi 336: Skor Heuristik = 2279, Temperatur = 34.4977, Probabilitas = 0.2215
# Iterasi 337: Skor Heuristik = 2279, Temperatur = 34.1527, Probabilitas = 0.0377
# Iterasi 338: Skor Heuristik = 2355, Temperatur = 33.8112, Probabilitas = 0.1056
# Iterasi 339: Skor Heuristik = 2309, Temperatur = 33.4731, Probabilitas = 1.0000
# Iterasi 340: Skor Heuristik = 2289, Temperatur = 33.1384, Probabilitas = 1.0000
# Iterasi 341: Skor Heuristik = 2289, Temperatur = 32.8070, Probabilitas = 0.0001
# Iterasi 342: Skor Heuristik = 2313, Temperatur = 32.4789, Probabilitas = 0.4776
# Iterasi 343: Skor Heuristik = 2313, Temperatur = 32.1541, Probabilitas = 0.0000
# Iterasi 344: Skor Heuristik = 2318, Temperatur = 31.8326, Probabilitas = 0.8546
# Iterasi 345: Skor Heuristik = 2318, Temperatur = 31.5142, Probabilitas = 0.0097
# Iterasi 346: Skor Heuristik = 2318, Temperatur = 31.1991, Probabilitas = 0.3823
# Iterasi 347: Skor Heuristik = 2318, Temperatur = 30.8871, Probabilitas = 1.0000
# Iterasi 348: Skor Heuristik = 2326, Temperatur = 30.5782, Probabilitas = 0.7698
# Iterasi 349: Skor Heuristik = 2326, Temperatur = 30.2725, Probabilitas = 0.0001
# Iterasi 350: Skor Heuristik = 2325, Temperatur = 29.9697, Probabilitas = 1.0000
# Iterasi 351: Skor Heuristik = 2316, Temperatur = 29.6700, Probabilitas = 1.0000
# Iterasi 352: Skor Heuristik = 2316, Temperatur = 29.3733, Probabilitas = 0.0010
# Iterasi 353: Skor Heuristik = 2316, Temperatur = 29.0796, Probabilitas = 0.0001
# Iterasi 354: Skor Heuristik = 2316, Temperatur = 28.7888, Probabilitas = 0.0002
# Iterasi 355: Skor Heuristik = 2316, Temperatur = 28.5009, Probabilitas = 0.0032
# Iterasi 356: Skor Heuristik = 2316, Temperatur = 28.2159, Probabilitas = 0.0003
# Iterasi 357: Skor Heuristik = 2345, Temperatur = 27.9338, Probabilitas = 0.3541
# Iterasi 358: Skor Heuristik = 2345, Temperatur = 27.6544, Probabilitas = 0.1142
# Iterasi 359: Skor Heuristik = 2347, Temperatur = 27.3779, Probabilitas = 0.9296
# Iterasi 360: Skor Heuristik = 2347, Temperatur = 27.1041, Probabilitas = 0.0186
# Iterasi 361: Skor Heuristik = 2241, Temperatur = 26.8331, Probabilitas = 1.0000
# Iterasi 362: Skor Heuristik = 2241, Temperatur = 26.5647, Probabilitas = 0.0351
# Iterasi 363: Skor Heuristik = 2265, Temperatur = 26.2991, Probabilitas = 0.4015
# Iterasi 364: Skor Heuristik = 2161, Temperatur = 26.0361, Probabilitas = 1.0000
# Iterasi 365: Skor Heuristik = 2161, Temperatur = 25.7757, Probabilitas = 0.0001
# Iterasi 366: Skor Heuristik = 2160, Temperatur = 25.5180, Probabilitas = 1.0000
# Iterasi 367: Skor Heuristik = 2160, Temperatur = 25.2628, Probabilitas = 0.0224
# Iterasi 368: Skor Heuristik = 2164, Temperatur = 25.0102, Probabilitas = 0.8522
# Iterasi 369: Skor Heuristik = 2164, Temperatur = 24.7601, Probabilitas = 0.2336
# Iterasi 370: Skor Heuristik = 2116, Temperatur = 24.5125, Probabilitas = 1.0000
# Iterasi 371: Skor Heuristik = 2116, Temperatur = 24.2673, Probabilitas = 1.0000
# Iterasi 372: Skor Heuristik = 2116, Temperatur = 24.0247, Probabilitas = 0.1602
# Iterasi 373: Skor Heuristik = 2116, Temperatur = 23.7844, Probabilitas = 0.0000
# Iterasi 374: Skor Heuristik = 2146, Temperatur = 23.5466, Probabilitas = 0.2797
# Iterasi 375: Skor Heuristik = 2146, Temperatur = 23.3111, Probabilitas = 0.0009
# Iterasi 376: Skor Heuristik = 2146, Temperatur = 23.0780, Probabilitas = 0.0001
# Iterasi 377: Skor Heuristik = 2146, Temperatur = 22.8472, Probabilitas = 0.0000
# Iterasi 378: Skor Heuristik = 2146, Temperatur = 22.6187, Probabilitas = 0.0007
# Iterasi 379: Skor Heuristik = 2152, Temperatur = 22.3926, Probabilitas = 0.7649
# Iterasi 380: Skor Heuristik = 2152, Temperatur = 22.1686, Probabilitas = 0.0158
# Iterasi 381: Skor Heuristik = 2152, Temperatur = 21.9469, Probabilitas = 0.0712
# Iterasi 382: Skor Heuristik = 2084, Temperatur = 21.7275, Probabilitas = 1.0000
# Iterasi 383: Skor Heuristik = 2089, Temperatur = 21.5102, Probabilitas = 0.7926
# Iterasi 384: Skor Heuristik = 2048, Temperatur = 21.2951, Probabilitas = 1.0000
# Iterasi 385: Skor Heuristik = 2048, Temperatur = 21.0821, Probabilitas = 0.2090
# Iterasi 386: Skor Heuristik = 1998, Temperatur = 20.8713, Probabilitas = 1.0000
# Iterasi 387: Skor Heuristik = 2003, Temperatur = 20.6626, Probabilitas = 0.7851
# Iterasi 388: Skor Heuristik = 1979, Temperatur = 20.4560, Probabilitas = 1.0000
# Iterasi 389: Skor Heuristik = 1979, Temperatur = 20.2514, Probabilitas = 0.0315
# Iterasi 390: Skor Heuristik = 1979, Temperatur = 20.0489, Probabilitas = 0.0711
# Iterasi 391: Skor Heuristik = 1979, Temperatur = 19.8484, Probabilitas = 0.5195
# Iterasi 392: Skor Heuristik = 1966, Temperatur = 19.6499, Probabilitas = 1.0000
# Iterasi 393: Skor Heuristik = 1994, Temperatur = 19.4534, Probabilitas = 0.2371
# Iterasi 394: Skor Heuristik = 1984, Temperatur = 19.2589, Probabilitas = 1.0000
# Iterasi 395: Skor Heuristik = 1984, Temperatur = 19.0663, Probabilitas = 0.3503
# Iterasi 396: Skor Heuristik = 1984, Temperatur = 18.8756, Probabilitas = 0.3853
# Iterasi 397: Skor Heuristik = 1984, Temperatur = 18.6869, Probabilitas = 0.0000
# Iterasi 398: Skor Heuristik = 1998, Temperatur = 18.5000, Probabilitas = 0.4692
# Iterasi 399: Skor Heuristik = 1998, Temperatur = 18.3150, Probabilitas = 0.4917
# Iterasi 400: Skor Heuristik = 1998, Temperatur = 18.1319, Probabilitas = 0.3319
# Iterasi 401: Skor Heuristik = 1998, Temperatur = 17.9506, Probabilitas = 1.0000
# Iterasi 402: Skor Heuristik = 1982, Temperatur = 17.7710, Probabilitas = 1.0000
# Iterasi 403: Skor Heuristik = 1982, Temperatur = 17.5933, Probabilitas = 0.0000
# Iterasi 404: Skor Heuristik = 1982, Temperatur = 17.4174, Probabilitas = 0.0000
# Iterasi 405: Skor Heuristik = 1982, Temperatur = 17.2432, Probabilitas = 0.0618
# Iterasi 406: Skor Heuristik = 1982, Temperatur = 17.0708, Probabilitas = 0.0355
# Iterasi 407: Skor Heuristik = 1982, Temperatur = 16.9001, Probabilitas = 0.5871
# Iterasi 408: Skor Heuristik = 1982, Temperatur = 16.7311, Probabilitas = 0.0000
# Iterasi 409: Skor Heuristik = 1978, Temperatur = 16.5638, Probabilitas = 1.0000
# Iterasi 410: Skor Heuristik = 1978, Temperatur = 16.3981, Probabilitas = 0.0474
# Iterasi 411: Skor Heuristik = 1978, Temperatur = 16.2342, Probabilitas = 0.0008
# Iterasi 412: Skor Heuristik = 1978, Temperatur = 16.0718, Probabilitas = 0.0647
# Iterasi 413: Skor Heuristik = 1978, Temperatur = 15.9111, Probabilitas = 0.0014
# Iterasi 414: Skor Heuristik = 2006, Temperatur = 15.7520, Probabilitas = 0.1691
# Iterasi 415: Skor Heuristik = 2006, Temperatur = 15.5945, Probabilitas = 0.1060
# Iterasi 416: Skor Heuristik = 2006, Temperatur = 15.4385, Probabilitas = 1.0000
# Iterasi 417: Skor Heuristik = 2006, Temperatur = 15.2841, Probabilitas = 0.0312
# Iterasi 418: Skor Heuristik = 2014, Temperatur = 15.1313, Probabilitas = 0.5894
# Iterasi 419: Skor Heuristik = 2014, Temperatur = 14.9800, Probabilitas = 0.0025
# Iterasi 420: Skor Heuristik = 2014, Temperatur = 14.8302, Probabilitas = 0.0000
# Iterasi 421: Skor Heuristik = 2014, Temperatur = 14.6819, Probabilitas = 0.4416
# Iterasi 422: Skor Heuristik = 2014, Temperatur = 14.5351, Probabilitas = 0.0000
# Iterasi 423: Skor Heuristik = 2014, Temperatur = 14.3897, Probabilitas = 0.0000
# Iterasi 424: Skor Heuristik = 2014, Temperatur = 14.2458, Probabilitas = 0.0018
# Iterasi 425: Skor Heuristik = 2014, Temperatur = 14.1034, Probabilitas = 0.0000
# Iterasi 426: Skor Heuristik = 2014, Temperatur = 13.9623, Probabilitas = 0.0003
# Iterasi 427: Skor Heuristik = 2014, Temperatur = 13.8227, Probabilitas = 0.0003
# Iterasi 428: Skor Heuristik = 2014, Temperatur = 13.6845, Probabilitas = 0.0000
# Iterasi 429: Skor Heuristik = 2014, Temperatur = 13.5476, Probabilitas = 0.0003
# Iterasi 430: Skor Heuristik = 1997, Temperatur = 13.4122, Probabilitas = 1.0000
# Iterasi 431: Skor Heuristik = 1997, Temperatur = 13.2780, Probabilitas = 0.0000
# Iterasi 432: Skor Heuristik = 1997, Temperatur = 13.1453, Probabilitas = 0.0000
# Iterasi 433: Skor Heuristik = 1997, Temperatur = 13.0138, Probabilitas = 0.0997
# Iterasi 434: Skor Heuristik = 1997, Temperatur = 12.8837, Probabilitas = 0.0000
# Iterasi 435: Skor Heuristik = 1997, Temperatur = 12.7548, Probabilitas = 0.0012
# Iterasi 436: Skor Heuristik = 1997, Temperatur = 12.6273, Probabilitas = 1.0000
# Iterasi 437: Skor Heuristik = 1997, Temperatur = 12.5010, Probabilitas = 0.0051
# Iterasi 438: Skor Heuristik = 2001, Temperatur = 12.3760, Probabilitas = 0.7238
# Iterasi 439: Skor Heuristik = 2001, Temperatur = 12.2522, Probabilitas = 0.0000
# Iterasi 440: Skor Heuristik = 1999, Temperatur = 12.1297, Probabilitas = 1.0000
# Iterasi 441: Skor Heuristik = 1999, Temperatur = 12.0084, Probabilitas = 0.0000
# Iterasi 442: Skor Heuristik = 1997, Temperatur = 11.8883, Probabilitas = 1.0000
# Iterasi 443: Skor Heuristik = 1997, Temperatur = 11.7694, Probabilitas = 1.0000
# Iterasi 444: Skor Heuristik = 1987, Temperatur = 11.6518, Probabilitas = 1.0000
# Iterasi 445: Skor Heuristik = 1987, Temperatur = 11.5352, Probabilitas = 0.0262
# Iterasi 446: Skor Heuristik = 1987, Temperatur = 11.4199, Probabilitas = 0.3497
# Iterasi 447: Skor Heuristik = 1957, Temperatur = 11.3057, Probabilitas = 1.0000
# Iterasi 448: Skor Heuristik = 1957, Temperatur = 11.1926, Probabilitas = 0.0000
# Iterasi 449: Skor Heuristik = 1957, Temperatur = 11.0807, Probabilitas = 0.0000
# Iterasi 450: Skor Heuristik = 1957, Temperatur = 10.9699, Probabilitas = 0.0000
# Iterasi 451: Skor Heuristik = 1957, Temperatur = 10.8602, Probabilitas = 1.0000
# Iterasi 452: Skor Heuristik = 1957, Temperatur = 10.7516, Probabilitas = 0.1418
# Iterasi 453: Skor Heuristik = 1957, Temperatur = 10.6441, Probabilitas = 0.0340
# Iterasi 454: Skor Heuristik = 1957, Temperatur = 10.5376, Probabilitas = 0.0638
# Iterasi 455: Skor Heuristik = 1942, Temperatur = 10.4323, Probabilitas = 1.0000
# Iterasi 456: Skor Heuristik = 1942, Temperatur = 10.3279, Probabilitas = 0.0000
# Iterasi 457: Skor Heuristik = 1942, Temperatur = 10.2247, Probabilitas = 1.0000
# Iterasi 458: Skor Heuristik = 1896, Temperatur = 10.1224, Probabilitas = 1.0000
# Iterasi 459: Skor Heuristik = 1896, Temperatur = 10.0212, Probabilitas = 0.0046
# Iterasi 460: Skor Heuristik = 1896, Temperatur = 9.9210, Probabilitas = 0.0000
# Iterasi 461: Skor Heuristik = 1896, Temperatur = 9.8218, Probabilitas = 0.0000
# Iterasi 462: Skor Heuristik = 1896, Temperatur = 9.7235, Probabilitas = 0.0000
# Iterasi 463: Skor Heuristik = 1896, Temperatur = 9.6263, Probabilitas = 0.1389
# Iterasi 464: Skor Heuristik = 1896, Temperatur = 9.5300, Probabilitas = 0.0000
# Iterasi 465: Skor Heuristik = 1896, Temperatur = 9.4347, Probabilitas = 0.0000
# Iterasi 466: Skor Heuristik = 1896, Temperatur = 9.3404, Probabilitas = 0.0002
# Iterasi 467: Skor Heuristik = 1896, Temperatur = 9.2470, Probabilitas = 0.0390
# Iterasi 468: Skor Heuristik = 1896, Temperatur = 9.1545, Probabilitas = 0.1400
# Iterasi 469: Skor Heuristik = 1896, Temperatur = 9.0630, Probabilitas = 0.1911
# Iterasi 470: Skor Heuristik = 1896, Temperatur = 8.9724, Probabilitas = 0.0000
# Iterasi 471: Skor Heuristik = 1896, Temperatur = 8.8826, Probabilitas = 0.0008
# Iterasi 472: Skor Heuristik = 1898, Temperatur = 8.7938, Probabilitas = 0.7966
# Iterasi 473: Skor Heuristik = 1898, Temperatur = 8.7059, Probabilitas = 0.0000
# Iterasi 474: Skor Heuristik = 1898, Temperatur = 8.6188, Probabilitas = 0.0076
# Iterasi 475: Skor Heuristik = 1898, Temperatur = 8.5326, Probabilitas = 0.1079
# Iterasi 476: Skor Heuristik = 1898, Temperatur = 8.4473, Probabilitas = 0.0000
# Iterasi 477: Skor Heuristik = 1898, Temperatur = 8.3628, Probabilitas = 0.0000
# Iterasi 478: Skor Heuristik = 1898, Temperatur = 8.2792, Probabilitas = 0.0000
# Iterasi 479: Skor Heuristik = 1898, Temperatur = 8.1964, Probabilitas = 0.0000
# Iterasi 480: Skor Heuristik = 1872, Temperatur = 8.1144, Probabilitas = 1.0000
# Iterasi 481: Skor Heuristik = 1872, Temperatur = 8.0333, Probabilitas = 0.0008
# Iterasi 482: Skor Heuristik = 1872, Temperatur = 7.9530, Probabilitas = 0.0000
# Iterasi 483: Skor Heuristik = 1872, Temperatur = 7.8734, Probabilitas = 0.0000
# Iterasi 484: Skor Heuristik = 1872, Temperatur = 7.7947, Probabilitas = 0.2772
# Iterasi 485: Skor Heuristik = 1866, Temperatur = 7.7167, Probabilitas = 1.0000
# Iterasi 486: Skor Heuristik = 1866, Temperatur = 7.6396, Probabilitas = 0.0333
# Iterasi 487: Skor Heuristik = 1866, Temperatur = 7.5632, Probabilitas = 0.0000
# Iterasi 488: Skor Heuristik = 1866, Temperatur = 7.4876, Probabilitas = 0.0004
# Iterasi 489: Skor Heuristik = 1866, Temperatur = 7.4127, Probabilitas = 0.0771
# Iterasi 490: Skor Heuristik = 1832, Temperatur = 7.3385, Probabilitas = 1.0000
# Iterasi 491: Skor Heuristik = 1831, Temperatur = 7.2652, Probabilitas = 1.0000
# Iterasi 492: Skor Heuristik = 1831, Temperatur = 7.1925, Probabilitas = 0.0000
# Iterasi 493: Skor Heuristik = 1817, Temperatur = 7.1206, Probabilitas = 1.0000
# Iterasi 494: Skor Heuristik = 1817, Temperatur = 7.0494, Probabilitas = 1.0000
# Iterasi 495: Skor Heuristik = 1817, Temperatur = 6.9789, Probabilitas = 0.0000
# Iterasi 496: Skor Heuristik = 1817, Temperatur = 6.9091, Probabilitas = 0.8653
# Iterasi 497: Skor Heuristik = 1817, Temperatur = 6.8400, Probabilitas = 0.0000
# Iterasi 498: Skor Heuristik = 1817, Temperatur = 6.7716, Probabilitas = 0.0000
# Iterasi 499: Skor Heuristik = 1817, Temperatur = 6.7039, Probabilitas = 0.0000
# Iterasi 500: Skor Heuristik = 1811, Temperatur = 6.6369, Probabilitas = 1.0000
# Iterasi 501: Skor Heuristik = 1811, Temperatur = 6.5705, Probabilitas = 0.0000
# Iterasi 502: Skor Heuristik = 1811, Temperatur = 6.5048, Probabilitas = 0.0000
# Iterasi 503: Skor Heuristik = 1811, Temperatur = 6.4397, Probabilitas = 0.0000
# Iterasi 504: Skor Heuristik = 1787, Temperatur = 6.3753, Probabilitas = 1.0000
# Iterasi 505: Skor Heuristik = 1795, Temperatur = 6.3116, Probabilitas = 0.2815
# Iterasi 506: Skor Heuristik = 1795, Temperatur = 6.2485, Probabilitas = 0.0000
# Iterasi 507: Skor Heuristik = 1801, Temperatur = 6.1860, Probabilitas = 0.3791
# Iterasi 508: Skor Heuristik = 1792, Temperatur = 6.1241, Probabilitas = 1.0000
# Iterasi 509: Skor Heuristik = 1768, Temperatur = 6.0629, Probabilitas = 1.0000
# Iterasi 510: Skor Heuristik = 1768, Temperatur = 6.0022, Probabilitas = 0.0000
# Iterasi 511: Skor Heuristik = 1768, Temperatur = 5.9422, Probabilitas = 0.3643
# Iterasi 512: Skor Heuristik = 1768, Temperatur = 5.8828, Probabilitas = 0.0000
# Iterasi 513: Skor Heuristik = 1768, Temperatur = 5.8240, Probabilitas = 0.0000
# Iterasi 514: Skor Heuristik = 1768, Temperatur = 5.7657, Probabilitas = 0.0000
# Iterasi 515: Skor Heuristik = 1768, Temperatur = 5.7081, Probabilitas = 0.0000
# Iterasi 516: Skor Heuristik = 1768, Temperatur = 5.6510, Probabilitas = 0.0000
# Iterasi 517: Skor Heuristik = 1739, Temperatur = 5.5945, Probabilitas = 1.0000
# Iterasi 518: Skor Heuristik = 1739, Temperatur = 5.5385, Probabilitas = 0.0000
# Iterasi 519: Skor Heuristik = 1739, Temperatur = 5.4832, Probabilitas = 0.0024
# Iterasi 520: Skor Heuristik = 1739, Temperatur = 5.4283, Probabilitas = 0.0000
# Iterasi 521: Skor Heuristik = 1739, Temperatur = 5.3740, Probabilitas = 0.0000
# Iterasi 522: Skor Heuristik = 1739, Temperatur = 5.3203, Probabilitas = 1.0000
# Iterasi 523: Skor Heuristik = 1739, Temperatur = 5.2671, Probabilitas = 0.0000
# Iterasi 524: Skor Heuristik = 1739, Temperatur = 5.2144, Probabilitas = 0.0005
# Iterasi 525: Skor Heuristik = 1693, Temperatur = 5.1623, Probabilitas = 1.0000
# Iterasi 526: Skor Heuristik = 1693, Temperatur = 5.1107, Probabilitas = 0.0000
# Iterasi 527: Skor Heuristik = 1673, Temperatur = 5.0596, Probabilitas = 1.0000
# Iterasi 528: Skor Heuristik = 1671, Temperatur = 5.0090, Probabilitas = 1.0000
# Iterasi 529: Skor Heuristik = 1671, Temperatur = 4.9589, Probabilitas = 0.0000
# Iterasi 530: Skor Heuristik = 1671, Temperatur = 4.9093, Probabilitas = 0.0000
# Iterasi 531: Skor Heuristik = 1671, Temperatur = 4.8602, Probabilitas = 0.0001
# Iterasi 532: Skor Heuristik = 1671, Temperatur = 4.8116, Probabilitas = 0.0000
# Iterasi 533: Skor Heuristik = 1671, Temperatur = 4.7635, Probabilitas = 0.0000
# Iterasi 534: Skor Heuristik = 1671, Temperatur = 4.7158, Probabilitas = 0.0000
# Iterasi 535: Skor Heuristik = 1671, Temperatur = 4.6687, Probabilitas = 0.0000
# Iterasi 536: Skor Heuristik = 1671, Temperatur = 4.6220, Probabilitas = 0.0000
# Iterasi 537: Skor Heuristik = 1671, Temperatur = 4.5758, Probabilitas = 0.0000
# Iterasi 538: Skor Heuristik = 1671, Temperatur = 4.5300, Probabilitas = 0.0000
# Iterasi 539: Skor Heuristik = 1671, Temperatur = 4.4847, Probabilitas = 0.0000
# Iterasi 540: Skor Heuristik = 1665, Temperatur = 4.4399, Probabilitas = 1.0000
# Iterasi 541: Skor Heuristik = 1665, Temperatur = 4.3955, Probabilitas = 0.0000
# Iterasi 542: Skor Heuristik = 1665, Temperatur = 4.3515, Probabilitas = 0.0008
# Iterasi 543: Skor Heuristik = 1665, Temperatur = 4.3080, Probabilitas = 0.0001
# Iterasi 544: Skor Heuristik = 1665, Temperatur = 4.2649, Probabilitas = 0.0000
# Iterasi 545: Skor Heuristik = 1665, Temperatur = 4.2223, Probabilitas = 0.0000
# Iterasi 546: Skor Heuristik = 1665, Temperatur = 4.1800, Probabilitas = 0.0000
# Iterasi 547: Skor Heuristik = 1665, Temperatur = 4.1382, Probabilitas = 0.0000
# Iterasi 548: Skor Heuristik = 1665, Temperatur = 4.0969, Probabilitas = 0.0000
# Iterasi 549: Skor Heuristik = 1677, Temperatur = 4.0559, Probabilitas = 0.0519
# Iterasi 550: Skor Heuristik = 1677, Temperatur = 4.0153, Probabilitas = 0.0000
# Iterasi 551: Skor Heuristik = 1677, Temperatur = 3.9752, Probabilitas = 0.0000
# Iterasi 552: Skor Heuristik = 1677, Temperatur = 3.9354, Probabilitas = 0.0000
# Iterasi 553: Skor Heuristik = 1643, Temperatur = 3.8961, Probabilitas = 1.0000
# Iterasi 554: Skor Heuristik = 1643, Temperatur = 3.8571, Probabilitas = 0.0000
# Iterasi 555: Skor Heuristik = 1643, Temperatur = 3.8185, Probabilitas = 0.0000
# Iterasi 556: Skor Heuristik = 1643, Temperatur = 3.7804, Probabilitas = 0.0000
# Iterasi 557: Skor Heuristik = 1643, Temperatur = 3.7426, Probabilitas = 0.0000
# Iterasi 558: Skor Heuristik = 1643, Temperatur = 3.7051, Probabilitas = 0.1980
# Iterasi 559: Skor Heuristik = 1643, Temperatur = 3.6681, Probabilitas = 0.0000
# Iterasi 560: Skor Heuristik = 1643, Temperatur = 3.6314, Probabilitas = 0.0000
# Iterasi 561: Skor Heuristik = 1643, Temperatur = 3.5951, Probabilitas = 0.0000
# Iterasi 562: Skor Heuristik = 1643, Temperatur = 3.5591, Probabilitas = 0.0000
# Iterasi 563: Skor Heuristik = 1615, Temperatur = 3.5235, Probabilitas = 1.0000
# Iterasi 564: Skor Heuristik = 1615, Temperatur = 3.4883, Probabilitas = 0.0000
# Iterasi 565: Skor Heuristik = 1615, Temperatur = 3.4534, Probabilitas = 0.0000
# Iterasi 566: Skor Heuristik = 1615, Temperatur = 3.4189, Probabilitas = 0.0000
# Iterasi 567: Skor Heuristik = 1615, Temperatur = 3.3847, Probabilitas = 0.0000
# Iterasi 568: Skor Heuristik = 1615, Temperatur = 3.3509, Probabilitas = 0.0000
# Iterasi 569: Skor Heuristik = 1615, Temperatur = 3.3173, Probabilitas = 0.0013
# Iterasi 570: Skor Heuristik = 1615, Temperatur = 3.2842, Probabilitas = 0.0002
# Iterasi 571: Skor Heuristik = 1615, Temperatur = 3.2513, Probabilitas = 0.0002
# Iterasi 572: Skor Heuristik = 1595, Temperatur = 3.2188, Probabilitas = 1.0000
# Iterasi 573: Skor Heuristik = 1595, Temperatur = 3.1866, Probabilitas = 0.0000
# Iterasi 574: Skor Heuristik = 1595, Temperatur = 3.1548, Probabilitas = 0.0009
# Iterasi 575: Skor Heuristik = 1595, Temperatur = 3.1232, Probabilitas = 0.0017
# Iterasi 576: Skor Heuristik = 1510, Temperatur = 3.0920, Probabilitas = 1.0000
# Iterasi 577: Skor Heuristik = 1510, Temperatur = 3.0611, Probabilitas = 0.0000
# Iterasi 578: Skor Heuristik = 1502, Temperatur = 3.0305, Probabilitas = 1.0000
# Iterasi 579: Skor Heuristik = 1502, Temperatur = 3.0001, Probabilitas = 0.0048
# Iterasi 580: Skor Heuristik = 1502, Temperatur = 2.9701, Probabilitas = 0.0000
# Iterasi 581: Skor Heuristik = 1502, Temperatur = 2.9404, Probabilitas = 0.0000
# Iterasi 582: Skor Heuristik = 1502, Temperatur = 2.9110, Probabilitas = 0.0162
# Iterasi 583: Skor Heuristik = 1502, Temperatur = 2.8819, Probabilitas = 0.0000
# Iterasi 584: Skor Heuristik = 1502, Temperatur = 2.8531, Probabilitas = 0.1221
# Iterasi 585: Skor Heuristik = 1502, Temperatur = 2.8246, Probabilitas = 0.4926
# Iterasi 586: Skor Heuristik = 1502, Temperatur = 2.7963, Probabilitas = 0.0000
# Iterasi 587: Skor Heuristik = 1502, Temperatur = 2.7684, Probabilitas = 0.0000
# Iterasi 588: Skor Heuristik = 1502, Temperatur = 2.7407, Probabilitas = 0.0000
# Iterasi 589: Skor Heuristik = 1502, Temperatur = 2.7133, Probabilitas = 0.0000
# Iterasi 590: Skor Heuristik = 1502, Temperatur = 2.6861, Probabilitas = 0.0000
# Iterasi 591: Skor Heuristik = 1502, Temperatur = 2.6593, Probabilitas = 0.0011
# Iterasi 592: Skor Heuristik = 1502, Temperatur = 2.6327, Probabilitas = 0.0000
# Iterasi 593: Skor Heuristik = 1502, Temperatur = 2.6064, Probabilitas = 0.0000
# Iterasi 594: Skor Heuristik = 1502, Temperatur = 2.5803, Probabilitas = 0.0000
# Iterasi 595: Skor Heuristik = 1502, Temperatur = 2.5545, Probabilitas = 0.0000
# Iterasi 596: Skor Heuristik = 1502, Temperatur = 2.5290, Probabilitas = 0.0000
# Iterasi 597: Skor Heuristik = 1502, Temperatur = 2.5037, Probabilitas = 0.0000
# Iterasi 598: Skor Heuristik = 1502, Temperatur = 2.4786, Probabilitas = 0.0000
# Iterasi 599: Skor Heuristik = 1502, Temperatur = 2.4538, Probabilitas = 0.0000
# Iterasi 600: Skor Heuristik = 1502, Temperatur = 2.4293, Probabilitas = 0.0006
# ...
# Iterasi 1178: Skor Heuristik = 1123, Temperatur = 0.0073, Probabilitas = 0.0000
# Iterasi 1179: Skor Heuristik = 1123, Temperatur = 0.0072, Probabilitas = 0.0000
# Iterasi 1180: Skor Heuristik = 1123, Temperatur = 0.0071, Probabilitas = 0.0000
# Iterasi 1181: Skor Heuristik = 1123, Temperatur = 0.0071, Probabilitas = 0.0000
# Iterasi 1182: Skor Heuristik = 1123, Temperatur = 0.0070, Probabilitas = 0.0000
# Iterasi 1183: Skor Heuristik = 1123, Temperatur = 0.0069, Probabilitas = 0.0000
# Iterasi 1184: Skor Heuristik = 1123, Temperatur = 0.0069, Probabilitas = 0.0000
# Iterasi 1185: Skor Heuristik = 1123, Temperatur = 0.0068, Probabilitas = 0.0000
# Iterasi 1186: Skor Heuristik = 1123, Temperatur = 0.0067, Probabilitas = 0.0000
# Iterasi 1187: Skor Heuristik = 1123, Temperatur = 0.0067, Probabilitas = 0.0000
# Iterasi 1188: Skor Heuristik = 1123, Temperatur = 0.0066, Probabilitas = 0.0000
# Iterasi 1189: Skor Heuristik = 1123, Temperatur = 0.0065, Probabilitas = 0.0000
# Iterasi 1190: Skor Heuristik = 1123, Temperatur = 0.0065, Probabilitas = 0.0000
# Iterasi 1191: Skor Heuristik = 1123, Temperatur = 0.0064, Probabilitas = 0.0000
# Iterasi 1192: Skor Heuristik = 1123, Temperatur = 0.0063, Probabilitas = 0.0000
# Iterasi 1193: Skor Heuristik = 1123, Temperatur = 0.0063, Probabilitas = 0.0000
# Iterasi 1194: Skor Heuristik = 1123, Temperatur = 0.0062, Probabilitas = 0.0000
# Iterasi 1195: Skor Heuristik = 1123, Temperatur = 0.0061, Probabilitas = 0.0000
# Iterasi 1196: Skor Heuristik = 1123, Temperatur = 0.0061, Probabilitas = 0.0000
# Iterasi 1197: Skor Heuristik = 1123, Temperatur = 0.0060, Probabilitas = 0.0000
# Iterasi 1198: Skor Heuristik = 1123, Temperatur = 0.0060, Probabilitas = 0.0000
# Iterasi 1199: Skor Heuristik = 1123, Temperatur = 0.0059, Probabilitas = 0.0000
# Iterasi 1200: Skor Heuristik = 1123, Temperatur = 0.0058, Probabilitas = 0.0000
# Iterasi 1201: Skor Heuristik = 1123, Temperatur = 0.0058, Probabilitas = 0.0000
# Iterasi 1202: Skor Heuristik = 1123, Temperatur = 0.0057, Probabilitas = 0.0000
# Iterasi 1203: Skor Heuristik = 1123, Temperatur = 0.0057, Probabilitas = 0.0000
# Iterasi 1204: Skor Heuristik = 1123, Temperatur = 0.0056, Probabilitas = 0.0000
# Iterasi 1205: Skor Heuristik = 1123, Temperatur = 0.0056, Probabilitas = 0.0000
# Iterasi 1206: Skor Heuristik = 1123, Temperatur = 0.0055, Probabilitas = 0.0000
# Iterasi 1207: Skor Heuristik = 1123, Temperatur = 0.0054, Probabilitas = 0.0000
# Iterasi 1208: Skor Heuristik = 1123, Temperatur = 0.0054, Probabilitas = 0.0000
# Iterasi 1209: Skor Heuristik = 1123, Temperatur = 0.0053, Probabilitas = 0.0000
# Iterasi 1210: Skor Heuristik = 1123, Temperatur = 0.0053, Probabilitas = 0.0000
# Iterasi 1211: Skor Heuristik = 1123, Temperatur = 0.0052, Probabilitas = 0.0000
# Iterasi 1212: Skor Heuristik = 1123, Temperatur = 0.0052, Probabilitas = 0.0000
# Iterasi 1213: Skor Heuristik = 1123, Temperatur = 0.0051, Probabilitas = 0.0000
# Iterasi 1214: Skor Heuristik = 1123, Temperatur = 0.0051, Probabilitas = 0.0000
# Iterasi 1215: Skor Heuristik = 1122, Temperatur = 0.0050, Probabilitas = 1.0000
# Iterasi 1216: Skor Heuristik = 1122, Temperatur = 0.0050, Probabilitas = 0.0000
# Iterasi 1217: Skor Heuristik = 1122, Temperatur = 0.0049, Probabilitas = 0.0000
# Iterasi 1218: Skor Heuristik = 1122, Temperatur = 0.0049, Probabilitas = 0.0000
# Iterasi 1219: Skor Heuristik = 1122, Temperatur = 0.0048, Probabilitas = 0.0000
# Iterasi 1220: Skor Heuristik = 1122, Temperatur = 0.0048, Probabilitas = 0.0000
# Iterasi 1221: Skor Heuristik = 1122, Temperatur = 0.0047, Probabilitas = 0.0000
# Iterasi 1222: Skor Heuristik = 1122, Temperatur = 0.0047, Probabilitas = 0.0000
# Iterasi 1223: Skor Heuristik = 1122, Temperatur = 0.0046, Probabilitas = 0.0000
# Iterasi 1224: Skor Heuristik = 1122, Temperatur = 0.0046, Probabilitas = 0.0000
# Iterasi 1225: Skor Heuristik = 1122, Temperatur = 0.0045, Probabilitas = 0.0000
# Iterasi 1226: Skor Heuristik = 1122, Temperatur = 0.0045, Probabilitas = 0.0000
# Iterasi 1227: Skor Heuristik = 1122, Temperatur = 0.0045, Probabilitas = 0.0000
# Iterasi 1228: Skor Heuristik = 1122, Temperatur = 0.0044, Probabilitas = 0.0000
# Iterasi 1229: Skor Heuristik = 1122, Temperatur = 0.0044, Probabilitas = 0.0000
# Iterasi 1230: Skor Heuristik = 1122, Temperatur = 0.0043, Probabilitas = 0.0000
# Iterasi 1231: Skor Heuristik = 1122, Temperatur = 0.0043, Probabilitas = 0.0000
# Iterasi 1232: Skor Heuristik = 1122, Temperatur = 0.0042, Probabilitas = 0.0000
# Iterasi 1233: Skor Heuristik = 1122, Temperatur = 0.0042, Probabilitas = 0.0000
# Iterasi 1234: Skor Heuristik = 1122, Temperatur = 0.0042, Probabilitas = 0.0000
# Iterasi 1235: Skor Heuristik = 1122, Temperatur = 0.0041, Probabilitas = 0.0000
# Iterasi 1236: Skor Heuristik = 1122, Temperatur = 0.0041, Probabilitas = 0.0000
# Iterasi 1237: Skor Heuristik = 1122, Temperatur = 0.0040, Probabilitas = 0.0000
# Iterasi 1238: Skor Heuristik = 1122, Temperatur = 0.0040, Probabilitas = 0.0000
# Iterasi 1239: Skor Heuristik = 1122, Temperatur = 0.0039, Probabilitas = 0.0000
# Iterasi 1240: Skor Heuristik = 1122, Temperatur = 0.0039, Probabilitas = 0.0000
# Iterasi 1241: Skor Heuristik = 1122, Temperatur = 0.0039, Probabilitas = 0.0000
# Iterasi 1242: Skor Heuristik = 1122, Temperatur = 0.0038, Probabilitas = 0.0000
# Iterasi 1243: Skor Heuristik = 1122, Temperatur = 0.0038, Probabilitas = 0.0000
# Iterasi 1244: Skor Heuristik = 1122, Temperatur = 0.0038, Probabilitas = 0.0000
# Iterasi 1245: Skor Heuristik = 1122, Temperatur = 0.0037, Probabilitas = 0.0000
# Iterasi 1246: Skor Heuristik = 1122, Temperatur = 0.0037, Probabilitas = 0.0000
# Iterasi 1247: Skor Heuristik = 1122, Temperatur = 0.0036, Probabilitas = 0.0000
# Iterasi 1248: Skor Heuristik = 1122, Temperatur = 0.0036, Probabilitas = 0.0000
# Iterasi 1249: Skor Heuristik = 1122, Temperatur = 0.0036, Probabilitas = 1.0000
# Iterasi 1250: Skor Heuristik = 1122, Temperatur = 0.0035, Probabilitas = 0.0000
# Iterasi 1251: Skor Heuristik = 1122, Temperatur = 0.0035, Probabilitas = 0.0000
# Iterasi 1252: Skor Heuristik = 1122, Temperatur = 0.0035, Probabilitas = 0.0000
# Iterasi 1253: Skor Heuristik = 1122, Temperatur = 0.0034, Probabilitas = 0.0000
# Iterasi 1254: Skor Heuristik = 1122, Temperatur = 0.0034, Probabilitas = 0.0000
# Iterasi 1255: Skor Heuristik = 1122, Temperatur = 0.0034, Probabilitas = 0.0000
# Iterasi 1256: Skor Heuristik = 1122, Temperatur = 0.0033, Probabilitas = 0.0000
# Iterasi 1257: Skor Heuristik = 1122, Temperatur = 0.0033, Probabilitas = 0.0000
# Iterasi 1258: Skor Heuristik = 1122, Temperatur = 0.0033, Probabilitas = 0.0000
# Iterasi 1259: Skor Heuristik = 1122, Temperatur = 0.0032, Probabilitas = 0.0000
# Iterasi 1260: Skor Heuristik = 1082, Temperatur = 0.0032, Probabilitas = 1.0000
# Iterasi 1261: Skor Heuristik = 1082, Temperatur = 0.0032, Probabilitas = 0.0000
# Iterasi 1262: Skor Heuristik = 1082, Temperatur = 0.0031, Probabilitas = 0.0000
# Iterasi 1263: Skor Heuristik = 1082, Temperatur = 0.0031, Probabilitas = 0.0000
# Iterasi 1264: Skor Heuristik = 1082, Temperatur = 0.0031, Probabilitas = 0.0000
# Iterasi 1265: Skor Heuristik = 1082, Temperatur = 0.0030, Probabilitas = 0.0000
# Iterasi 1266: Skor Heuristik = 1082, Temperatur = 0.0030, Probabilitas = 0.0000
# Iterasi 1267: Skor Heuristik = 1082, Temperatur = 0.0030, Probabilitas = 0.0000
# Iterasi 1268: Skor Heuristik = 1082, Temperatur = 0.0029, Probabilitas = 0.0000
# Iterasi 1269: Skor Heuristik = 1082, Temperatur = 0.0029, Probabilitas = 0.0000
# Iterasi 1270: Skor Heuristik = 1082, Temperatur = 0.0029, Probabilitas = 0.0000
# Iterasi 1271: Skor Heuristik = 1082, Temperatur = 0.0029, Probabilitas = 0.0000
# Iterasi 1272: Skor Heuristik = 1082, Temperatur = 0.0028, Probabilitas = 0.0000
# Iterasi 1273: Skor Heuristik = 1082, Temperatur = 0.0028, Probabilitas = 0.0000
# Iterasi 1274: Skor Heuristik = 1082, Temperatur = 0.0028, Probabilitas = 0.0000
# Iterasi 1275: Skor Heuristik = 1082, Temperatur = 0.0027, Probabilitas = 0.0000
# Iterasi 1276: Skor Heuristik = 1082, Temperatur = 0.0027, Probabilitas = 0.0000
# Iterasi 1277: Skor Heuristik = 1082, Temperatur = 0.0027, Probabilitas = 0.0000
# Iterasi 1278: Skor Heuristik = 1082, Temperatur = 0.0027, Probabilitas = 0.0000
# Iterasi 1279: Skor Heuristik = 1082, Temperatur = 0.0026, Probabilitas = 0.0000
# Iterasi 1280: Skor Heuristik = 1082, Temperatur = 0.0026, Probabilitas = 0.0000
# Iterasi 1281: Skor Heuristik = 1082, Temperatur = 0.0026, Probabilitas = 0.0000
# Iterasi 1282: Skor Heuristik = 1082, Temperatur = 0.0026, Probabilitas = 0.0000
# Iterasi 1283: Skor Heuristik = 1082, Temperatur = 0.0025, Probabilitas = 0.0000
# Iterasi 1284: Skor Heuristik = 1082, Temperatur = 0.0025, Probabilitas = 0.0000
# Iterasi 1285: Skor Heuristik = 1082, Temperatur = 0.0025, Probabilitas = 0.0000
# Iterasi 1286: Skor Heuristik = 1059, Temperatur = 0.0025, Probabilitas = 1.0000
# Iterasi 1287: Skor Heuristik = 1059, Temperatur = 0.0024, Probabilitas = 0.0000
# Iterasi 1288: Skor Heuristik = 1059, Temperatur = 0.0024, Probabilitas = 0.0000
# Iterasi 1289: Skor Heuristik = 1059, Temperatur = 0.0024, Probabilitas = 0.0000
# Iterasi 1290: Skor Heuristik = 1059, Temperatur = 0.0024, Probabilitas = 0.0000
# Iterasi 1291: Skor Heuristik = 1059, Temperatur = 0.0023, Probabilitas = 0.0000
# Iterasi 1292: Skor Heuristik = 1050, Temperatur = 0.0023, Probabilitas = 1.0000
# Iterasi 1293: Skor Heuristik = 1050, Temperatur = 0.0023, Probabilitas = 0.0000
# Iterasi 1294: Skor Heuristik = 1050, Temperatur = 0.0023, Probabilitas = 0.0000
# Iterasi 1295: Skor Heuristik = 1050, Temperatur = 0.0022, Probabilitas = 0.0000
# Iterasi 1296: Skor Heuristik = 1050, Temperatur = 0.0022, Probabilitas = 0.0000
# Iterasi 1297: Skor Heuristik = 1050, Temperatur = 0.0022, Probabilitas = 0.0000
# Iterasi 1298: Skor Heuristik = 1050, Temperatur = 0.0022, Probabilitas = 1.0000
# Iterasi 1299: Skor Heuristik = 1050, Temperatur = 0.0022, Probabilitas = 0.0000
# Iterasi 1300: Skor Heuristik = 1050, Temperatur = 0.0021, Probabilitas = 0.0000
# Iterasi 1301: Skor Heuristik = 1050, Temperatur = 0.0021, Probabilitas = 0.0000
# Iterasi 1302: Skor Heuristik = 1050, Temperatur = 0.0021, Probabilitas = 0.0000
# Iterasi 1303: Skor Heuristik = 1050, Temperatur = 0.0021, Probabilitas = 0.0000
# Iterasi 1304: Skor Heuristik = 1050, Temperatur = 0.0021, Probabilitas = 0.0000
# Iterasi 1305: Skor Heuristik = 1050, Temperatur = 0.0020, Probabilitas = 0.0000
# Iterasi 1306: Skor Heuristik = 1050, Temperatur = 0.0020, Probabilitas = 0.0000
# Iterasi 1307: Skor Heuristik = 1050, Temperatur = 0.0020, Probabilitas = 0.0000
# Iterasi 1308: Skor Heuristik = 1050, Temperatur = 0.0020, Probabilitas = 0.0000
# Iterasi 1309: Skor Heuristik = 1050, Temperatur = 0.0020, Probabilitas = 0.0000
# Iterasi 1310: Skor Heuristik = 1050, Temperatur = 0.0019, Probabilitas = 0.0000
# Iterasi 1311: Skor Heuristik = 1050, Temperatur = 0.0019, Probabilitas = 0.0000
# Iterasi 1312: Skor Heuristik = 1050, Temperatur = 0.0019, Probabilitas = 0.0000
# Iterasi 1313: Skor Heuristik = 1050, Temperatur = 0.0019, Probabilitas = 0.0000
# Iterasi 1314: Skor Heuristik = 1050, Temperatur = 0.0019, Probabilitas = 0.0000
# Iterasi 1315: Skor Heuristik = 1050, Temperatur = 0.0018, Probabilitas = 0.0000
# Iterasi 1316: Skor Heuristik = 1032, Temperatur = 0.0018, Probabilitas = 1.0000
# Iterasi 1317: Skor Heuristik = 1032, Temperatur = 0.0018, Probabilitas = 0.0000
# Iterasi 1318: Skor Heuristik = 1032, Temperatur = 0.0018, Probabilitas = 0.0000
# Iterasi 1319: Skor Heuristik = 1032, Temperatur = 0.0018, Probabilitas = 0.0000
# Iterasi 1320: Skor Heuristik = 1032, Temperatur = 0.0017, Probabilitas = 0.0000
# Iterasi 1321: Skor Heuristik = 1032, Temperatur = 0.0017, Probabilitas = 0.0000
# Iterasi 1322: Skor Heuristik = 1032, Temperatur = 0.0017, Probabilitas = 0.0000
# Iterasi 1323: Skor Heuristik = 1032, Temperatur = 0.0017, Probabilitas = 0.0000
# Iterasi 1324: Skor Heuristik = 1032, Temperatur = 0.0017, Probabilitas = 0.0000
# Iterasi 1325: Skor Heuristik = 1032, Temperatur = 0.0017, Probabilitas = 0.0000
# Iterasi 1326: Skor Heuristik = 1032, Temperatur = 0.0016, Probabilitas = 0.0000
# Iterasi 1327: Skor Heuristik = 1032, Temperatur = 0.0016, Probabilitas = 0.0000
# Iterasi 1328: Skor Heuristik = 1032, Temperatur = 0.0016, Probabilitas = 0.0000
# Iterasi 1329: Skor Heuristik = 1032, Temperatur = 0.0016, Probabilitas = 0.0000
# Iterasi 1330: Skor Heuristik = 1032, Temperatur = 0.0016, Probabilitas = 0.0000
# Iterasi 1331: Skor Heuristik = 1032, Temperatur = 0.0016, Probabilitas = 0.0000
# Iterasi 1332: Skor Heuristik = 1032, Temperatur = 0.0016, Probabilitas = 0.0000
# Iterasi 1333: Skor Heuristik = 1032, Temperatur = 0.0015, Probabilitas = 0.0000
# Iterasi 1334: Skor Heuristik = 1032, Temperatur = 0.0015, Probabilitas = 0.0000
# Iterasi 1335: Skor Heuristik = 1032, Temperatur = 0.0015, Probabilitas = 0.0000
# Iterasi 1336: Skor Heuristik = 1032, Temperatur = 0.0015, Probabilitas = 0.0000
# Iterasi 1337: Skor Heuristik = 1032, Temperatur = 0.0015, Probabilitas = 0.0000
# Iterasi 1338: Skor Heuristik = 1032, Temperatur = 0.0015, Probabilitas = 0.0000
# Iterasi 1339: Skor Heuristik = 1032, Temperatur = 0.0014, Probabilitas = 0.0000
# Iterasi 1340: Skor Heuristik = 1032, Temperatur = 0.0014, Probabilitas = 0.0000
# Iterasi 1341: Skor Heuristik = 1032, Temperatur = 0.0014, Probabilitas = 0.0000
# Iterasi 1342: Skor Heuristik = 1032, Temperatur = 0.0014, Probabilitas = 0.0000
# Iterasi 1343: Skor Heuristik = 1032, Temperatur = 0.0014, Probabilitas = 0.0000
# Iterasi 1344: Skor Heuristik = 1032, Temperatur = 0.0014, Probabilitas = 0.0000
# Iterasi 1345: Skor Heuristik = 1032, Temperatur = 0.0014, Probabilitas = 0.0000
# Iterasi 1346: Skor Heuristik = 1032, Temperatur = 0.0013, Probabilitas = 0.0000
# Iterasi 1347: Skor Heuristik = 1032, Temperatur = 0.0013, Probabilitas = 0.0000
# Iterasi 1348: Skor Heuristik = 1032, Temperatur = 0.0013, Probabilitas = 0.0000
# Iterasi 1349: Skor Heuristik = 1032, Temperatur = 0.0013, Probabilitas = 0.0000
# Iterasi 1350: Skor Heuristik = 1032, Temperatur = 0.0013, Probabilitas = 0.0000
# Iterasi 1351: Skor Heuristik = 1032, Temperatur = 0.0013, Probabilitas = 0.0000
# Iterasi 1352: Skor Heuristik = 1032, Temperatur = 0.0013, Probabilitas = 0.0000
# Iterasi 1353: Skor Heuristik = 1032, Temperatur = 0.0013, Probabilitas = 0.0000
# Iterasi 1354: Skor Heuristik = 1032, Temperatur = 0.0012, Probabilitas = 0.0000
# Iterasi 1355: Skor Heuristik = 1032, Temperatur = 0.0012, Probabilitas = 0.0000
# Iterasi 1356: Skor Heuristik = 1032, Temperatur = 0.0012, Probabilitas = 0.0000
# Iterasi 1357: Skor Heuristik = 1032, Temperatur = 0.0012, Probabilitas = 0.0000
# Iterasi 1358: Skor Heuristik = 1032, Temperatur = 0.0012, Probabilitas = 0.0000
# Iterasi 1359: Skor Heuristik = 1032, Temperatur = 0.0012, Probabilitas = 0.0000
# Iterasi 1360: Skor Heuristik = 1032, Temperatur = 0.0012, Probabilitas = 0.0000
# Iterasi 1361: Skor Heuristik = 1032, Temperatur = 0.0012, Probabilitas = 0.0000
# Iterasi 1362: Skor Heuristik = 1032, Temperatur = 0.0011, Probabilitas = 0.0000
# Iterasi 1363: Skor Heuristik = 1032, Temperatur = 0.0011, Probabilitas = 0.0000
# Iterasi 1364: Skor Heuristik = 1032, Temperatur = 0.0011, Probabilitas = 0.0000
# Iterasi 1365: Skor Heuristik = 1032, Temperatur = 0.0011, Probabilitas = 0.0000
# Iterasi 1366: Skor Heuristik = 1018, Temperatur = 0.0011, Probabilitas = 1.0000
# Iterasi 1367: Skor Heuristik = 1018, Temperatur = 0.0011, Probabilitas = 0.0000
# Iterasi 1368: Skor Heuristik = 1018, Temperatur = 0.0011, Probabilitas = 0.0000
# Iterasi 1369: Skor Heuristik = 1018, Temperatur = 0.0011, Probabilitas = 0.0000
# Iterasi 1370: Skor Heuristik = 1018, Temperatur = 0.0011, Probabilitas = 0.0000
# Iterasi 1371: Skor Heuristik = 1018, Temperatur = 0.0010, Probabilitas = 0.0000
# Iterasi 1372: Skor Heuristik = 1018, Temperatur = 0.0010, Probabilitas = 0.0000
# Iterasi 1373: Skor Heuristik = 1018, Temperatur = 0.0010, Probabilitas = 0.0000
# Iterasi 1374: Skor Heuristik = 1018, Temperatur = 0.0010, Probabilitas = 0.0000
# Iterasi 1375: Skor Heuristik = 1018, Temperatur = 0.0010, Probabilitas = 0.0000
# Waktu yang dibutuhkan: 8.294220924377441 detik
# Total frekuensi stuck di local optima: 5

# %%
# Visualisasi kondisi akhir
plot_cube(final_state, f"Final State of the Cube (Score: {final_score})")

# %%
# Plotting hasil objective function dan probabilitas
main.plot_objective_function()
