# %% [markdown]
# ## MAIN PROGRAM UNTUK SEMUA ALGORITMA

# %% [markdown]
# 1. Steepest Ascendt Hill Climbing

# %%
from algorithms.SteepestHillClimb import SteepestHillClimbing
from cube.visual import plot_cube

# %%
main = SteepestHillClimbing(max_iterations=100)
initial_state = main.initial_state
initial_score = main.objective_function

# Visualisasi kondisi awal
plot_cube(initial_state, f"Initial State of the Cube (Score: {initial_score})")

# %%
# Menjalankan pencarian lokal
final_state, final_score, execution_time = main.search()
# Out:
# Iterasi 1: Skor sekarang = 2983
# Iterasi 2: Skor sekarang = 2655
# Iterasi 3: Skor sekarang = 2341
# Iterasi 4: Skor sekarang = 2085
# Iterasi 5: Skor sekarang = 1845
# Iterasi 6: Skor sekarang = 1728
# Iterasi 7: Skor sekarang = 1582
# Iterasi 8: Skor sekarang = 1435
# Iterasi 9: Skor sekarang = 1335
# Iterasi 10: Skor sekarang = 1279
# Iterasi 11: Skor sekarang = 1235
# Iterasi 12: Skor sekarang = 1201
# Iterasi 13: Skor sekarang = 1141
# Iterasi 14: Skor sekarang = 1101
# Iterasi 15: Skor sekarang = 1052
# Iterasi 16: Skor sekarang = 1010
# Iterasi 17: Skor sekarang = 970
# Iterasi 18: Skor sekarang = 930
# Iterasi 19: Skor sekarang = 897
# Iterasi 20: Skor sekarang = 869
# Iterasi 21: Skor sekarang = 833
# Iterasi 22: Skor sekarang = 818
# Iterasi 23: Skor sekarang = 798
# Iterasi 24: Skor sekarang = 781
# Iterasi 25: Skor sekarang = 754
# Iterasi 26: Skor sekarang = 724
# Iterasi 27: Skor sekarang = 688
# Iterasi 28: Skor sekarang = 682
# Iterasi 29: Skor sekarang = 678
# Iterasi 30: Skor sekarang = 670
# Iterasi 31: Skor sekarang = 663
# Iterasi 32: Skor sekarang = 653
# Iterasi 33: Skor sekarang = 649
# Iterasi 34: Skor sekarang = 646
# Iterasi 35: Skor sekarang = 641
# Iterasi 36: Skor sekarang = 635
# Iterasi 37: Skor sekarang = 631
# Iterasi 38: Skor sekarang = 630
# Iterasi 39: Skor sekarang = 629
# Iterasi 40: Skor sekarang = 628

# %%
# Visualisasi kondisi akhir
plot_cube(final_state, f"Final State of the Cube (Score: {final_score}, Time: {execution_time:.2f} seconds)")

# %% [markdown]
# 2. Simulated Annealing
