# %% [markdown]
# ## MAIN PROGRAM UNTUK SEMUA ALGORITMA

# %% [markdown]
# 1. Steepest Ascendt Hill Climbing

# %%
from algorithms.SteepestHillClimb import SteepestHillClimbing
from cube.visual import plot_cube
import matplotlib.pyplot as plt

# %%
main = SteepestHillClimbing(max_iterations=100)
initial_state = main.initial_state
initial_score = main.objective_function


# Visualisasi kondisi awal
plot_cube(initial_state, f"Initial State of the Cube (Score: {initial_score})")

# %%
final_state, final_score, execution_time, history = main.search()
# Out:
# Iterasi 1: Skor sekarang = 3562
# Iterasi 2: Skor sekarang = 3074
# Iterasi 3: Skor sekarang = 2748
# Iterasi 4: Skor sekarang = 2462
# Iterasi 5: Skor sekarang = 2254
# Iterasi 6: Skor sekarang = 2102
# Iterasi 7: Skor sekarang = 1958
# Iterasi 8: Skor sekarang = 1845
# Iterasi 9: Skor sekarang = 1695
# Iterasi 10: Skor sekarang = 1587
# Iterasi 11: Skor sekarang = 1521
# Iterasi 12: Skor sekarang = 1453
# Iterasi 13: Skor sekarang = 1397
# Iterasi 14: Skor sekarang = 1347
# Iterasi 15: Skor sekarang = 1301
# Iterasi 16: Skor sekarang = 1230
# Iterasi 17: Skor sekarang = 1166
# Iterasi 18: Skor sekarang = 1120
# Iterasi 19: Skor sekarang = 1082
# Iterasi 20: Skor sekarang = 1048
# Iterasi 21: Skor sekarang = 1014
# Iterasi 22: Skor sekarang = 986
# Iterasi 23: Skor sekarang = 962
# Iterasi 24: Skor sekarang = 944
# Iterasi 25: Skor sekarang = 926
# Iterasi 26: Skor sekarang = 896
# Iterasi 27: Skor sekarang = 884
# Iterasi 28: Skor sekarang = 860
# Iterasi 29: Skor sekarang = 848
# Iterasi 30: Skor sekarang = 830
# Iterasi 31: Skor sekarang = 812
# Iterasi 32: Skor sekarang = 792
# Iterasi 33: Skor sekarang = 736
# Iterasi 34: Skor sekarang = 722
# Iterasi 35: Skor sekarang = 710
# Iterasi 36: Skor sekarang = 694
# Iterasi 37: Skor sekarang = 682
# Iterasi 38: Skor sekarang = 672
# Iterasi 39: Skor sekarang = 664
# Iterasi 40: Skor sekarang = 654
# Iterasi 41: Skor sekarang = 646
# Iterasi 42: Skor sekarang = 639
# Iterasi 43: Skor sekarang = 633
# Iterasi 44: Skor sekarang = 629
# Iterasi 45: Skor sekarang = 625
# Iterasi 46: Skor sekarang = 621
# Iterasi 47: Skor sekarang = 618
# Iterasi 48: Skor sekarang = 594
# Iterasi 49: Skor sekarang = 587
# Iterasi 50: Skor sekarang = 585
# Iterasi 51: Skor sekarang = 583
# Iterasi 52: Skor sekarang = 580
# Iterasi 53: Skor sekarang = 578
# Iterasi 54: Skor sekarang = 576
# Iterasi 55: Skor sekarang = 573

# %%
# Visualisasi kondisi akhir
plot_cube(final_state, f"Final State of the Cube (Score: {final_score}, Time: {execution_time:.2f} seconds)")

# %%
# Visualisasi skor tiap iterasi
plt.plot(history)
plt.xlabel('Iteration')
plt.ylabel('Score')
plt.title('Score per Iteration')
plt.show()

# %% [markdown]
# 2. Simulated Annealing
