# %% [markdown]
# ## MAIN PROGRAM UNTUK SEMUA ALGORITMA

# %% [markdown]
# 1. Steepest Ascendt Hill Climbing

# %%
from algorithms.SteepestHillClimb import SteepestHillClimbing
from cube.visual import plot_cube
import matplotlib.pyplot as plt

# %%
main = SteepestHillClimbing(max_iterations=100)
initial_state = main.initial_state
initial_score = main.objective_function


# Visualisasi kondisi awal
plot_cube(initial_state, f"Initial State of the Cube (Score: {initial_score})")

# %%
final_state, final_score, execution_time, history = main.search()
# Out:
# Iterasi 1: Skor sekarang = 3262
# Iterasi 2: Skor sekarang = 2822
# Iterasi 3: Skor sekarang = 2523
# Iterasi 4: Skor sekarang = 2304
# Iterasi 5: Skor sekarang = 2058
# Iterasi 6: Skor sekarang = 1952
# Iterasi 7: Skor sekarang = 1858
# Iterasi 8: Skor sekarang = 1645
# Iterasi 9: Skor sekarang = 1522
# Iterasi 10: Skor sekarang = 1438
# Iterasi 11: Skor sekarang = 1383
# Iterasi 12: Skor sekarang = 1301
# Iterasi 13: Skor sekarang = 1261
# Iterasi 14: Skor sekarang = 1213
# Iterasi 15: Skor sekarang = 1173
# Iterasi 16: Skor sekarang = 1143
# Iterasi 17: Skor sekarang = 1113
# Iterasi 18: Skor sekarang = 1047
# Iterasi 19: Skor sekarang = 1008
# Iterasi 20: Skor sekarang = 984
# Iterasi 21: Skor sekarang = 957
# Iterasi 22: Skor sekarang = 934
# Iterasi 23: Skor sekarang = 913
# Iterasi 24: Skor sekarang = 896
# Iterasi 25: Skor sekarang = 878
# Iterasi 26: Skor sekarang = 862
# Iterasi 27: Skor sekarang = 844
# Iterasi 28: Skor sekarang = 820
# Iterasi 29: Skor sekarang = 810
# Iterasi 30: Skor sekarang = 800
# Iterasi 31: Skor sekarang = 782
# Iterasi 32: Skor sekarang = 766
# Iterasi 33: Skor sekarang = 756
# Iterasi 34: Skor sekarang = 747
# Iterasi 35: Skor sekarang = 742
# Iterasi 36: Skor sekarang = 738
# Iterasi 37: Skor sekarang = 734
# Iterasi 38: Skor sekarang = 728
# Iterasi 39: Skor sekarang = 724
# Iterasi 40: Skor sekarang = 719
# Iterasi 41: Skor sekarang = 709
# Iterasi 42: Skor sekarang = 695
# Iterasi 43: Skor sekarang = 687
# Iterasi 44: Skor sekarang = 679
# Iterasi 45: Skor sekarang = 671
# Iterasi 46: Skor sekarang = 666
# Iterasi 47: Skor sekarang = 662
# Iterasi 48: Skor sekarang = 658
# Iterasi 49: Skor sekarang = 656
# Iterasi 50: Skor sekarang = 655
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 final_state, final_score, execution_time, history = main.search()
#
# ValueError: not enough values to unpack (expected 4, got 3)

# %%
# Visualisasi kondisi akhir
plot_cube(final_state, f"Final State of the Cube (Score: {final_score}, Time: {execution_time:.2f} seconds)")

# %%
# Visualisasi skor tiap iterasi
plt.plot(history)
plt.xlabel('Iteration')
plt.ylabel('Score')
plt.title('Score per Iteration')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 2
#       1 # Plot nilai objective function terhadap jumlah iterasi
# ----> 2 plt.plot(main.history, marker='o', linestyle='-')
#       3 plt.title("Objective Function Score over Iterations")
#       4 plt.xlabel("Iteration")
#
# AttributeError: 'SteepestHillClimbing' object has no attribute 'history'

# %% [markdown]
# 2. Simulated Annealing
