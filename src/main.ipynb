# %% [markdown]
# ## MAIN PROGRAM UNTUK SEMUA ALGORITMA

# %% [markdown]
# 1. Steepest Ascendt Hill Climbing

# %%
from algorithms.SteepestHillClimb import SteepestHillClimbing
from cube.visual import plot_cube
import matplotlib.pyplot as plt

# %%
main = SteepestHillClimbing(max_iterations=100)
initial_state = main.initial_state
initial_score = main.objective_function


# Visualisasi kondisi awal
plot_cube(initial_state, f"Initial State of the Cube (Score: {initial_score})")

# %%
final_state, final_score, execution_time, history, iteration_count = main.search()
# Out:
# Iterasi 1: Skor sekarang = 3656
# Iterasi 2: Skor sekarang = 3266
# Iterasi 3: Skor sekarang = 3062
# Iterasi 4: Skor sekarang = 2929
# Iterasi 5: Skor sekarang = 2765
# Iterasi 6: Skor sekarang = 2561
# Iterasi 7: Skor sekarang = 2443
# Iterasi 8: Skor sekarang = 2354
# Iterasi 9: Skor sekarang = 2092
# Iterasi 10: Skor sekarang = 2004
# Iterasi 11: Skor sekarang = 1896
# Iterasi 12: Skor sekarang = 1802
# Iterasi 13: Skor sekarang = 1730
# Iterasi 14: Skor sekarang = 1656
# Iterasi 15: Skor sekarang = 1606
# Iterasi 16: Skor sekarang = 1548
# Iterasi 17: Skor sekarang = 1496
# Iterasi 18: Skor sekarang = 1384
# Iterasi 19: Skor sekarang = 1318
# Iterasi 20: Skor sekarang = 1276
# Iterasi 21: Skor sekarang = 1230
# Iterasi 22: Skor sekarang = 1198
# Iterasi 23: Skor sekarang = 1160
# Iterasi 24: Skor sekarang = 1110
# Iterasi 25: Skor sekarang = 1080
# Iterasi 26: Skor sekarang = 1053
# Iterasi 27: Skor sekarang = 1026
# Iterasi 28: Skor sekarang = 999
# Iterasi 29: Skor sekarang = 983
# Iterasi 30: Skor sekarang = 970
# Iterasi 31: Skor sekarang = 944
# Iterasi 32: Skor sekarang = 936
# Iterasi 33: Skor sekarang = 923
# Iterasi 34: Skor sekarang = 876
# Iterasi 35: Skor sekarang = 864
# Iterasi 36: Skor sekarang = 856
# Iterasi 37: Skor sekarang = 846
# Iterasi 38: Skor sekarang = 839
# Iterasi 39: Skor sekarang = 834
# Iterasi 40: Skor sekarang = 821
# Iterasi 41: Skor sekarang = 813
# Iterasi 42: Skor sekarang = 809
# Iterasi 43: Skor sekarang = 805
# Iterasi 44: Skor sekarang = 803
# Iterasi 45: Skor sekarang = 793
# Iterasi 46: Skor sekarang = 778
# Iterasi 47: Skor sekarang = 761
# Iterasi 48: Skor sekarang = 753
# Iterasi 49: Skor sekarang = 745
# Iterasi 50: Skor sekarang = 736
# Iterasi 51: Skor sekarang = 733
# Iterasi 52: Skor sekarang = 730
# Iterasi 53: Skor sekarang = 728
# Iterasi 54: Skor sekarang = 724
# Iterasi 55: Skor sekarang = 722
# Iterasi 56: Skor sekarang = 721
# Iterasi 57: Skor sekarang = 720
# Iterasi 58: Skor sekarang = 718
# Iterasi 59: Skor sekarang = 717
# Iterasi 60: Skor sekarang = 716
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 final_state, final_score, execution_time, history, iteration_count = main.search()
#
# ValueError: not enough values to unpack (expected 5, got 4)

# %%
# Visualisasi kondisi akhir
plot_cube(final_state, f"Final State of the Cube (Score: {final_score}, Time: {execution_time:.2f} seconds)")
# print waktu iterasi
print(f"Total Iteration: {iteration_count}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 4
#       2 plot_cube(final_state, f"Final State of the Cube (Score: {final_score}, Time: {execution_time:.2f} seconds)")
#       3 # print waktu iterasi
# ----> 4 print(f"Total Iteration: {iteration_count}")
#
# NameError: name 'iteration_count' is not defined

# %%
# Visualisasi skor tiap iterasi
plt.plot(history)
plt.xlabel('Iteration')
plt.ylabel('Score')
plt.title('Score per Iteration')
plt.show()

# %% [markdown]
# 2. Simulated Annealing
