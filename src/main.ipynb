# %% [markdown]
# # MAIN PROGRAM UNTUK SEMUA ALGORITMA

# %% [markdown]
# ### Kubus akan di generate dari lapisan bawah ke lapisan atas. Jadi bayangkan saja layer1 ditumpuk layer2 ditumpuk layer3 dan seterusnya

# %% [markdown]
# 1. Steepest Ascendt Hill Climbing

# %%
from algorithms.SteepestHillClimb import SteepestHillClimbing
from cube.visual import plot_cube
import matplotlib.pyplot as plt

# %%
main = SteepestHillClimbing(max_iterations=100)
initial_state = main.initial_state
initial_score = main.objective_function


# Visualisasi kondisi awal
plot_cube(initial_state, f"Initial State of the Cube (Score: {initial_score})")

# %%
final_state, final_score, execution_time, history, iteration_count = main.search()
# Out:
# Iterasi 1: Skor sekarang = 3004
# Iterasi 2: Skor sekarang = 2688
# Iterasi 3: Skor sekarang = 2362
# Iterasi 4: Skor sekarang = 2090
# Iterasi 5: Skor sekarang = 1861
# Iterasi 6: Skor sekarang = 1653
# Iterasi 7: Skor sekarang = 1541
# Iterasi 8: Skor sekarang = 1453
# Iterasi 9: Skor sekarang = 1401
# Iterasi 10: Skor sekarang = 1352
# Iterasi 11: Skor sekarang = 1292
# Iterasi 12: Skor sekarang = 1266
# Iterasi 13: Skor sekarang = 1124
# Iterasi 14: Skor sekarang = 1050
# Iterasi 15: Skor sekarang = 1028
# Iterasi 16: Skor sekarang = 1007
# Iterasi 17: Skor sekarang = 989
# Iterasi 18: Skor sekarang = 971
# Iterasi 19: Skor sekarang = 953
# Iterasi 20: Skor sekarang = 937
# Iterasi 21: Skor sekarang = 911
# Iterasi 22: Skor sekarang = 897
# Iterasi 23: Skor sekarang = 878
# Iterasi 24: Skor sekarang = 864
# Iterasi 25: Skor sekarang = 858
# Iterasi 26: Skor sekarang = 854
# Iterasi 27: Skor sekarang = 852
# Iterasi 28: Skor sekarang = 844
# Iterasi 29: Skor sekarang = 806
# Iterasi 30: Skor sekarang = 788
# Iterasi 31: Skor sekarang = 782
# Iterasi 32: Skor sekarang = 768
# Iterasi 33: Skor sekarang = 758
# Iterasi 34: Skor sekarang = 754
# Iterasi 35: Skor sekarang = 750
# Iterasi 36: Skor sekarang = 746
# Iterasi 37: Skor sekarang = 739
# Iterasi 38: Skor sekarang = 735
# Iterasi 39: Skor sekarang = 732
# Iterasi 40: Skor sekarang = 726
# Iterasi 41: Skor sekarang = 717
# Iterasi 42: Skor sekarang = 707
# Iterasi 43: Skor sekarang = 699
# Iterasi 44: Skor sekarang = 693
# Iterasi 45: Skor sekarang = 681
# Iterasi 46: Skor sekarang = 672
# Iterasi 47: Skor sekarang = 670
# Iterasi 48: Skor sekarang = 668
# Iterasi 49: Skor sekarang = 663
# Iterasi 50: Skor sekarang = 659
# Iterasi 51: Skor sekarang = 651
# Iterasi 52: Skor sekarang = 643
# Iterasi 53: Skor sekarang = 640
# Iterasi 54: Skor sekarang = 638
# Iterasi 55: Skor sekarang = 632
# Iterasi 56: Skor sekarang = 629
# Iterasi 57: Skor sekarang = 627
# Iterasi 58: Skor sekarang = 625
# Iterasi 59: Skor sekarang = 623
# Iterasi 60: Skor sekarang = 619

# %%
# Visualisasi kondisi akhir
plot_cube(final_state, f"Final State of the Cube (Score: {final_score}, Time: {execution_time:.2f} seconds, Iteration: {iteration_count-1})")

# %%
# Visualisasi skor tiap iterasi
plt.plot(history)
plt.xlabel('Iteration')
plt.ylabel('Score')
plt.title('Score per Iteration')
plt.show()

# %% [markdown]
# 2. Simulated Annealing
